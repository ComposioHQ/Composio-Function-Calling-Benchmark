# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

schema_funcs_param = {}

for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
    single_func_param = {}
    for sck, scv in sc["parameters"]["properties"].items():
        single_func_param[sck] = scv['description']
    schema_funcs_param[sc["name"]] = single_func_param

pprint(schema_funcs_param)  # print(f"\t{sck} - {scv['description']}")
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.
# {'create_space': {'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The name of the new space__',
#                   'team_id': 'The ID of the team__'},
#  'create_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to create__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to create__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to create__'},
#  'delete_space': {'space_id': 'The ID of the space__'},
#  'delete_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to delete__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag_name': 'The name of the tag to delete__'},
#  'get_space': {'space_id': 'The ID of the space__'},
#  'get_space_tags': {'space_id': 'The ID of the space__'},
#  'get_spaces': {'archived': 'A flag to decide whether to include archived '
#                             'spaces or not__',
#                 'team_id': 'The ID of the team__'},
#  'update_space': {'admin_can_manage': 'A flag to determine if the '
#                                       'administrator can manage the space or '
#                                       'not__',
#                   'color': 'The color used for the space__',
#                   'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The new name of the space__',
#                   'private': 'A flag to determine if the space is private or '
#                              'not__',
#                   'space_id': 'The ID of the space__'}}

# %%
schema_func_decription_dict = {
    "get_spaces": "Retrives information of all the spaces available in user's Clickup Workspace.",
    "create_space": "Creates a new ClickUp space",
    "get_space": "Retrives information of a specific Clickup space",
    "update_space": "Modifies name, settings the Space color, and assignee management Space.",
    "delete_space": "Delete an existing space from user's ClickUp Workspace",
    "get_space_tags": "Retrives all the Tags assigned on all the tasks in a Space.",
    "create_space_tag": "Assigns a customized Tag in a ClickUp Space.",
    "delete_space_tag": "Deletes a specific tag previously assigned in a space.",
}

schema_func_params_dict = {
    'create_space': {
        'features__due_dates__enabled': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
        'name': 'The name of the new space to create \nExample:  \'NewWorkspace\', \'TempWorkspace\'',
        'team_id': 'The ID of the team \nExample:  \'abc123\', \'def456\' '
        },
    'create_space_tag': {
        'space_id': 'The ID of the space \nExample:  \'abc123\', \'def456\'',
        'tag__name': 'The name of the tag to assign \nExample:  \'NewTag\', \'TempTag\'',
        'tag__tag_bg': 'The background color of the tag to assign \nExample:  \'#FF0000\', \'#00FF00\'',
        'tag__tag_fg': 'The foreground(text) color of the tag to assign \nExample:  \'#FF0000\', \'#00FF00\''
        },
    'delete_space': {
        'space_id': 'The ID of the space to delete \nExample:  \'abc123\', \'def456\''
        },
    'delete_space_tag': {
        'space_id': 'The ID of the space to delete \nExample:  \'abc123\', \'def456\'',
        'tag__name': 'The name of the tag to delete \nExample:  \'NewTag\', \'TempTag\'',
        'tag__tag_bg': 'The background color of the tag to delete \nExample:  \'#FF0000\', \'#00FF00\', \'#0000FF\'',
        'tag__tag_fg': 'The foreground color of the tag to delete \nExample:  \'#FF0000\', \'#00FF00\', \'#0000FF\'',
        'tag_name': 'The name of the tag to delete \nExample:  \'NewTag\', \'TempTag\''
        },
    'get_space': {
        'space_id': 'The ID of the space to retrieve details \nExample:  \'abc123\', \'def456\''
        },
    'get_space_tags': {
        'space_id': 'The ID of the space to retrieve all the tags from \nExample:  \'abc123\', \'def456\''
        },
    'get_spaces': {
        'archived': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
        'team_id': 'The ID of the team \nExample:  \'abc123\', \'def456\''
        },
    'update_space': {
        'admin_can_manage': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
        'color': 'The color used for the space \nExample:  \'#FF0000\', \'#00FF00\'',
        'features__due_dates__enabled': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
        'name': 'The new name of the space \nExample:  \'NewWorkspace\', \'TempWorkspace\'',
        'private': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
        'space_id': 'The ID of the space to update \nExample:  \'abc123\', \'def456\''
        }
        }
    
optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["description"] = schema_func_decription_dict[temp_dict["name"]]
    for func_param_name, func_param_description in schema_func_params_dict[temp_dict["name"]].items():
        sc["parameters"]["properties"][func_param_name]["description"] = func_param_description
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized3_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Creates a new ClickUp space',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The name of the new space to create \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456' ",
#      'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Retrives information of a specific Clickup space',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to retrieve details \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'color': {'description': "The color used for the space \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The new name of the space \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': "The ID of the space to update \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': "Delete an existing space from user's ClickUp Workspace",
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to retrieve all the tags from \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to assign \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground(text) color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Deletes a specific tag previously assigned in a space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag_name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in optimized_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'input_schema': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'name': 'create_space',
#   'description': 'Creates a new ClickUp space',
#   'input_schema': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The name of the new space to create \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456' ",
#      'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'get_space',
#   'description': 'Retrives information of a specific Clickup space',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to retrieve details \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'update_space',
#   'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'input_schema': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'color': {'description': "The color used for the space \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The new name of the space \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': "The ID of the space to update \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'delete_space',
#   'description': "Delete an existing space from user's ClickUp Workspace",
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'get_space_tags',
#   'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to retrieve all the tags from \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'create_space_tag',
#   'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to assign \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground(text) color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'name': 'delete_space_tag',
#   'description': 'Deletes a specific tag previously assigned in a space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag_name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
import anthropic
client = anthropic.Anthropic()


tool_trailer = "\n".join([f'{sc["name"]} - {sc["description"]}' for sc in flattened_schema])

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system =  f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

The Functions provided to you are:
{tool_trailer}

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response
# Out:
# ToolsBetaMessage(id='msg_013n55P91m3aQxjaemGEEXfZ', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01FwR1HHRZyrkmCFwCTx99hi', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=235))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:48<00:00,  2.16s/it]
# [ToolsBetaMessage(id='msg_01TkXRaNMKKLBQaRDd1yP42D', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01RjhU3cEXqVAzvaSBE9vwCM', input={'team_id': 'team123', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=80)),
#  ToolsBetaMessage(id='msg_0172PgRuZ2SP5GxUQQkXAKVN', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01NZXHdvqwYV9Q1VYPirCbPc', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=235)),
#  ToolsBetaMessage(id='msg_01BoyPmWbKqZE4ykL93PhFf7', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the custom tags from the "sd456" ClickUp space.', type='text'), ToolUseBlock(id='toolu_01Jr2duYp3Y6wDaAHmU5gZba', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2628, output_tokens=84)),
#  ToolsBetaMessage(id='msg_01EEKeoQjLi4LWu3LorWYfnp', content=[TextBlock(text="Okay, let's address this issue step-by-step:", type='text'), ToolUseBlock(id='toolu_017PWbc1Ngyc7ChmTtgeLzAs', input={'space_id': 'prj1122'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2655, output_tokens=75)),
#  ToolsBetaMessage(id='msg_01RbLkWAPmL8oom7yB3waFbT', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" based on the information provided.', type='text'), ToolUseBlock(id='toolu_017H5suBkassNr9p5eNDTB1j', input={'space_id': 'qa789', 'tag__name': 'MinorIssue', 'tag__tag_bg': '#FFFFE0', 'tag__tag_fg': '#000000', 'tag_name': 'MinorIssue'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=183)),
#  ToolsBetaMessage(id='msg_01NhrfaCbz8dF7tfSd1D5xXh', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01NesufuP8bBAaKsYSSs8whU', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': '#000000', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=292)),
#  ToolsBetaMessage(id='msg_01WpCxjazRNDcd9kqctQinCc', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_019pjTSdbmyfUsSuvBbADwiw', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2623, output_tokens=63)),
#  ToolsBetaMessage(id='msg_01XedcYtVgSUqwqqpLPMgPf5', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_013vLdbtznYKQ1RSuVmPF286', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=233)),
#  ToolsBetaMessage(id='msg_01BoRkjymFtMGAFCuC8rpFbc', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01YVd66Dq92DDzJmuiczyuqU', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2618, output_tokens=63)),
#  ToolsBetaMessage(id='msg_01TWhquwzDKhtsA1xmpFmjzt', content=[TextBlock(text="Okay, let's use the relevant tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01Rzp7UdvuVyNPbHMoPiPauA', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#123456', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=303)),
#  ToolsBetaMessage(id='msg_01HNGRAMeMpn5DRjexNJwtvj', content=[TextBlock(text='Okay, let\'s address Samantha\'s requirements for the "pd2023" space at Neptune Technologies:', type='text'), ToolUseBlock(id='toolu_011cFPdmJdidDqgJnattrNak', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#FFFFFF', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2709, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01XQuF6k4as73FdDW5c3f6XD', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01CKk3gTUXHBF8E9H5UY3Qm3', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2682, output_tokens=235)),
#  ToolsBetaMessage(id='msg_01Nr5BXPaWtz7cYBtc1KR59S', content=[TextBlock(text='Okay, let\'s use the relevant ClickUp tools to assist the IT department at Zenith Corp. with their project space audit and clean-up.\n\nFirst, we\'ll retrieve a list of all the spaces in the "it7890" team to get an overview of the current project spaces:', type='text'), ToolUseBlock(id='toolu_018pnAgC7tptRAFhJUMjAA7z', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2641, output_tokens=138)),
#  ToolsBetaMessage(id='msg_01XyZWcpHdTgmmmGpic2XtxW', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for Luxe Apparel's Fall Campaign 2023.", type='text'), ToolUseBlock(id='toolu_01TEEzZP3Wxthnh2MvhJszvi', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2673, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01FAyoqHx5VuGX6Ln3rCvco9', content=[TextBlock(text="Okay, let's address this situation using the ClickUp tools provided:", type='text'), ToolUseBlock(id='toolu_01PNyStWp62kAwSXFYNBHFnv', input={'space_id': 'outreachQ2', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B', 'tag_name': 'OldCampaign'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2665, output_tokens=175)),
#  ToolsBetaMessage(id='msg_013ubKA4eve7ixmRXvrnnXJZ', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Urgent Review" tag in the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_01PdReXDZAXkh6rds6NmJ5da', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2648, output_tokens=162)),
#  ToolsBetaMessage(id='msg_01EKYaLCaqJvqXh1XPxebZvF', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01HL78xQWoDKLf1rSNZ4CaLc', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2646, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01PZ6MmikHgXPC6rvvCQq2MY', content=[TextBlock(text="Okay, let's use the relevant tools to update the OTSpace1 space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01MsjadwGHPE2gdgVwtM81cq', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2725, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01YGmZ3Np7BVBBLDV47WKeUC', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_0165rt8pYVEfZx7tS1TcytR2', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01MD1RpwgEKb2dX5ksC72MhT', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to help TerraFirma with this request.\n\nFirst, we need to retrieve the details of the "TF_ProjectX" space. We can use the ', type='text'), ToolUseBlock(id='toolu_01U8wkj3XuGb8nkgvNUpCeg8', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2644, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01BR8RPPM5aQyKKCfn6eMfr1', content=[TextBlock(text='Okay, let\'s start by retrieving the list of all spaces under the "FI_Team2023" team ID, including both active and archived spaces. We can use the `get_spaces` function for this:', type='text'), ToolUseBlock(id='toolu_01LQfLUqCi9maev59ioPSBk9', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2710, output_tokens=125)),
#  ToolsBetaMessage(id='msg_01EAkiJR9bktxLQsWRvmM9oa', content=[TextBlock(text='Okay, let\'s use the ClickUp API tools to create the new "Design Hub 2023" space for Vera\'s design team at PixelPerfect Studios.', type='text'), ToolUseBlock(id='toolu_01A8yYKdK1LCD9uRZyCC8KzA', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2720, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01XKh8g1A5w5WatZsmNpWgvX', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address Jess's request for the content team's workflow improvement.", type='text'), ToolUseBlock(id='toolu_01AGm6xoHtqkTjpAX9LCpGBt', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2689, output_tokens=154)),
#  ToolsBetaMessage(id='msg_01HGjFnfMXqNQEDHE9T9peJS', content=[TextBlock(text='Okay, let\'s address the requirements from the finance team at Prospera Finances regarding the ClickUp space "PF_Projects":', type='text'), ToolUseBlock(id='toolu_01MT7bNSDqgtGxLPbqs3JP2F', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#0077B6', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2724, output_tokens=318)),
#  ToolsBetaMessage(id='msg_011TjjXBDT8AWDfQnzsYd96e', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_012FSSM8jGqKzZbUjYEEGE5R', input={'space_id': 'GES_InfraDev2022', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'ArchiveThis'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=170)),
#  ToolsBetaMessage(id='msg_014LMuR9xkva4pTbQQxZ8J6M', content=[TextBlock(text='Understood. To delete the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment and workspace optimization initiative, I will use the following tool:', type='text'), ToolUseBlock(id='toolu_01ATMPh2gQFi2u7w544FsKpo', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2668, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01Ae67SXeLLjiG26C5zSyQSC', content=[TextBlock(text='Okay, let\'s use the `get_space_tags` function to retrieve the list of all existing tags in the "Marketing2023" space. Here\'s how we can do it:', type='text'), ToolUseBlock(id='toolu_01Jdcp3g1AR4bnr6YqUA5i1z', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=108)),
#  ToolsBetaMessage(id='msg_01M8fswJK7LJijQPjYv2P7Kz', content=[TextBlock(text='Okay, let\'s address the requirements for the "TI_ProductLaunches" space in the Titan Industries ClickUp workspace:', type='text'), ToolUseBlock(id='toolu_01HNSrAtutzSPTYkccFsDD8o', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2718, output_tokens=322)),
#  ToolsBetaMessage(id='msg_016NDsR3XAVFrryirQcN9Dgz', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01JEAE92YFTCYPPA32mX7o1Q', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2685, output_tokens=74)),
#  ToolsBetaMessage(id='msg_01MmhKU1i6Wi9qboYveia1ks', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to implement the new tagging system for the "DigitalTrans2023" space as requested.', type='text'), ToolUseBlock(id='toolu_01W37BdAmqtNMtbasBhsRmFE', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2713, output_tokens=169)),
#  ToolsBetaMessage(id='msg_01TUnGLDY4iaAkonceChpGu8', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the customer success team as per Lucas' requirements.", type='text'), ToolUseBlock(id='toolu_01YV9eJSsBF2qSBVGGpJ6zwL', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2672, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01AQJuvCzYVhYbuLCTGKzgk2', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01FmKjEQ71d8DX4pwftCLSYn', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=291)),
#  ToolsBetaMessage(id='msg_018oxVaPLRipKEfMGYfd3qyc', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the unused tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_01TL7sgs7ubE6YxaaPh5BBH8', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2660, output_tokens=184)),
#  ToolsBetaMessage(id='msg_01TLkatJS9ZkkXige6ggKP1V', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_012mi5BGfW4pPcu4YRgyvJ4T', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2658, output_tokens=144)),
#  ToolsBetaMessage(id='msg_01YADuu5EeETLctpRkYRhTXk', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_0157HKDcQP6Qt6WEeR1ytnp7', input={'space_id': 'proddev808', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000', 'tag_name': 'BetaFeature'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2651, output_tokens=185)),
#  ToolsBetaMessage(id='msg_01AEBdraM1wM2N6mBGLj7QRz', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01HZ4ouakHWYPKmFuZWS31py', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01PLa2K5oq8yKs4bdbG5itim', content=[TextBlock(text='Okay, based on the given situation, the user needs to retrieve all the information from the ClickUp space dedicated to inventory management. To do this, we can use the ', type='text'), ToolUseBlock(id='toolu_01JU1dGx3RMaEn3KiSn1gUcy', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2617, output_tokens=94)),
#  ToolsBetaMessage(id='msg_01CsRMy1fLHKgAtEMicfEaGV', content=[TextBlock(text='Okay, based on the information provided, it seems the operations team needs to delete the ClickUp space with the ID "eduop876" as it is no longer needed.\n\nTo delete the space, I will use the ', type='text'), ToolUseBlock(id='toolu_01RtzKnbiMaBTf1epF2ktQfJ', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2620, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01Cnn6kSMNto26H9jndp6TJ6', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_018ACV7AnYuzcNT4q2d2tuti', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=236)),
#  ToolsBetaMessage(id='msg_01KKDdFmV4RrjZKSAwKoahdK', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_017R7FYSDstRoWm57SkRVmNo', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2653, output_tokens=302)),
#  ToolsBetaMessage(id='msg_01BFDNn5Vr1zvs6m2wTVySrC', content=[TextBlock(text='Okay, let\'s address Samantha\'s request to update the "Digital Design Team" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01RRT2zwqnjdpWFeJzgQ3XBV', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'features__time_tracking__enabled': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2697, output_tokens=310)),
#  ToolsBetaMessage(id='msg_012oaf3WPduDG1QNfiAfKvUy', content=[TextBlock(text='Okay, based on the information provided, the best tool to use here would be the ', type='text'), ToolUseBlock(id='toolu_01GKjsCY9xz7C7kWJVkwPi6D', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2661, output_tokens=246)),
#  ToolsBetaMessage(id='msg_01LcTQft3pgEZkQEB27c6A7G', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01VJ3d9TWWyPRufysG6unN4z', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01JFZeGbuUFd5Y1pTqCVWne8', content=[TextBlock(text="Okay, let's address this request using the ClickUp tools provided.", type='text'), ToolUseBlock(id='toolu_0127XsXG821k4th8JeUUHue9', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2656, output_tokens=147)),
#  ToolsBetaMessage(id='msg_01FMD1X2MEyTkpxFUuVMTSeG', content=[TextBlock(text='Okay, based on the given situation, the finance team wants to permanently delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the ', type='text'), ToolUseBlock(id='toolu_01YEFT24LUcPHzat6cJTq3K9', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2624, output_tokens=101)),
#  ToolsBetaMessage(id='msg_01WjoqyoH3PFC78uYAUjyK6G', content=[TextBlock(text="Okay, let's handle this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_017jkhUXk8XoHEWsDW2q2dQE', input={'space_id': 'gfxdes678', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'LowPriority'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=172)),
#  ToolsBetaMessage(id='msg_016Xw8xPg4tnT7o64q6us5nt', content=[TextBlock(text='Okay, based on the requirements provided, the best tool to use here is the ', type='text'), ToolUseBlock(id='toolu_01EfzF5r4mzNLVghxAdF5Q3G', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2664, output_tokens=245)),
#  ToolsBetaMessage(id='msg_01JiTasCzZbxTx3TuPEoteke', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_018qGN3AYqhRQpu4kfgypAwb', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=64)),
#  ToolsBetaMessage(id='msg_01WassAC2ruTSDbB7Zvv7CYx', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address this request:", type='text'), ToolUseBlock(id='toolu_01PNmMR3cri5zbu3JcDiV4qZ', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=306)),
#  ToolsBetaMessage(id='msg_01CGLf6d8ti6dsoJAjch8scP', content=[TextBlock(text='Okay, let\'s set up the new "Fall Events 2023" space for the event management team at Occasions Plus.', type='text'), ToolUseBlock(id='toolu_017hbGjuAA13qZNhdQQqoCWd', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2678, output_tokens=256))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'team123'}, 'name': 'get_spaces'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#123456',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#0077B6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.68

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:58<00:00,  2.37s/it]
# [ToolsBetaMessage(id='msg_016UGSCu7wb8mR1PQaTJPVRE', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01JGkTQVguCTag9eQuAF9eof', input={'team_id': 'team123', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=80)),
#  ToolsBetaMessage(id='msg_01Kgyb3XHhUYTZxvtBz1wDnk', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_011hYTL2pMkGEnbLLdR7cMAD', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=235)),
#  ToolsBetaMessage(id='msg_012HxtvvtvLsR8nwr394jPvq', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the custom tags from the "sd456" ClickUp space.', type='text'), ToolUseBlock(id='toolu_01JJ1hSVR3HPFmKR73XSDEAE', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2628, output_tokens=84)),
#  ToolsBetaMessage(id='msg_011opqKtUC3gXvpuSNb9fHXU', content=[TextBlock(text="Okay, let's address this issue step-by-step:", type='text'), ToolUseBlock(id='toolu_017VFuAmazKNGFaX8JQwZMir', input={'space_id': 'prj1122'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2655, output_tokens=75)),
#  ToolsBetaMessage(id='msg_01NBYAS8T4KPU6VJW8uQRYYG', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" based on the information provided.', type='text'), ToolUseBlock(id='toolu_0166HMgHFBXvQyHLi8PJdHX6', input={'space_id': 'qa789', 'tag__name': 'MinorIssue', 'tag__tag_bg': '#FFFFE0', 'tag__tag_fg': '#000000', 'tag_name': 'MinorIssue'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=183)),
#  ToolsBetaMessage(id='msg_011Z9XiNC4QRnyQv7cZEerCc', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_016SN7VKkU1KJjK5ibpLnpP6', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': '#000000', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=292)),
#  ToolsBetaMessage(id='msg_013riF14ZYBXUdUm7Rg9kuHw', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01WbQdtsFNZQH84PtTLEaChs', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2623, output_tokens=63)),
#  ToolsBetaMessage(id='msg_019LPcYm7NpSh5Jc8SA9wiW1', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01GDjQsS6CE4GgTBUeBCpKWL', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=233)),
#  ToolsBetaMessage(id='msg_01LyvfyJPu81rnJsBt8nsCs7', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01H4C7udDRkgMjf1iDhbDZf5', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2618, output_tokens=63)),
#  ToolsBetaMessage(id='msg_01NLT6cg7Aodn9bxRjXxfj9c', content=[TextBlock(text="Okay, let's use the relevant tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01S2w91hGvi5L8YBuSPvnZCo', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#123456', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=303)),
#  ToolsBetaMessage(id='msg_01RF5TPCmpsgkifK7dpwBd6v', content=[TextBlock(text='Okay, let\'s address Samantha\'s requirements for the "pd2023" space at Neptune Technologies:', type='text'), ToolUseBlock(id='toolu_01465z5kKWB1BeZk4V8bh5QS', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#FFFFFF', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2709, output_tokens=313)),
#  ToolsBetaMessage(id='msg_018BQk4rpUXZAXqS8qZaLg3r', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01FTwAwZAC6L8R8QfKMeLsQ5', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2682, output_tokens=235)),
#  ToolsBetaMessage(id='msg_01CSBVzqfq4R2vsbCcg9V4RT', content=[TextBlock(text='Okay, let\'s use the relevant ClickUp tools to assist the IT department at Zenith Corp. with their project space audit and clean-up.\n\nFirst, we\'ll retrieve a list of all the spaces in the "it7890" team to get an overview of the current project spaces:', type='text'), ToolUseBlock(id='toolu_01WoAKSwa6VSNDpMRjXz7br8', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2641, output_tokens=138)),
#  ToolsBetaMessage(id='msg_014zUrbFpgWNkh9GjhkndznA', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for Luxe Apparel's Fall Campaign 2023.", type='text'), ToolUseBlock(id='toolu_01XzBhumHnmRFagc3utEK8TE', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2673, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01SWKiEZLeyieRpmFg93HqzL', content=[TextBlock(text="Okay, let's address this situation using the ClickUp tools provided:", type='text'), ToolUseBlock(id='toolu_01JoWB32v8bG4Ja9DaEsLUvY', input={'space_id': 'outreachQ2', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B', 'tag_name': 'OldCampaign'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2665, output_tokens=175)),
#  ToolsBetaMessage(id='msg_018QYqBnmPN2XXpGfA6ET3e1', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Urgent Review" tag in the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_01WDnd8WNxrHZvh9NZLEBTCZ', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2648, output_tokens=162)),
#  ToolsBetaMessage(id='msg_01XF8SBvA1jQSpHNLREvxs3R', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01S37eqWsNzHBieS5eb2CD7Z', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2646, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01SDwx2kdjB9JqEZAf7Afy7g', content=[TextBlock(text="Okay, let's use the relevant tools to update the OTSpace1 space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01QBpkPWCiZDfULe7hEEQBX5', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2725, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01JtC3QvvkXRyVG75dSwserX', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01LLEwfxBymBzU5X1noG8Xn4', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01BWwLqCT7o3UaB7ATmiWxpn', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to help TerraFirma with this request.\n\nFirst, we need to retrieve the details of the "TF_ProjectX" space. We can use the ', type='text'), ToolUseBlock(id='toolu_01QGHYoGjw1E7sXpgouCgyzS', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2644, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01HpAXzdKGgYDw5ZPAbitPUm', content=[TextBlock(text='Okay, let\'s start by retrieving the list of all spaces under the "FI_Team2023" team ID, including both active and archived spaces. We can use the `get_spaces` function for this:', type='text'), ToolUseBlock(id='toolu_01GGJukEhnnBaKpNLEUjovqd', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2710, output_tokens=125)),
#  ToolsBetaMessage(id='msg_01JYCYfh3nFRRKmXfYNrFLQV', content=[TextBlock(text='Okay, let\'s use the ClickUp API tools to create the new "Design Hub 2023" space for Vera\'s design team at PixelPerfect Studios.', type='text'), ToolUseBlock(id='toolu_019MSBAFvny6SmkwUHYoMRw8', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2720, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01LFHTba9CqQaNrV1NFbg3xw', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address Jess's request for the content team's workflow improvement.", type='text'), ToolUseBlock(id='toolu_014GPDvuNG6F4HhkuELtMy5W', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2689, output_tokens=154)),
#  ToolsBetaMessage(id='msg_01RnavjMQsbK4KXZDHzNKKFd', content=[TextBlock(text='Okay, let\'s address the requirements from the finance team at Prospera Finances regarding the ClickUp space "PF_Projects":', type='text'), ToolUseBlock(id='toolu_01NnHxYBMTK3E76NFYvgwdf1', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#0077B6', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2724, output_tokens=318)),
#  ToolsBetaMessage(id='msg_01XkNvPjtdWpGTLtXhUYcxJ8', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_017Z5nd7UZ29ugFq4Tm4MEKT', input={'space_id': 'GES_InfraDev2022', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'ArchiveThis'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=170)),
#  ToolsBetaMessage(id='msg_01C2rQEPu4Wu6ZuXFZqDhcLF', content=[TextBlock(text='Understood. To delete the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment and workspace optimization initiative, I will use the following tool:', type='text'), ToolUseBlock(id='toolu_01MBBVsYmTjruF5q7q8b6zk1', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2668, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01QkTwYBCPN3zVX68DkpyiwL', content=[TextBlock(text='Okay, let\'s use the `get_space_tags` function to retrieve the list of all existing tags in the "Marketing2023" space. Here\'s how we can do it:', type='text'), ToolUseBlock(id='toolu_018JPFryZNQD63jQ3CLd9zWk', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=108)),
#  ToolsBetaMessage(id='msg_017SoxoKjRQgHs3fw5rXeRuH', content=[TextBlock(text='Okay, let\'s address the requirements for the "TI_ProductLaunches" space in the Titan Industries ClickUp workspace:', type='text'), ToolUseBlock(id='toolu_016y3dRGkRqyUrAeGx8A94DD', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2718, output_tokens=322)),
#  ToolsBetaMessage(id='msg_01DctvFSpiRUiFTyPJZr5rWL', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01UGtjMRj1YuWaSdg1Pn9HhH', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2685, output_tokens=74)),
#  ToolsBetaMessage(id='msg_01DVLgK5VGVgWtNsqMhr7TP2', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to implement the new tagging system for the "DigitalTrans2023" space as requested.', type='text'), ToolUseBlock(id='toolu_01TbskiLKEgr6GCwkGDaCbQE', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2713, output_tokens=169)),
#  ToolsBetaMessage(id='msg_018YvFXFzFG6Hv2deKAiSwYa', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the customer success team as per Lucas' requirements.", type='text'), ToolUseBlock(id='toolu_01JupeZpznmFXzLuQm4HUvMW', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2672, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01GfKu7UtNz3Dirb68LkbSSy', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_011426YiRHQqoWT6vA7ePveN', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=291)),
#  ToolsBetaMessage(id='msg_01H96nbmZvcVhgaGu3Hk7WvU', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the unused tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_01EsVk1UG1gf6Ubp8bQhDuCT', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2660, output_tokens=184)),
#  ToolsBetaMessage(id='msg_01CXDjuhsfgvL5UgYemS6v8C', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01JEKEk9h1MEkF4HcF5kZLCW', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2658, output_tokens=144)),
#  ToolsBetaMessage(id='msg_01KZsXF71zWpPAbyyMSJx9gz', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_01AC3jKHdymLXHtQdcPJrT55', input={'space_id': 'proddev808', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000', 'tag_name': 'BetaFeature'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2651, output_tokens=185)),
#  ToolsBetaMessage(id='msg_01BNRXVhFVE6CyJ6UidtrmNd', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01CqDvgb7j1UTuH5iVwgiMJP', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01NNopSgpsuk5Qy3LrAzHhw4', content=[TextBlock(text='Okay, based on the given situation, the user needs to retrieve all the information from the ClickUp space dedicated to inventory management. To do this, we can use the ', type='text'), ToolUseBlock(id='toolu_01DRQQ6CKMgsskfoSb5YxfLu', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2617, output_tokens=94)),
#  ToolsBetaMessage(id='msg_01CNugmYD5ei9KoubrKCrs5g', content=[TextBlock(text='Okay, based on the information provided, it seems the operations team needs to delete the ClickUp space with the ID "eduop876" as it is no longer needed.\n\nTo delete the space, I will use the ', type='text'), ToolUseBlock(id='toolu_01PAVJ6GZ5bz3VudU2xuN48r', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2620, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01SseASL84xiEd1BEBftBTPA', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01RHnXZVVWAm3dXwciJ9oMmA', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=236)),
#  ToolsBetaMessage(id='msg_01VCPV67qhUcxHjo1c8srXra', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01M8r7yxcvRTAcU7rkaxdyyx', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2653, output_tokens=302)),
#  ToolsBetaMessage(id='msg_015mnSUWCJEtGk8TARUaREQk', content=[TextBlock(text='Okay, let\'s address Samantha\'s request to update the "Digital Design Team" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01N5nqxmofREK7w9FxyB6hHL', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'features__time_tracking__enabled': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2697, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01KdtpAbTsEKwLL1tg4mrsU1', content=[TextBlock(text='Okay, based on the information provided, the best tool to use here would be the ', type='text'), ToolUseBlock(id='toolu_016JwKWUii24i2A1E4yLsyym', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2661, output_tokens=246)),
#  ToolsBetaMessage(id='msg_016BWQK85utTMpThSYUxmN1L', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01TSwb6utr5MvTZu7Agmx7tM', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01LRQtYwtZoFNt9wyqRHyiCB', content=[TextBlock(text="Okay, let's address this request using the ClickUp tools provided.", type='text'), ToolUseBlock(id='toolu_011PfqEWCa7mQ86zXF6FXb92', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2656, output_tokens=147)),
#  ToolsBetaMessage(id='msg_01Q8VjmrRgTMFQ8mMitAFTxA', content=[TextBlock(text='Okay, based on the given situation, the finance team wants to permanently delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the ', type='text'), ToolUseBlock(id='toolu_011iE8XdmjwW3g5hcANHqt5z', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2624, output_tokens=101)),
#  ToolsBetaMessage(id='msg_014uY1bTHMPfwPKEB4C81B4B', content=[TextBlock(text="Okay, let's handle this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_017hxve6e8fUCyMMusa6zrAA', input={'space_id': 'gfxdes678', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'LowPriority'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=172)),
#  ToolsBetaMessage(id='msg_01VFQtJgFUQyvy7FyvSyZMtR', content=[TextBlock(text='Okay, based on the requirements provided, the best tool to use here is the ', type='text'), ToolUseBlock(id='toolu_016dPfWsbr4BnV6yEQvJ3ngh', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2664, output_tokens=245)),
#  ToolsBetaMessage(id='msg_01QqtywxSnBwXQrUwxgFPxtp', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01EJKHEKnbSu8g6zSrtg3Mv7', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=64)),
#  ToolsBetaMessage(id='msg_01QCs6Vyc8BN1rYvDuEcwuMT', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address this request:", type='text'), ToolUseBlock(id='toolu_01HQuoFh4j5yCRdvJaPpMU4p', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=306)),
#  ToolsBetaMessage(id='msg_014s8u2pVVBv9yLKEcMYiyRL', content=[TextBlock(text='Okay, let\'s set up the new "Fall Events 2023" space for the event management team at Occasions Plus.', type='text'), ToolUseBlock(id='toolu_01DGqt7bdfigXFJcbMZxSxCV', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2678, output_tokens=256))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_2 = sum(result_list)/len(result_list)
run_acc_2
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'team123'}, 'name': 'get_spaces'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#123456',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#0077B6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.68

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:52<00:00,  2.25s/it]
# [ToolsBetaMessage(id='msg_01U87sZe6e2cfxoZvvZTHYxP', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01UBg4D2XkWXGkPBMs9GaK9y', input={'team_id': 'team123', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=80)),
#  ToolsBetaMessage(id='msg_0182MarMUye4sHJoCXWhnn6R', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01Ce8y1YNXia9JZ7rtWhGnG2', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=235)),
#  ToolsBetaMessage(id='msg_01BZEGvGV489jrsnXnP8uDAr', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the custom tags from the "sd456" ClickUp space.', type='text'), ToolUseBlock(id='toolu_01F3EvSKbEZmrvkn4hPds9Fa', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2628, output_tokens=84)),
#  ToolsBetaMessage(id='msg_01QRA4788jrcsMpvDu867xkn', content=[TextBlock(text="Okay, let's address this issue step-by-step:", type='text'), ToolUseBlock(id='toolu_01GMLFa8P9m5Y8yHmj9JBhJJ', input={'space_id': 'prj1122'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2655, output_tokens=75)),
#  ToolsBetaMessage(id='msg_01MnDpBhmLgJS4FCHCd8VLrC', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" based on the information provided.', type='text'), ToolUseBlock(id='toolu_01CEFG6cDjj5cXYvTyHLiRL1', input={'space_id': 'qa789', 'tag__name': 'MinorIssue', 'tag__tag_bg': '#FFFFE0', 'tag__tag_fg': '#000000', 'tag_name': 'MinorIssue'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=183)),
#  ToolsBetaMessage(id='msg_01HWLozCLmS6VvPMmLLCPzoj', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_019mC7CXWhCd33i4P4SnhgWW', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': '#000000', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=292)),
#  ToolsBetaMessage(id='msg_017LdQGcv1je5MPJCFHQrcJw', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01DUWP7XNppXRWxnyottkYDN', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2623, output_tokens=63)),
#  ToolsBetaMessage(id='msg_011472nK5YcvdqegziNvzAw6', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01TViYV5ABi2z7dZG1gdjgxw', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2634, output_tokens=233)),
#  ToolsBetaMessage(id='msg_01Lhcjj8wKJ1HLDh6GuQ3xd9', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01WT4CwwAXW9m1XZLBhKFcXa', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2618, output_tokens=63)),
#  ToolsBetaMessage(id='msg_01BoAHB1DkqMq6yZpzm3Zjfv', content=[TextBlock(text="Okay, let's use the relevant tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01PUxhiARPybHQjLQgaGsCcR', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#123456', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=303)),
#  ToolsBetaMessage(id='msg_01CKgQKpWvaERAWAF6jmXCuo', content=[TextBlock(text='Okay, let\'s address Samantha\'s requirements for the "pd2023" space at Neptune Technologies:', type='text'), ToolUseBlock(id='toolu_01TjNC82JA6vJfiHMpNTmoHJ', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#FFFFFF', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2709, output_tokens=313)),
#  ToolsBetaMessage(id='msg_011En6qnupqAn5rBP2pPznxv', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01CviYyX5k4eGAhnRaKE92op', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2682, output_tokens=235)),
#  ToolsBetaMessage(id='msg_018YTGJGYKGHFdZHRx9hS5Mi', content=[TextBlock(text='Okay, let\'s use the relevant ClickUp tools to assist the IT department at Zenith Corp. with their project space audit and clean-up.\n\nFirst, we\'ll retrieve a list of all the spaces in the "it7890" team to get an overview of the current project spaces:', type='text'), ToolUseBlock(id='toolu_01VzpjnhKDWCtqPo4ypaMFVr', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2641, output_tokens=138)),
#  ToolsBetaMessage(id='msg_01N6P9U7svvoM8neMDfXGe7F', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for Luxe Apparel's Fall Campaign 2023.", type='text'), ToolUseBlock(id='toolu_01YS61fAqhp79wjXn9yheaAb', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2673, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01UJSWGUxVEASqfmhL5rQFk7', content=[TextBlock(text="Okay, let's address this situation using the ClickUp tools provided:", type='text'), ToolUseBlock(id='toolu_01SqVdo7yHXHpgb8gDYx9PZW', input={'space_id': 'outreachQ2', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B', 'tag_name': 'OldCampaign'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2665, output_tokens=175)),
#  ToolsBetaMessage(id='msg_0172TsTHSyn8QT3eSy9wQbRx', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Urgent Review" tag in the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_016jwMZfsdeN6wTHiWERjEqu', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2648, output_tokens=162)),
#  ToolsBetaMessage(id='msg_015qjNC444AWZdF2tSdSe41x', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01PTDvJ2NYUSPfqSqoBsjK56', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2646, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01Lign1ab7cfUDiT3hGv7rQw', content=[TextBlock(text="Okay, let's use the relevant tools to update the OTSpace1 space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01C28Nx8jJ1shHzDRp7ChNJP', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2725, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01Gyg31azPFjKGf3g9SrQswV', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_015wo3zebBRfCBpknn92ofnX', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01YY5B2uyZuQ4yz4QAXfK7Mw', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to help TerraFirma with this request.\n\nFirst, we need to retrieve the details of the "TF_ProjectX" space. We can use the ', type='text'), ToolUseBlock(id='toolu_01SUk28RmDXTt5HSgj11tH9W', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2644, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01E9FdXAjiuC872VDMFoaDXe', content=[TextBlock(text='Okay, let\'s start by retrieving the list of all spaces under the "FI_Team2023" team ID, including both active and archived spaces. We can use the `get_spaces` function for this:', type='text'), ToolUseBlock(id='toolu_011r9zqgseNdnan2htw16h4x', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2710, output_tokens=125)),
#  ToolsBetaMessage(id='msg_019rpAqC5GvkeZCJKXyGRq52', content=[TextBlock(text='Okay, let\'s use the ClickUp API tools to create the new "Design Hub 2023" space for Vera\'s design team at PixelPerfect Studios.', type='text'), ToolUseBlock(id='toolu_01LPvVGLTh3Ay5tuKNf6QXqN', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2720, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01YERwAMwvSfEeaneB6j9Xyg', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address Jess's request for the content team's workflow improvement.", type='text'), ToolUseBlock(id='toolu_01WcaR5HhUTVXst3CvjnPjNg', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2689, output_tokens=154)),
#  ToolsBetaMessage(id='msg_01FH3CsAnnPmKdQ1gEhU3u8s', content=[TextBlock(text='Okay, let\'s address the requirements from the finance team at Prospera Finances regarding the ClickUp space "PF_Projects":', type='text'), ToolUseBlock(id='toolu_01QzwVhNPYsERgbroZmiuEWC', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#0077B6', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2724, output_tokens=318)),
#  ToolsBetaMessage(id='msg_01Fx4wGh1haMXUeBdLELMjwg', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_01EuUo8gjkJzBykk99BnQhwi', input={'space_id': 'GES_InfraDev2022', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'ArchiveThis'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=170)),
#  ToolsBetaMessage(id='msg_01SVzcPudFU8hbJdA8Guq6Gm', content=[TextBlock(text='Understood. To delete the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment and workspace optimization initiative, I will use the following tool:', type='text'), ToolUseBlock(id='toolu_017dvr6B3JQG3KjXK35RBfaH', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2668, output_tokens=104)),
#  ToolsBetaMessage(id='msg_017CeJxwdR5AKbBvnga2vseG', content=[TextBlock(text='Okay, let\'s use the `get_space_tags` function to retrieve the list of all existing tags in the "Marketing2023" space. Here\'s how we can do it:', type='text'), ToolUseBlock(id='toolu_011rSgiqXi1pFC5iY64gkh1w', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2677, output_tokens=108)),
#  ToolsBetaMessage(id='msg_018e8DxMGuCMB4cARgF1VcDc', content=[TextBlock(text='Okay, let\'s address the requirements for the "TI_ProductLaunches" space in the Titan Industries ClickUp workspace:', type='text'), ToolUseBlock(id='toolu_01FRrZyGWHFQdP3Jwxg2vviP', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2718, output_tokens=322)),
#  ToolsBetaMessage(id='msg_01DfVSy2cJxuErYwYQaT7ks8', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01QDEEELE9shg7xSocM2rY2o', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2685, output_tokens=74)),
#  ToolsBetaMessage(id='msg_011Gxffa7rmtfSAk2UsvNAfZ', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to implement the new tagging system for the "DigitalTrans2023" space as requested.', type='text'), ToolUseBlock(id='toolu_01WvKzbThkJqc3V2PuxFNjNj', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2713, output_tokens=169)),
#  ToolsBetaMessage(id='msg_014K7eC2MDguRx1bstgBwifi', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the customer success team as per Lucas' requirements.", type='text'), ToolUseBlock(id='toolu_01XQdALNZTG4eJuNH7xYv4Df', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2672, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01ArDeEXwqK9cVSYxeyJeNid', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01BNx1Tc7gEDtBaHoa1R7ZgP', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=291)),
#  ToolsBetaMessage(id='msg_01HHrj52zRHLZUVCqLg4DpEP', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the unused tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_01NJUsvSArc9paiyzY6rCynr', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2660, output_tokens=184)),
#  ToolsBetaMessage(id='msg_01UvMrNLrF5Qo4oiuUjm9HAo', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01PmGyvbMt5tFVGtZv6GGRjX', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2658, output_tokens=144)),
#  ToolsBetaMessage(id='msg_01NyC4ntfLYbm7Tfv8csvCjV', content=[TextBlock(text='Okay, let\'s use the ClickUp API to delete the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_017DPAnWRuDDphFiC8WDAcGD', input={'space_id': 'proddev808', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000', 'tag_name': 'BetaFeature'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2651, output_tokens=185)),
#  ToolsBetaMessage(id='msg_01AFenawekqFGwDzGDBdKer3', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01UpCJHkP4R39TyiP2Gj8PZ7', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2650, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01XUzBEzwRMGDyc53rpWRHt8', content=[TextBlock(text='Okay, based on the given situation, the user needs to retrieve all the information from the ClickUp space dedicated to inventory management. To do this, we can use the ', type='text'), ToolUseBlock(id='toolu_01WodUXMQfYFQ8UxkSpHn1zH', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2617, output_tokens=94)),
#  ToolsBetaMessage(id='msg_01TuUU3VuX1Aszbwku4Htqio', content=[TextBlock(text='Okay, based on the information provided, it seems the operations team needs to delete the ClickUp space with the ID "eduop876" as it is no longer needed.\n\nTo delete the space, I will use the ', type='text'), ToolUseBlock(id='toolu_01YXeB9jdCtkpMPMzxaarA48', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2620, output_tokens=104)),
#  ToolsBetaMessage(id='msg_018ECJj33SDfJV824ojPBAoo', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01MdTkYtNtLV1X1U4v86G3eN', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2654, output_tokens=236)),
#  ToolsBetaMessage(id='msg_01EsWhXti3bVFeB79nBpCg3T', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01BbUffc9xHKExQsKS4QKDNo', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2653, output_tokens=302)),
#  ToolsBetaMessage(id='msg_01NZtoeDpxY8RLzedpV5kVvF', content=[TextBlock(text='Okay, let\'s address Samantha\'s request to update the "Digital Design Team" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01FZibc3WXEjGdcQDqvJCubL', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'features__time_tracking__enabled': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'multiple_assignees': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2697, output_tokens=310)),
#  ToolsBetaMessage(id='msg_015GttEx4S7tWX4NDjrWxZ3A', content=[TextBlock(text='Okay, based on the information provided, the best tool to use here would be the ', type='text'), ToolUseBlock(id='toolu_015EuT9Fd5fFKVFSMA1SscDy', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2661, output_tokens=246)),
#  ToolsBetaMessage(id='msg_01PHoqAeduQssrKNNxYyFcoV', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01XpVdVvepUUcbfaZnhaE9Qw', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2643, output_tokens=66)),
#  ToolsBetaMessage(id='msg_01SGsLaDA7j7votYa8sSDZi5', content=[TextBlock(text="Okay, let's address this request using the ClickUp tools provided.", type='text'), ToolUseBlock(id='toolu_01CWGxQTAaLmz4NxqDXfbHDG', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2656, output_tokens=147)),
#  ToolsBetaMessage(id='msg_016FfvReusu5wqaGD6nMcWT8', content=[TextBlock(text='Okay, based on the given situation, the finance team wants to permanently delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the ', type='text'), ToolUseBlock(id='toolu_01A3SPCzi7KqDp21aj6snN7n', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2624, output_tokens=101)),
#  ToolsBetaMessage(id='msg_01FteDN7c5GJtBUH9gYTvTo4', content=[TextBlock(text="Okay, let's handle this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_01A3hNDBf2ZjG7WUCNHeHpes', input={'space_id': 'gfxdes678', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF', 'tag_name': 'LowPriority'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=172)),
#  ToolsBetaMessage(id='msg_01JWvHYffBPirPMo8tYGXz3W', content=[TextBlock(text='Okay, based on the requirements provided, the best tool to use here is the ', type='text'), ToolUseBlock(id='toolu_018G3t9XJyeeUDU9MZhZXxDz', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2664, output_tokens=245)),
#  ToolsBetaMessage(id='msg_01WkNLa5X3nkjoTtq7ZnyHT2', content=[TextBlock(text="Okay, let's use the ", type='text'), ToolUseBlock(id='toolu_01PgKN6qy2Nt8P2u9guSR2eY', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2640, output_tokens=64)),
#  ToolsBetaMessage(id='msg_01CMRqaYbGRMpQ8gTzcDrnJV', content=[TextBlock(text="Okay, let's use the relevant ClickUp tools to address this request:", type='text'), ToolUseBlock(id='toolu_011c524BuA2LPeHPpUhtfT6j', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2663, output_tokens=306)),
#  ToolsBetaMessage(id='msg_015j2bQPpRfWPZfB5PyP3iSM', content=[TextBlock(text='Okay, let\'s set up the new "Fall Events 2023" space for the event management team at Occasions Plus.', type='text'), ToolUseBlock(id='toolu_01RrP8GTDzRZbSnXRPPYiNAo', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2678, output_tokens=256))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_3 = sum(result_list)/len(result_list)
run_acc_3
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'team123'}, 'name': 'get_spaces'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#123456',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#0077B6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.68

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary + \nFunction and Parameter Descriptions Optimized + Function Parameter examples added : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
print(f"Run 2: {run_acc_2}")
print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary +
# Function and Parameter Descriptions Optimized + Function Parameter examples added : Accuracy
# =========================================
# Run 1: 0.68
# Run 2: 0.68
# Run 3: 0.68

# %% [markdown]
# | Approach | Run 1 | Run 2  | Run 3  | Average Accuracy  |
# |---|---|---|---|---|
# | No System Prompt  | 0.36  | 0.36  | 0.36  | 0.36  |
# | Flattening Schema  | 0.54  | 0.5  | 0.54  | 0.527  |
# | Flattened Schema + <br>Simple System Prompt  | 0.56  | 0.56  | 0.54  | 0.553  |
# | Flattened Schema + <br>Focused System Prompt  | 0.64  | 0.64  | 0.62  | 0.633  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary  | 0.64  | 0.62  | 0.66  | 0.64  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function Name Optimized  | 0.72  | 0.72  | 0.66  | 0.70  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function Description Optimized  |  0.68  | 0.7  | 0.68  | 0.687  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized  | 0.78  | 0.76  | 0.76  | 0.767  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized + <br>Function Call examples added  | 0.72  | 0.7  | 0.66  | 0.693  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized + <br>Function Parameter examples added  | 0.82  | 0.76  | 0.78  | 0.787  |
