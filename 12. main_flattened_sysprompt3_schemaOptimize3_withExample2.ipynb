# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

schema_funcs_param = {}

for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
    single_func_param = {}
    for sck, scv in sc["parameters"]["properties"].items():
        single_func_param[sck] = scv['description']
    schema_funcs_param[sc["name"]] = single_func_param

pprint(schema_funcs_param)  # print(f"\t{sck} - {scv['description']}")
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.
# {'create_space': {'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The name of the new space__',
#                   'team_id': 'The ID of the team__'},
#  'create_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to create__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to create__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to create__'},
#  'delete_space': {'space_id': 'The ID of the space__'},
#  'delete_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to delete__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag_name': 'The name of the tag to delete__'},
#  'get_space': {'space_id': 'The ID of the space__'},
#  'get_space_tags': {'space_id': 'The ID of the space__'},
#  'get_spaces': {'archived': 'A flag to decide whether to include archived '
#                             'spaces or not__',
#                 'team_id': 'The ID of the team__'},
#  'update_space': {'admin_can_manage': 'A flag to determine if the '
#                                       'administrator can manage the space or '
#                                       'not__',
#                   'color': 'The color used for the space__',
#                   'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The new name of the space__',
#                   'private': 'A flag to determine if the space is private or '
#                              'not__',
#                   'space_id': 'The ID of the space__'}}

# %%
schema_func_decription_dict = {
    "get_spaces": "Retrives information of all the spaces available in user's Clickup Workspace.",
    "create_space": "Creates a new ClickUp space",
    "get_space": "Retrives information of a specific Clickup space",
    "update_space": "Modifies name, settings the Space color, and assignee management Space.",
    "delete_space": "Delete an existing space from user's ClickUp Workspace",
    "get_space_tags": "Retrives all the Tags assigned on all the tasks in a Space.",
    "create_space_tag": "Assigns a customized Tag in a ClickUp Space.",
    "delete_space_tag": "Deletes a specific tag previously assigned in a space.",
}

schema_func_params_dict = {
    'create_space': {
        'features__due_dates__enabled': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
        'name': 'The name of the new space to create \nExample:  \'NewWorkspace\', \'TempWorkspace\'',
        'team_id': 'The ID of the team \nExample:  \'abc123\', \'def456\' '
        },
    'create_space_tag': {
        'space_id': 'The ID of the space \nExample:  \'abc123\', \'def456\'',
        'tag__name': 'The name of the tag to assign \nExample:  \'NewTag\', \'TempTag\'',
        'tag__tag_bg': 'The background color of the tag to assign \nExample:  \'#FF0000\', \'#00FF00\'',
        'tag__tag_fg': 'The foreground(text) color of the tag to assign \nExample:  \'#FF0000\', \'#00FF00\''
        },
    'delete_space': {
        'space_id': 'The ID of the space to delete \nExample:  \'abc123\', \'def456\''
        },
    'delete_space_tag': {
        'space_id': 'The ID of the space to delete \nExample:  \'abc123\', \'def456\'',
        'tag__name': 'The name of the tag to delete \nExample:  \'NewTag\', \'TempTag\'',
        'tag__tag_bg': 'The background color of the tag to delete \nExample:  \'#FF0000\', \'#00FF00\', \'#0000FF\'',
        'tag__tag_fg': 'The foreground color of the tag to delete \nExample:  \'#FF0000\', \'#00FF00\', \'#0000FF\'',
        'tag_name': 'The name of the tag to delete \nExample:  \'NewTag\', \'TempTag\''
        },
    'get_space': {
        'space_id': 'The ID of the space to retrieve details \nExample:  \'abc123\', \'def456\''
        },
    'get_space_tags': {
        'space_id': 'The ID of the space to retrieve all the tags from \nExample:  \'abc123\', \'def456\''
        },
    'get_spaces': {
        'archived': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
        'team_id': 'The ID of the team \nExample:  \'abc123\', \'def456\''
        },
    'update_space': {
        'admin_can_manage': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
        'color': 'The color used for the space \nExample:  \'#FF0000\', \'#00FF00\'',
        'features__due_dates__enabled': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
        'name': 'The new name of the space \nExample:  \'NewWorkspace\', \'TempWorkspace\'',
        'private': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
        'space_id': 'The ID of the space to update \nExample:  \'abc123\', \'def456\''
        }
        }
    
optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["description"] = schema_func_decription_dict[temp_dict["name"]]
    for func_param_name, func_param_description in schema_func_params_dict[temp_dict["name"]].items():
        sc["parameters"]["properties"][func_param_name]["description"] = func_param_description
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized3_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Creates a new ClickUp space',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The name of the new space to create \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456' ",
#      'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Retrives information of a specific Clickup space',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to retrieve details \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'color': {'description': "The color used for the space \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The new name of the space \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': "The ID of the space to update \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': "Delete an existing space from user's ClickUp Workspace",
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to retrieve all the tags from \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to assign \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground(text) color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Deletes a specific tag previously assigned in a space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag_name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in optimized_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'input_schema': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'name': 'create_space',
#   'description': 'Creates a new ClickUp space',
#   'input_schema': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. \nExample: True, False \nDefault: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample: True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample: True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The name of the new space to create \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'team_id': {'description': "The ID of the team \nExample:  'abc123', 'def456' ",
#      'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'get_space',
#   'description': 'Retrives information of a specific Clickup space',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to retrieve details \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'update_space',
#   'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'input_schema': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'color': {'description': "The color used for the space \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. \nExample:  True, False \nDefault: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space \nExample:  True, False. Default: True',
#      'type': 'boolean'},
#     'name': {'description': "The new name of the space \nExample:  'NewWorkspace', 'TempWorkspace'",
#      'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not \nExample:  True, False. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': "The ID of the space to update \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'delete_space',
#   'description': "Delete an existing space from user's ClickUp Workspace",
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'get_space_tags',
#   'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to retrieve all the tags from \nExample:  'abc123', 'def456'",
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'create_space_tag',
#   'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to assign \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground(text) color of the tag to assign \nExample:  '#FF0000', '#00FF00'",
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'name': 'delete_space_tag',
#   'description': 'Deletes a specific tag previously assigned in a space.',
#   'input_schema': {'properties': {'space_id': {'description': "The ID of the space to delete \nExample:  'abc123', 'def456'",
#      'type': 'string'},
#     'tag__name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'},
#     'tag__tag_bg': {'description': "The background color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag__tag_fg': {'description': "The foreground color of the tag to delete \nExample:  '#FF0000', '#00FF00', '#0000FF'",
#      'type': 'string'},
#     'tag_name': {'description': "The name of the tag to delete \nExample:  'NewTag', 'TempTag'",
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
import anthropic
client = anthropic.Anthropic()


tool_trailer = "\n".join([f'{sc["name"]} - {sc["description"]}' for sc in flattened_schema])

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system =  f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

The Functions provided to you are:
{tool_trailer}

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response
# Out:
# ToolsBetaMessage(id='msg_01Bbgq7b57o3UMzkhcuMFmQY', content=[TextBlock(text='To set up the new project space "Innovative Campaigns 2023" for the "Creative Minds" team with the given requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01F7rJeNyYoU1PmgqM4VSZSF', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2535, output_tokens=273))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
        
llm_output
# Out:
# 100%|██████████| 50/50 [03:42<00:00,  4.45s/it]
# [ToolsBetaMessage(id='msg_01LZUknES35pso4ejEHb3i6g', content=[TextBlock(text='To view all the active spaces under the "Innovative Solutions" team with the team ID "team123", you can use the `get_spaces` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01Wo2Q5Cbbt8pHvgpGLx53y8', input={'team_id': 'team123', 'archived': 'False'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2529, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01JnmRaBCpS1ENcQt8Bn25zQ', content=[TextBlock(text='To set up the new project space "Innovative Campaigns 2023" for the "Creative Minds" team with the given requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01Lo2nAiqpMaiZDeJ9BNkWMe', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2535, output_tokens=273)),
#  ToolsBetaMessage(id='msg_016FLsR9LXW8qaDb4c7bZQ6w', content=[TextBlock(text='To retrieve the list of custom tags created in the ClickUp space with ID "sd456", you can use the `get_space_tags` tool. Here\'s how you can invoke it:', type='text'), ToolUseBlock(id='toolu_012kgK3pfJ3Kv8nVT2xAViTv', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2523, output_tokens=100)),
#  ToolsBetaMessage(id='msg_01677w4sXpyTwSGuD7236zTt', content=[TextBlock(text='To update the tag in the ClickUp space "prj1122" with the new name "Critical Bug" and colors, we can use the `delete_space_tag` and `create_space_tag` tools.\n\nFirst, let\'s delete the existing "CriticalIssue" tag:', type='text'), ToolUseBlock(id='toolu_017iwiyCAz4CFj1Jj7i4nAx9', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FF0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2550, output_tokens=236)),
#  ToolsBetaMessage(id='msg_018DpGh8s4ecNfLDLJMXp5UV', content=[TextBlock(text='To delete the "MinorIssue" tag from the space with ID "qa789", we can use the `delete_space_tag` function with the following parameters:', type='text'), ToolUseBlock(id='toolu_015gUgEvSX2bUKpo2r22Pydi', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_bg': '#FFFFE0', 'tag__tag_fg': '#000000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2538, output_tokens=190)),
#  ToolsBetaMessage(id='msg_01R3ao644s3ZJGJjmvdJru4G', content=[TextBlock(text='To update the "Backend_Development_Space" (space ID "bkend345") and disable multiple assignees while keeping other settings unchanged, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_013VHKakzPSRu8dK9hbP5xM4', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': '#000000', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'True', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2549, output_tokens=331)),
#  ToolsBetaMessage(id='msg_014dEz4xKXkJTvh3T8JWdWC1', content=[TextBlock(text='To delete the unused ClickUp space with the ID "gt678", we can utilize the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_017eaXG3LYynJomUCXbQpFHp', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2518, output_tokens=91)),
#  ToolsBetaMessage(id='msg_01Fcke5BNF4Sesxpcy1yE2ME', content=[TextBlock(text='To create a new space named "Design Studio 2023" with the specified settings for the team with ID "ds101", we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_012Xvz34uwK197Bo25R53pj7', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2529, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01GbkJ5LMdtScN7MX3LQBTrq', content=[TextBlock(text='To retrieve the details of the space with ID "ep456", we can use the "get_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01XqRUks3HgJZWkSmpYa6h2k', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2513, output_tokens=89)),
#  ToolsBetaMessage(id='msg_016eSAJAxjrJeDQ34qoVjTS5', content=[TextBlock(text="To address the operations team's request, we can utilize the `update_space` tool. Here's how we can invoke it with the required parameters:", type='text'), ToolUseBlock(id='toolu_01ARNkFk5tf8SqhbqYLfNAZw', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#0000FF', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2545, output_tokens=317)),
#  ToolsBetaMessage(id='msg_012bXEMsPdyak5vpxBuK9mfg', content=[TextBlock(text="To address Samantha's requirements, we can utilize the `update_space` tool. Here's how we can invoke it with the appropriate parameters:", type='text'), ToolUseBlock(id='toolu_01AgSTqoEdVNF2WQS6636j3T', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#FFFFFF', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'True', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2604, output_tokens=321)),
#  ToolsBetaMessage(id='msg_01FACSiCDCv9yGnwxThTjikp', content=[TextBlock(text='To create a new space in ClickUp for the events management team at Glorious Events Inc., we can utilize the "create_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01SE9gHjTqf2rzHYB51tgaTt', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2577, output_tokens=265)),
#  ToolsBetaMessage(id='msg_01S3xhimUmHW27pg9S2Hu9uo', content=[TextBlock(text="To assist the IT department at Zenith Corp. in auditing their project spaces in ClickUp, we can utilize the `get_spaces` tool to retrieve a list of all spaces, including archived ones. Here's how we can invoke the tool:", type='text'), ToolUseBlock(id='toolu_013YNgTsSe8qMCEHMJ7zsSQn', input={'team_id': 'it7890', 'archived': 'True'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2536, output_tokens=128)),
#  ToolsBetaMessage(id='msg_01Ri5qvedrJ8QDGSeMtRx2XN', content=[TextBlock(text='To create a new ClickUp space for the "Fall Campaign 2023" with the specified requirements, we can utilize the "create_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01JCzmUzTYTUBUwFiBWww7qn', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2568, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01D2ActhsYSEDXKZnat6fjbx', content=[TextBlock(text='To delete the "OldCampaign" tag from the "outreachQ2" space in ClickUp, we can use the `delete_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01FnbswVMaSQGUq52Bn5miPd', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2560, output_tokens=203)),
#  ToolsBetaMessage(id='msg_01W9XtmaqVkkm6E3FJydttZh', content=[TextBlock(text='To add the new "Urgent Review" tag to the "FTProjects" space in ClickUp, we can use the `create_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01EqhV3KqWZovvcTDffqMsFT', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2543, output_tokens=170)),
#  ToolsBetaMessage(id='msg_01FgtPt5rUeHZzXSftxnpK9A', content=[TextBlock(text="To address Crystal's requirements, we can utilize the `update_space` tool. Let's gather the necessary information to fill in the parameters:", type='text'), ToolUseBlock(id='toolu_01VsepHFSLCQNNp9tX2NEaBN', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2541, output_tokens=316)),
#  ToolsBetaMessage(id='msg_0147tkL2n4VtGsAT3QSVSD9v', content=[TextBlock(text="To address the requirements, we can utilize the `update_space` tool. Here's how we can invoke it with the necessary parameters:", type='text'), ToolUseBlock(id='toolu_01DFWkHzzx3AvcT6JYiTPiRe', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2620, output_tokens=315)),
#  ToolsBetaMessage(id='msg_01QNMDyESrx22qQsqeodjMTg', content=[TextBlock(text='To retrieve all the tags assigned on tasks within the "DSAnalysis" ClickUp space, you can utilize the `get_space_tags` tool. Here\'s how you can invoke it:', type='text'), ToolUseBlock(id='toolu_01HxHfuwdPs23UawDDQL47vk', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2535, output_tokens=101)),
#  ToolsBetaMessage(id='msg_019ntrRP3m2eCUdVg1tT1KxP', content=[TextBlock(text='To assist TerraFirma with getting an overview of the "TF_ProjectX" space before phasing it out, we can utilize the following ClickUp tools:', type='text'), ToolUseBlock(id='toolu_01CCJbv4WKuyZBH8nZYvYPSg', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2539, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01JkZJu9n8H3FVd2WLgLXPDz', content=[TextBlock(text='To gather a comprehensive list of all active and archived spaces under the team ID "FI_Team2023", we can utilize the "get_spaces" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01U6WukyCTS5ZSw4sSWDtZQM', input={'team_id': 'FI_Team2023', 'archived': 'True'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2605, output_tokens=120)),
#  ToolsBetaMessage(id='msg_01CPp7HJn2q8FY4n9wwqQc1r', content=[TextBlock(text='To create the new "Design Hub 2023" space with the specified requirements, we can utilize the `create_space` tool. Here\'s how we can invoke it with the appropriate parameters:', type='text'), ToolUseBlock(id='toolu_013imMfLN9aQK6VsnDEF2TbV', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2615, output_tokens=269)),
#  ToolsBetaMessage(id='msg_01UkMmk4C83n8jUSuNrgBA4N', content=[TextBlock(text='To assist Jess with creating a new tag named "Priority" with the specified background and text colors in the "WF_Content" ClickUp space, we can utilize the `create_space_tag` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_012a3NfBoSyxtkCdL2J3C592', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2584, output_tokens=182)),
#  ToolsBetaMessage(id='msg_018rUojCwqDZzariA8RK96tk', content=[TextBlock(text="To address the requirements from the finance team at Prospera Finances, we can utilize the `update_space` tool. Here's how we can invoke it with the necessary parameters:", type='text'), ToolUseBlock(id='toolu_01GPfTnYwb2mVzcUMdWYvwZd', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#0072C6', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2619, output_tokens=326)),
#  ToolsBetaMessage(id='msg_011WWXo8tmZLExJ3aXfGDBW5', content=[TextBlock(text='To delete the obsolete tag "ArchiveThis" from the "GES_InfraDev2022" space, we can utilize the "delete_space_tag" function. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01RFDMLErjNdxAFGLXJTLVQa', input={'space_id': 'GES_InfraDev2022', 'tag_name': 'ArchiveThis', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2572, output_tokens=206)),
#  ToolsBetaMessage(id='msg_01V1Sbhh9saEzq45sMqL2dPe', content=[TextBlock(text='To delete the "NGS_EarlyConcepts" space from your ClickUp workspace, we can utilize the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01LPUmGi6B4csCcwFamG3xpo', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2563, output_tokens=103)),
#  ToolsBetaMessage(id='msg_01Vkpg9C8YYKqQt3ynLRruoZ', content=[TextBlock(text='To retrieve a list of all existing tags within the "Marketing2023" space, we can utilize the `get_space_tags` tool. Let\'s invoke it with the required parameter:', type='text'), ToolUseBlock(id='toolu_01UV3dGxQMquZTLhCuHyv55c', input={'space_id': 'Marketing2023'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2572, output_tokens=99)),
#  ToolsBetaMessage(id='msg_012yHS6r8y4HioKinh1ReXFm', content=[TextBlock(text='To address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace, we can utilize the `update_space` tool. Here\'s how we can invoke it with the appropriate parameters:', type='text'), ToolUseBlock(id='toolu_011akYu5seUYKsKEH3sx4Ns1', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2613, output_tokens=339)),
#  ToolsBetaMessage(id='msg_01Kq6Wga2XKvsvdCmJhH3ykH', content=[TextBlock(text='To retrieve detailed information about the space "CS_ProjectSpace1", we can utilize the `get_space` tool. This tool allows us to fetch comprehensive details about a specific space within the ClickUp workspace.', type='text'), ToolUseBlock(id='toolu_01DdGDsYcRWvngZGG5JjSztX', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2580, output_tokens=104)),
#  ToolsBetaMessage(id='msg_017KWpL8aGaKHaLMnUCxtYhZ', content=[TextBlock(text='To create the "MilestoneCritical" tag with the specified background color "#00008B" and foreground (text) color "#FFFFFF" in the "DigitalTrans2023" space, we can utilize the following tool:', type='text'), ToolUseBlock(id='toolu_01Ax6eoA8GE53jpUZcq7CPsf', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2608, output_tokens=190)),
#  ToolsBetaMessage(id='msg_01HHQBdY5rF2hL8d3p1BemXY', content=[TextBlock(text="To create a new space for the customer success team with the given requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01MHwXQufMK8EgLfz1ceWzub', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2567, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01J3qawq3TRe5cJyKwfmH5X5', content=[TextBlock(text='To update the existing ClickUp space with ID "social123" to reflect the new branding color and name, while ensuring only admins can manage it, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_018mDNNeR6vBDaNanLDroSxG', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2558, output_tokens=333)),
#  ToolsBetaMessage(id='msg_01NvBZavac51v1sfiwcZfVs5', content=[TextBlock(text='To delete the unused "OldCampaign" tag from the "branddept301" ClickUp space, we can utilize the `delete_space_tag` function with the following parameters:', type='text'), ToolUseBlock(id='toolu_01RKKqdyUwZNCPPKk6U9w1Ea', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2555, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01FdurFFpJsaDd4VrQQUczJF', content=[TextBlock(text='To create a new tag called "Time-Sensitive" with the specified colors in the ClickUp space "engteam777", we can use the `create_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01SKtxz3J4FYgD6v6eC7eQ84', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2553, output_tokens=175)),
#  ToolsBetaMessage(id='msg_01G3dMgvaDfmoRGWXTiaEFND', content=[TextBlock(text='To delete the "BetaFeature" tag from the "proddev808" space, we can use the `delete_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01ShkBooP36v6NBQR5CaH8dk', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2546, output_tokens=191)),
#  ToolsBetaMessage(id='msg_01D227qZiHwvrAcEQjKHrek2', content=[TextBlock(text='To create the "Employee Relations" space for the HR department with the specified requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01TujDbFWemwRUMmHxCmH8E9', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'private': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2545, output_tokens=275)),
#  ToolsBetaMessage(id='msg_01Dn5JT4Rowi12zbBNLv4sGe', content=[TextBlock(text="To retrieve all the information from the ClickUp space dedicated to inventory management, we can use the `get_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_014AjinSwN32CVLCtt42CmD4', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2512, output_tokens=94)),
#  ToolsBetaMessage(id='msg_0172fF1LxmZTJMGDXytdkFKC', content=[TextBlock(text='To delete the unnecessary ClickUp space with the ID "eduop876", we can use the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_015WJbqSRuPvhm9igivLfqkm', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2515, output_tokens=93)),
#  ToolsBetaMessage(id='msg_012NP1G9GZoGogNdEbtmsPyL', content=[TextBlock(text="To set up the new ClickUp space as per Natalie's requirements, we can use the `create_space` tool with the following parameters:", type='text'), ToolUseBlock(id='toolu_019P7RF1m4wooM2BNZUKWYBL', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2549, output_tokens=262)),
#  ToolsBetaMessage(id='msg_014ExiFhkBN58XnBnTrMNbLC', content=[TextBlock(text='To make the ClickUp space with ID "globalsales400" private, update its color to bright red ("#FF0000"), keep the name as "International Sales Division", and allow only space admins to manage its settings, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_013tMrQXktG5rZFMV1G74ymZ', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2548, output_tokens=349)),
#  ToolsBetaMessage(id='msg_01KShYrmqUHJyt2jMLdbeWBo', content=[TextBlock(text='To address Samantha\'s request, we can utilize the `update_space` tool to modify the existing "Digital Design Team" space according to the new specifications. Here\'s how we can invoke the tool with the required parameters:', type='text'), ToolUseBlock(id='toolu_01BE4hdTyzTCHEXT5cZytbLs', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': 'True', 'admin_can_manage': 'False', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2592, output_tokens=332)),
#  ToolsBetaMessage(id='msg_013YFo3V6SoArWP2hYTQQ4gM', content=[TextBlock(text="To create a new ClickUp space for the content strategy team with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01YQ6jeMcpxxzBeen1m2JQjL', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2556, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01CoXXQ6a687NDJPQw8QCgC8', content=[TextBlock(text='To retrieve the list of tags currently assigned to tasks within the ClickUp space "appdev300", you can utilize the "get_space_tags" tool. Here\'s how you can invoke it:', type='text'), ToolUseBlock(id='toolu_01DKevQkNWS643wRtNUt7jsM', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2538, output_tokens=102)),
#  ToolsBetaMessage(id='msg_01WaAgZkaDAvMorPJSrqxNQh', content=[TextBlock(text='To create a new tag named "Urgent Discrepancy" with the specified colors in the "datamodel404" space, we can use the `create_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_0163GbbMFcSbgYnoLjdL2ePb', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2551, output_tokens=175)),
#  ToolsBetaMessage(id='msg_01D9wZ7p5shhChcsY47eyE9S', content=[TextBlock(text='To delete the "finforecast345" ClickUp space, we can use the `delete_space` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01Ae9qjyPQ1kby1FuFhm1hYf', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2519, output_tokens=92)),
#  ToolsBetaMessage(id='msg_015GQrw29Q26ukekBys8RbEV', content=[TextBlock(text='To delete the "LowPriority" tag from the "gfxdes678" space, we can use the `delete_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01P9dnJCEPi9h8Ur3GDJNqsA', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2558, output_tokens=197)),
#  ToolsBetaMessage(id='msg_01Axr2xTNpwRGtg5QoA42DP2', content=[TextBlock(text='To create the new space for the client support division with the specified requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01ThC68ejj6b5X7CowmMoNKJ', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'True', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2559, output_tokens=259)),
#  ToolsBetaMessage(id='msg_012s2hGE5tvxGSXAf9e6FgLa', content=[TextBlock(text='To retrieve the complete configuration details of the ClickUp space with ID "gamedev909", we can use the "get_space" tool. Here\'s how we would invoke it:', type='text'), ToolUseBlock(id='toolu_01Ph7wD5siohQ3BwdGxByC1a', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2535, output_tokens=96)),
#  ToolsBetaMessage(id='msg_01C7MQL3ZDkhmi4pdS9BmtYy', content=[TextBlock(text='To rename the ClickUp space with the ID "mktoutreach768" to "Market Outreach 2023", set its color to navy blue ("#000080"), and make it private, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01FeTMMWsk9ReNqtVRzGzzrG', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2558, output_tokens=347)),
#  ToolsBetaMessage(id='msg_01EY3sjbcyX4LSK5Xdyidw1Z', content=[TextBlock(text='To set up the "Fall Events 2023" space for the event management team with the specified requirements, we can utilize the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01H3h3uQFvipH3avWEryZRkh', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2573, output_tokens=266))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

def convert_str_to_bool(nested_dict):
    for key, value in nested_dict.items():
        # If the value is a nested dictionary, recursively process it
        if isinstance(value, dict):
            convert_str_to_bool(value)
        else:
            if value == "True":
                nested_dict[key] = True
            elif value == "False":
                nested_dict[key] = False
    return nested_dict
                
# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    llm_response_dict = convert_str_to_bool(llm_response_dict)
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#0072C6',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': False,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.76

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_2 = sum(result_list)/len(result_list)
# run_acc_2

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_3 = sum(result_list)/len(result_list)
# run_acc_3

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary + \nFunction and Parameter Descriptions Optimized + Function Parameter examples added : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
# print(f"Run 2: {run_acc_2}")
# print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary +
# Function and Parameter Descriptions Optimized + Function Parameter examples added : Accuracy
# =========================================
# Run 1: 0.76

# %% [markdown]
# | Approach | Run 1 | Run 2  | Run 3  | Average Accuracy  |
# |---|---|---|---|---|
# | No System Prompt  | 0.36  | 0.36  | 0.36  | 0.36  |
# | Flattening Schema  | 0.54  | 0.5  | 0.54  | 0.527  |
# | Flattened Schema + <br>Simple System Prompt  | 0.56  | 0.56  | 0.54  | 0.553  |
# | Flattened Schema + <br>Focused System Prompt  | 0.64  | 0.64  | 0.62  | 0.633  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary  | 0.64  | 0.62  | 0.66  | 0.64  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function Name Optimized  | 0.72  | 0.72  | 0.66  | 0.70  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function Description Optimized  |  0.68  | 0.7  | 0.68  | 0.687  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized  | 0.78  | 0.76  | 0.76  | 0.767  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized + <br>Function Call examples added  | 0.72  | 0.7  | 0.66  | 0.693  |
# | Flattened Schema + <br>Focused System Prompt containing Schema summary + <br>Function and Parameter Descriptions Optimized + <br>Function Parameter examples added  | 0.82  | 0.76  | 0.78  | 0.787  |
