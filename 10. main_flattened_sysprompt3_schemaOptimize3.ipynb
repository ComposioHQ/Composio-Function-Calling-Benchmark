# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

schema_funcs_param = {}

for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
    single_func_param = {}
    for sck, scv in sc["parameters"]["properties"].items():
        single_func_param[sck] = scv['description']
    schema_funcs_param[sc["name"]] = single_func_param

pprint(schema_funcs_param)  # print(f"\t{sck} - {scv['description']}")
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.
# {'create_space': {'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The name of the new space__',
#                   'team_id': 'The ID of the team__'},
#  'create_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to create__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to create__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to create__'},
#  'delete_space': {'space_id': 'The ID of the space__'},
#  'delete_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to delete__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag_name': 'The name of the tag to delete__'},
#  'get_space': {'space_id': 'The ID of the space__'},
#  'get_space_tags': {'space_id': 'The ID of the space__'},
#  'get_spaces': {'archived': 'A flag to decide whether to include archived '
#                             'spaces or not__',
#                 'team_id': 'The ID of the team__'},
#  'update_space': {'admin_can_manage': 'A flag to determine if the '
#                                       'administrator can manage the space or '
#                                       'not__',
#                   'color': 'The color used for the space__',
#                   'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The new name of the space__',
#                   'private': 'A flag to determine if the space is private or '
#                              'not__',
#                   'space_id': 'The ID of the space__'}}

# %%
schema_func_decription_dict = {
    "get_spaces": "Retrives information of all the spaces available in user's Clickup Workspace.",
    "create_space": "Creates a new ClickUp space",
    "get_space": "Retrives information of a specific Clickup space",
    "update_space": "Modifies name, settings the Space color, and assignee management Space.",
    "delete_space": "Delete an existing space from user's ClickUp Workspace",
    "get_space_tags": "Retrives all the Tags assigned on all the tasks in a Space.",
    "create_space_tag": "Assigns a customized Tag in a ClickUp Space.",
    "delete_space_tag": "Deletes a specific tag previously assigned in a space.",
}

schema_func_params_dict = {
    'create_space': {
        'features__due_dates__enabled': 'If due date feature is enabled within the space. Default: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. Default: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space. Default: True',
        'name': 'The name of the new space to create',
        'team_id': 'The ID of the team'
        },
    'create_space_tag': {
        'space_id': 'The ID of the space',
        'tag__name': 'The name of the tag to assign',
        'tag__tag_bg': 'The background color of the tag to assign',
        'tag__tag_fg': 'The foreground(text) color of the tag to assign'
        },
    'delete_space': {
        'space_id': 'The ID of the space to delete'
        },
    'delete_space_tag': {
        'space_id': 'The ID of the space',
        'tag__name': 'The name of the tag to delete',
        'tag__tag_bg': 'The background color of the tag to delete',
        'tag__tag_fg': 'The foreground color of the tag to delete',
        'tag_name': 'The name of the tag to delete'
        },
    'get_space': {
        'space_id': 'The ID of the space to retrieve details'
        },
    'get_space_tags': {
        'space_id': 'The ID of the space to retrieve all the tags from'
        },
    'get_spaces': {
        'archived': 'A flag to decide whether to include archived spaces or not. Default: True',
        'team_id': 'The ID of the team'
        },
    'update_space': {
        'admin_can_manage': 'A flag to determine if the administrator can manage the space or not. Default: True',
        'color': 'The color used for the space',
        'features__due_dates__enabled': 'If due date feature is enabled within the space. Default: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. Default: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space. Default: True',
        'name': 'The new name of the space',
        'private': 'A flag to determine if the space is private or not. Default: False',
        'space_id': 'The ID of the space'
        }
        }
    
optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["description"] = schema_func_decription_dict[temp_dict["name"]]
    for func_param_name, func_param_description in schema_func_params_dict[temp_dict["name"]].items():
        sc["parameters"]["properties"][func_param_name]["description"] = func_param_description
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized3_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Creates a new ClickUp space',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space to create',
#      'type': 'string'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Retrives information of a specific Clickup space',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve details',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not. Default: True',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space', 'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': "Delete an existing space from user's ClickUp Workspace",
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to delete',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve all the tags from',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to assign',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to assign',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground(text) color of the tag to assign',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Deletes a specific tag previously assigned in a space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to delete',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to delete',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag to delete',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in optimized_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': "Retrives information of all the spaces available in user's Clickup Workspace.",
#   'input_schema': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'name': 'create_space',
#   'description': 'Creates a new ClickUp space',
#   'input_schema': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space to create',
#      'type': 'string'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'get_space',
#   'description': 'Retrives information of a specific Clickup space',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space to retrieve details',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'update_space',
#   'description': 'Modifies name, settings the Space color, and assignee management Space.',
#   'input_schema': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not. Default: True',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space', 'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'delete_space',
#   'description': "Delete an existing space from user's ClickUp Workspace",
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space to delete',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'get_space_tags',
#   'description': 'Retrives all the Tags assigned on all the tasks in a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space to retrieve all the tags from',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'create_space_tag',
#   'description': 'Assigns a customized Tag in a ClickUp Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to assign',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to assign',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground(text) color of the tag to assign',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'name': 'delete_space_tag',
#   'description': 'Deletes a specific tag previously assigned in a space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to delete',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to delete',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag to delete',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
import anthropic
client = anthropic.Anthropic()


tool_trailer = "\n".join([f'{sc["name"]} - {sc["description"]}' for sc in optimized_schema])

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system =  f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

The Functions provided to you are:
{tool_trailer}

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response
# Out:
# ToolsBetaMessage(id='msg_015TbEru7VZ81DfyT34Fnghf', content=[TextBlock(text='To set up the new project space in ClickUp for the "Creative Minds" team, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_018hYJudAWNEiehXbTa9gZzs', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=264))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
        
llm_output
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [03:34<00:00,  4.29s/it]
# [ToolsBetaMessage(id='msg_01QBWpEcopNnzR5sm5SqrMNB', content=[TextBlock(text='To retrieve information about all active spaces under the "Innovative Solutions" team with the team ID "team123", we can use the `get_spaces` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_018FrmwctYNgw1C265K32inP', input={'team_id': 'team123', 'archived': 'False'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2166, output_tokens=112)),
#  ToolsBetaMessage(id='msg_01ShJZUE1FL6UQif7ByvUToT', content=[TextBlock(text='To set up the new project space in ClickUp for the "Creative Minds" team, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01SP84c4VjxzeAkUvNkCiQcD', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01FjYQsi3bvT8QhPoFRkqjio', content=[TextBlock(text='To retrieve the list of custom tags created in the ClickUp space with ID "sd456", we can use the `get_space_tags` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01LWG8L6RtRyKGXw6PmLxuuJ', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2160, output_tokens=100)),
#  ToolsBetaMessage(id='msg_01MgN1T8GvBUaewjjXU2sAXL', content=[TextBlock(text='To update the tag in the ClickUp space "prj1122" with the new name "Critical Bug" and the specified colors, we can use the `delete_space_tag` and `create_space_tag` functions.\n\nFirst, let\'s delete the existing "CriticalIssue" tag:', type='text'), ToolUseBlock(id='toolu_015X1eL7PrntwaJuvSn6KzET', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FF0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2187, output_tokens=224)),
#  ToolsBetaMessage(id='msg_01Pin5Cz4uixd2QfUDXZBngX', content=[TextBlock(text='To remove the "MinorIssue" tag from the space with ID "qa789", we can use the `delete_space_tag` function. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01UhYy8UQw8DfFTtah92pxRm', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2175, output_tokens=194)),
#  ToolsBetaMessage(id='msg_01Tsyri29UegVbaEEMFfkzkW', content=[TextBlock(text='To update the "Backend_Development_Space" space (ID: bkend345) and disable multiple assignees while keeping other settings unchanged, we can use the `update_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01AUUgXpc724nLvrhCGnYgWX', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': '#000000', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2186, output_tokens=331)),
#  ToolsBetaMessage(id='msg_01KToSC2LXRHg4hZqv9awnEc', content=[TextBlock(text='To delete the unused ClickUp space with the ID "gt678", we can utilize the "delete_space" tool. Let\'s invoke it with the required parameter:', type='text'), ToolUseBlock(id='toolu_015dAeRo2DfASTURx52qSEW1', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2155, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01QhwsCAzFyvjSB75CMZmPSZ', content=[TextBlock(text="To create a new space in ClickUp with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01Ex1JDdhc39vfjvF1kwctfU', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2166, output_tokens=260)),
#  ToolsBetaMessage(id='msg_01URuBf76tQYndLwATGxjWSN', content=[TextBlock(text='To retrieve the details of the space with ID "ep456", we can use the `get_space` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01JyqM7KqV6HEAqkXmWSWCYk', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2150, output_tokens=89)),
#  ToolsBetaMessage(id='msg_018FF4qVtW7PKzCrHewASryL', content=[TextBlock(text='To update the existing ClickUp space "fe987" with the new name "FE Development 2023", make it private, and enable due date and time tracking features, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_014jSxbTyxrx4ctR5o3hnjdo', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#7B68EE', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2182, output_tokens=340)),
#  ToolsBetaMessage(id='msg_013qgAU3K6QPFa9zPJ9YKPDv', content=[TextBlock(text="To address Samantha's requirements, we can utilize the `update_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01SP3Cv2eYvM9c7d9BMWEu4a', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#ffffff', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2241, output_tokens=316)),
#  ToolsBetaMessage(id='msg_01BEgcuNWVKLkV7QBE5wJS6h', content=[TextBlock(text='To create a new ClickUp space for the events management team at Glorious Events Inc., we can utilize the `create_space` function with the following parameters:', type='text'), ToolUseBlock(id='toolu_01UR2DQc1j6BnXVhvxeLdznj', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2214, output_tokens=264)),
#  ToolsBetaMessage(id='msg_017SJoE776kDD8mk1umhCrPA', content=[TextBlock(text='To retrieve information about all spaces (including archived ones) in the ClickUp workspace for the IT team with ID "it7890", we can use the `get_spaces` tool:', type='text'), ToolUseBlock(id='toolu_01GzxJwsL5SuuidBJCQSTRdc', input={'team_id': 'it7890', 'archived': 'True'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2173, output_tokens=114)),
#  ToolsBetaMessage(id='msg_01RdwmB5QtCAT1HAgEYntE4P', content=[TextBlock(text='To create a new ClickUp space for the Fall Campaign 2023 with the specified requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_012myKrpdLajgwkLei7uEgLH', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2205, output_tokens=263)),
#  ToolsBetaMessage(id='msg_01WHqqGCKnGWueR7AgmbDd2A', content=[TextBlock(text='To delete the "OldCampaign" tag from the "outreachQ2" space in ClickUp, we can use the `delete_space_tag` function:', type='text'), ToolUseBlock(id='toolu_01RM66NxMVmvRGra1UmC1Msx', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=199)),
#  ToolsBetaMessage(id='msg_01P5HZt5omxtLacaixbU2Qaj', content=[TextBlock(text='To create the new "Urgent Review" tag in the "FTProjects" space with the specified colors, we can use the `create_space_tag` tool:', type='text'), ToolUseBlock(id='toolu_01LbzzxgwyetF7B2Pf65FLPL', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2180, output_tokens=166)),
#  ToolsBetaMessage(id='msg_013pmL46Z8FYwcYLP81k97HM', content=[TextBlock(text='To enable time tracking and update the theme for the "EMContentPlanning" space, we can use the `update_space` tool. Let\'s gather the required parameters:', type='text'), ToolUseBlock(id='toolu_01Wyxe62XDgWeHdJUUUpyJKN', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2178, output_tokens=323)),
#  ToolsBetaMessage(id='msg_01VALSMxZ8YBsp1iSW55sqKj', content=[TextBlock(text='To update the space with the new name, color, privacy settings, and disable time tracking, we can use the `update_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01Du6rpFbLKQSe2YpU4PGPXG', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2257, output_tokens=321)),
#  ToolsBetaMessage(id='msg_01F85ozTD4eDgUJYie4TwWj4', content=[TextBlock(text='To retrieve all the tags assigned on tasks within the "DSAnalysis" ClickUp space, we can use the `get_space_tags` tool. Let\'s invoke it with the required parameter:', type='text'), ToolUseBlock(id='toolu_01CcXqZ9qcL4a2abuTvqBnCG', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=102)),
#  ToolsBetaMessage(id='msg_01314nD36tVhbhCm9rwRSaP8', content=[TextBlock(text='To assist TerraFirma with getting an overview of the "TF_ProjectX" space before phasing it out, we can use the `get_space` tool to retrieve the space\'s details. Here\'s how we can invoke the tool:', type='text'), ToolUseBlock(id='toolu_01M1bNQXCLb1jiUYm99v9W7o', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2176, output_tokens=114)),
#  ToolsBetaMessage(id='msg_019ptWNGg1eGXEd3kPMq7WAs', content=[TextBlock(text='To retrieve a list of all active and archived spaces under the team ID "FI_Team2023", we can use the "get_spaces" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01MTtz2C5EUrFPswZDgyMzxM', input={'team_id': 'FI_Team2023', 'archived': 'True'}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2242, output_tokens=115)),
#  ToolsBetaMessage(id='msg_01Keucc2qkLt6B8H8WW1DTQx', content=[TextBlock(text='To create the new "Design Hub 2023" space with the specified requirements, we can utilize the `create_space` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01S5y5GjFfXQUTU31Ht9EJAV', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2252, output_tokens=265)),
#  ToolsBetaMessage(id='msg_01WoVaB2pTEjVR3WsroKRR7Q', content=[TextBlock(text='To assist Jess with creating the new "Priority" tag in the "WF_Content" ClickUp space, we can utilize the `create_space_tag` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01CV589iKoD7W2mFCZPx8ZFy', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2221, output_tokens=174)),
#  ToolsBetaMessage(id='msg_01Ecndh6VLCqxKLBSiNi8Tpj', content=[TextBlock(text="To address the finance team's requirements, we can utilize the `update_space` tool. Here's how we can invoke it with the necessary parameters:", type='text'), ToolUseBlock(id='toolu_01BwnLjq56dqWjivZCRrmY4s', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#7b68ee', 'private': True, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2256, output_tokens=319)),
#  ToolsBetaMessage(id='msg_019iPLEcRLc4x8LkDpyTVtNi', content=[TextBlock(text='To delete the obsolete tag "ArchiveThis" from the "GES_InfraDev2022" space, we can use the `delete_space_tag` function. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01GYfobbRpUroqWFc1G111An', input={'space_id': 'GES_InfraDev2022', 'tag_name': 'ArchiveThis', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2209, output_tokens=206)),
#  ToolsBetaMessage(id='msg_01V2yqRGNtzSMHTvfMUumXS4', content=[TextBlock(text='To delete the "NGS_EarlyConcepts" space from your ClickUp workspace, we can utilize the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01LEJV47w3vuumdLvQVK74gL', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2200, output_tokens=103)),
#  ToolsBetaMessage(id='msg_01KDQwq2MDqiSq96ky7mZtj9', content=[TextBlock(text='To retrieve a list of all existing tags within the "Marketing2023" space in ClickUp, we can utilize the `get_space_tags` function. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01JQUx1FpZi3guo3u6XS4KKP', input={'space_id': 'Marketing2023'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2209, output_tokens=102)),
#  ToolsBetaMessage(id='msg_01ShMhfR959MYuB5j2ZafoSB', content=[TextBlock(text="To address Mitchell's requirements, we can utilize the `update_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01DimSejBoFpUxyCUnpRweo6', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2250, output_tokens=317)),
#  ToolsBetaMessage(id='msg_01F535X57RAVENNxoAtDdhm4', content=[TextBlock(text='To retrieve detailed information about the space "CS_ProjectSpace1", we can utilize the `get_space` tool. This tool allows us to fetch comprehensive details about a specific ClickUp space by providing its space ID.', type='text'), ToolUseBlock(id='toolu_01FwZXdq7StVTCF92etUXCT3', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01HP9vYU74QEkTYryx4bzP5i', content=[TextBlock(text='To create the "MilestoneCritical" tag in the "DigitalTrans2023" space with the specified background color "#00008B" and text color "#FFFFFF", we can utilize the `create_space_tag` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01AQAzhsuxDN9K9BXda74i4T', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2245, output_tokens=199)),
#  ToolsBetaMessage(id='msg_01WfE17fwAKqH2QeDGZUwh2z', content=[TextBlock(text="To create a new space for the customer success team with the given requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01YXERTk5CxDSxaFCrVikJh7', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=264)),
#  ToolsBetaMessage(id='msg_0126E2vpgjgiBYj7SCZhFVjD', content=[TextBlock(text='To update the ClickUp space with the new branding color and name, while restricting direct management to space admins, we can use the `update_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01QDxPiU5V2EBdUmnYBXMfrd', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': 'False', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=326)),
#  ToolsBetaMessage(id='msg_01UJ4TTTCb5gwci5UYkBakbR', content=[TextBlock(text='To delete the unused "OldCampaign" tag from the "branddept301" ClickUp space, we can use the `delete_space_tag` function with the following parameters:', type='text'), ToolUseBlock(id='toolu_01BYenriLruKzk2cZds6Jkwp', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2192, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01PEAfD1xZyPBT6zDWQaXHVF', content=[TextBlock(text='To create a new tag called "Time-Sensitive" with the specified colors in the ClickUp space "engteam777", we can use the `create_space_tag` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01VUtbzSdo2Qz13Jrq8tTMvR', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2190, output_tokens=179)),
#  ToolsBetaMessage(id='msg_01RdwZYRjrf8m1KSnTBxfYnS', content=[TextBlock(text='To delete the "BetaFeature" tag from the "proddev808" ClickUp space, we can use the `delete_space_tag` function with the following parameters:', type='text'), ToolUseBlock(id='toolu_01S8xnhvvNPuW8dsyXmXw2kH', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2183, output_tokens=194)),
#  ToolsBetaMessage(id='msg_01F9M6Rvv928oPBUfNbbxFyK', content=[TextBlock(text='To create the "Employee Relations" space for the HR department with the specified requirements, we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01Kn6nBwBtM9mTEdtafCotTV', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'private': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'False'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2182, output_tokens=275)),
#  ToolsBetaMessage(id='msg_01EADg2BtX2cRd9e5EM2eKg9', content=[TextBlock(text="To retrieve all the information from the ClickUp space dedicated to inventory management, we can use the `get_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01ASCXVGY5YQjSieEafQqZ8L', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2149, output_tokens=94)),
#  ToolsBetaMessage(id='msg_015rteuDZqDekLvZ9UqputJP', content=[TextBlock(text='To delete the unnecessary ClickUp space with the ID "eduop876", we can use the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01UMzxDt8MoCLELSpbVjn3mh', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2152, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01NyE9hZNyTtJuockg1DGonp', content=[TextBlock(text="To create the new ClickUp space with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01Rqws3qFghKhhWivtyg7zBU', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2186, output_tokens=262)),
#  ToolsBetaMessage(id='msg_01Bra91fJNoHQedjruGDZnGv', content=[TextBlock(text='To make the ClickUp space with ID "globalsales400" private, update its color to bright red ("#FF0000"), keep the name as "International Sales Division", and allow only space admins to manage settings, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_013QbM1VUDgst6LjgFiZJjYz', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': 'True', 'admin_can_manage': 'True', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2185, output_tokens=348)),
#  ToolsBetaMessage(id='msg_01DeNbu88JeYHCX8GC8wYpRY', content=[TextBlock(text='To address Samantha\'s request, we can utilize the `update_space` tool to modify the existing "Digital Design Team" space according to the new specifications. Here\'s how we can invoke the tool with the required parameters:', type='text'), ToolUseBlock(id='toolu_01Ef7PxmrRPv6Fx1ktaVisie', input={'space_id': 'uiux1020', 'name': 'Digital Design Team (Rebranded)', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2229, output_tokens=337)),
#  ToolsBetaMessage(id='msg_015qYMDbYzQX5WTDu6pgGFhG', content=[TextBlock(text="To create a new ClickUp space for the content strategy team with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01C2cXp7uNDRGaPAoxugumwo', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': 'True', 'features__due_dates__enabled': 'False', 'features__due_dates__start_date': 'False', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2193, output_tokens=266)),
#  ToolsBetaMessage(id='msg_016D39PF2dikPZpT4Cz7kKok', content=[TextBlock(text='To retrieve all the tags assigned on tasks within the "appdev300" space in ClickUp, we can use the `get_space_tags` tool. Here\'s how we would invoke it:', type='text'), ToolUseBlock(id='toolu_01Dd2fpGVb9ZkWZcLTe7xZqV', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2175, output_tokens=102)),
#  ToolsBetaMessage(id='msg_01KwjaQbXN1A3AKznUzuynWC', content=[TextBlock(text='To create a new tag named "Urgent Discrepancy" with the specified colors in the "datamodel404" space, we can use the `create_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01KMtLZK17u2KWyG9qUbpiMw', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=175)),
#  ToolsBetaMessage(id='msg_01SpGgqc8WbKqTmnjrmMNUaL', content=[TextBlock(text='To delete the "finforecast345" ClickUp space, we can use the `delete_space` tool. Let\'s gather the required parameter:', type='text'), ToolUseBlock(id='toolu_01LHuCbciasYGMzXSBxsw4yd', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2156, output_tokens=91)),
#  ToolsBetaMessage(id='msg_013ufA3ywQFv3VRf886A5W7A', content=[TextBlock(text='To delete the "LowPriority" tag from the "gfxdes678" space, we can use the `delete_space_tag` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01Ro4Z9T85zk3vurti5Qp6dz', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=197)),
#  ToolsBetaMessage(id='msg_01P8TwecTkPGEvtS3HB8hurN', content=[TextBlock(text="To create the new space for the client support division with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01D8Gu7Uan4YEbHxTtTQ6LFr', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'True', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2196, output_tokens=263)),
#  ToolsBetaMessage(id='msg_016qNBWZfZo9QVK9pStpRNoL', content=[TextBlock(text='To retrieve the complete configuration details of the ClickUp space with ID "gamedev909", we can use the "get_space" tool. Here\'s how we would invoke it:', type='text'), ToolUseBlock(id='toolu_01Y3oN7CqHguufhDgccRkkJv', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=96)),
#  ToolsBetaMessage(id='msg_014xxao65o7hf3Q2S3RCGoRm', content=[TextBlock(text='To rename the ClickUp space with the ID "mktoutreach768" to "Market Outreach 2023", update its color to navy blue ("#000080"), and make it private, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01N5qgrrbY1Gk6vLSMuQcwNV', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=347)),
#  ToolsBetaMessage(id='msg_01DrCPgV8pjrSyEUkbkBzxmg', content=[TextBlock(text='To create the desired ClickUp space for the "Fall Events 2023" team, we can utilize the "create_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_019fac8tugSXgXgmLdSZpUUe', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': 'False', 'features__due_dates__enabled': 'True', 'features__due_dates__start_date': 'True', 'features__due_dates__remap_due_dates': 'False', 'features__due_dates__remap_closed_due_date': 'False', 'features__time_tracking__enabled': 'True'}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2210, output_tokens=263))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

def convert_str_to_bool(nested_dict):
    for key, value in nested_dict.items():
        # If the value is a nested dictionary, recursively process it
        if isinstance(value, dict):
            convert_str_to_bool(value)
        else:
            if value == "True":
                nested_dict[key] = True
            elif value == "False":
                nested_dict[key] = False
    return nested_dict

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    llm_response_dict = convert_str_to_bool(llm_response_dict)

    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#7B68EE',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#7b68ee',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': False,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team (Rebranded)',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.74

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_2 = sum(result_list)/len(result_list)
# run_acc_2

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_3 = sum(result_list)/len(result_list)
# run_acc_3

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary + \nFunction and Parameter Descriptions Optimized : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
# print(f"Run 2: {run_acc_2}")
# print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary +
# Function and Parameter Descriptions Optimized : Accuracy
# =========================================
# Run 1: 0.74
