# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'name': {'type': 'string', 'description': 'The name of the new space'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['team_id', 'name', 'multiple_assignees', 'features']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'name': {'type': 'string', 'description': 'The new name of the space'},
#     'color': {'type': 'string', 'description': 'The color used for the space'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to create',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to delete',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag_name', 'tag']}}]

# %%
from pprint import pprint

def flatten_properties(schema_ariginal, path_prefix=''):
    schema = schema_ariginal.copy()
    # Base case: If the schema is not an object, return it as-is
    if schema.get('type') != 'object':
        return {path_prefix: schema}
    
    flattened = {}
    for prop, details in schema.get('properties', {}).items():
        # Construct the new path prefix based on the current location in the schema
        new_prefix = f"{path_prefix}__{prop}" if path_prefix else prop
        if "description" in details:
            details["description"] = f'{details["description"]}__{schema.get("description", "")}'
        else:
            details["description"] = f'{prop}__{schema.get("description", "")}'
            
            
        # If the property is an object, recurse, otherwise, add to the flattened dict
        if details.get('type') == 'object':
            # Merge the results of the recursive call into the flattened dict
            flattened.update(flatten_properties(details, new_prefix))
        else:
            # Directly add the property with its new path prefix
            flattened[new_prefix] = details
    
    return flattened

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}


def flatten_schema(schema):
  # Flatten the parameters schema
  flattened_parameters = flatten_properties(schema['parameters'])

  # Incorporate the flattened parameters into the original schema
  flattened_schema = {
      "name": schema['name'],
      "description": schema['description'],
      "parameters": {
          "type": "object",
          "properties": flattened_parameters,
          "required": list(flattened_parameters.keys()) #schema['parameters']['required']
      }
  }
  return flattened_schema

pprint(flatten_schema(schema[1]))
# Out:
# {'description': 'Add a new Space to a Workspace.',
#  'name': 'create_space',
#  'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The name of the new '
#                                                        'space__',
#                                         'type': 'string'},
#                                'team_id': {'description': 'The ID of the '
#                                                           'team__',
#                                            'type': 'string'}},
#                 'required': ['team_id',
#                              'name',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
from pprint import pprint

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}

n = 3

pprint(schema[n])
print("-------------")
pprint(flatten_schema(schema[n]))
# Out:
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space',
#                                          'type': 'string'},
#                                'features': {'description': 'Enabled features '
#                                                            'within the space',
#                                             'properties': {'due_dates': {'description': 'Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings',
#                                                                          'properties': {'enabled': {'type': 'boolean'},
#                                                                                         'remap_closed_due_date': {'type': 'boolean'},
#                                                                                         'remap_due_dates': {'type': 'boolean'},
#                                                                                         'start_date': {'type': 'boolean'}},
#                                                                          'type': 'object'},
#                                                            'time_tracking': {'description': 'Time '
#                                                                                             'tracking '
#                                                                                             'feature '
#                                                                                             'settings',
#                                                                              'properties': {'enabled': {'type': 'boolean'}},
#                                                                              'type': 'object'}},
#                                             'type': 'object'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features'],
#                 'type': 'object'}}
# -------------
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not__',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space__',
#                                          'type': 'string'},
#                                'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space__',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not__',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space__',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
    
flattened_schema = [flatten_schema(sc) for sc in schema]


with open('clickup_space_flattened_schema.json', 'w') as f:
    json.dump(flattened_schema, f, indent=4, sort_keys=True)

pprint(flattened_schema)
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide '
#                                                             'whether to '
#                                                             'include archived '
#                                                             'spaces or not__',
#                                              'type': 'boolean'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id', 'archived'],
#                  'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The name of the new '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id',
#                               'name',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                  'Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                     'determine '
#                                                                     'if the '
#                                                                     'administrator '
#                                                                     'can '
#                                                                     'manage '
#                                                                     'the space '
#                                                                     'or not__',
#                                                      'type': 'boolean'},
#                                 'color': {'description': 'The color used for '
#                                                          'the space__',
#                                           'type': 'string'},
#                                 'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The new name of the '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'private': {'description': 'A flag to '
#                                                            'determine if the '
#                                                            'space is private '
#                                                            'or not__',
#                                             'type': 'boolean'},
#                                 'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'name',
#                               'color',
#                               'private',
#                               'admin_can_manage',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'create__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'}},
#                  'required': ['space_id',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'delete__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag_name': {'description': 'The name of the '
#                                                             'tag to delete__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'tag_name',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}}]

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
flattened_schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import os
import json
import dotenv
import anthropic
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()
# openai.api_key = os.getenv("OPENAI_API_KEY")

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in flattened_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import anthropic
client = anthropic.Anthropic()

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-haiku-20240307",
  system = """
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response #.choices[0].message.tool_calls[0].function
# Out:
# ToolsBetaMessage(id='msg_01QMXdRnrWxSDEGGJBWid5rH', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_01RA8Xxjgu9Jxt9W5MnnpPYa', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        # response.content[1]
        # if llm_response is not None:
        #     func_name = llm_response.name
        #     func_args_dict = json.loads(llm_response.arguments)
        # else:
        #     func_name = None
        #     func_args_dict = None 
        # return {"name": func_name, "arguments": func_args_dict}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:34<00:00,  1.89s/it]
# [ToolsBetaMessage(id='msg_016zmFZFW27uVsB4DK44w1Fg', content=[TextBlock(text='Okay, let\'s use the ClickUp API to check the active spaces under the "Innovative Solutions" team.', type='text'), ToolUseBlock(id='toolu_01WKdmyHoun78aiiGdxovB4r', input={'team_id': 'team123', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=99)),
#  ToolsBetaMessage(id='msg_01Mgub6B6eZ3R5TY8FjeJ2eX', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_01JM5n3ZhQfJYDQK8oz175ZT', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255)),
#  ToolsBetaMessage(id='msg_01KeKgdWxtinfba13yWcNGYU', content=[TextBlock(text='Okay, let\'s retrieve the custom tags for the ClickUp space with the ID "sd456" before archiving it.', type='text'), ToolUseBlock(id='toolu_013wMhQ1VR5a6FSVrtxHLju5', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2020, output_tokens=86)),
#  ToolsBetaMessage(id='msg_01HAU7RsFAiwooaP5PKytNtM', content=[TextBlock(text='Okay, let\'s update the tag in the "prj1122" space as requested:', type='text'), ToolUseBlock(id='toolu_01R2KfARCahpc3H54NUJAwpk', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2047, output_tokens=177)),
#  ToolsBetaMessage(id='msg_015Yy6KVsJbSoJTH9AVXgabc', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789":', type='text'), ToolUseBlock(id='toolu_013HKskDdFf8mhjNbTWf8ZZQ', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=177)),
#  ToolsBetaMessage(id='msg_01Je5YoixQAMBWsWGYx6piAr', content=[TextBlock(text='Okay, let\'s update the "Backend_Development_Space" to disallow multiple assignees while keeping the other settings unchanged.', type='text'), ToolUseBlock(id='toolu_01XYtENdraeE5XV6wTPAFjvL', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=311)),
#  ToolsBetaMessage(id='msg_0163p62vXM1UEniEuKL2PGQn', content=[TextBlock(text='Okay, let\'s delete the unused ClickUp space with the ID "gt678":', type='text'), ToolUseBlock(id='toolu_01SXKBKuNZR1Bpt7fwRZmseU', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2015, output_tokens=76)),
#  ToolsBetaMessage(id='msg_01CTr8zNXRz49mVMY6tM2BvV', content=[TextBlock(text="Okay, let's create the new space for the design team based on the requirements you provided:", type='text'), ToolUseBlock(id='toolu_015MKQLDKaDw7x262X75mEck', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=247)),
#  ToolsBetaMessage(id='msg_019t8WQta8AbBXivBpC8Pt7Y', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the space with ID "ep456".', type='text'), ToolUseBlock(id='toolu_01CtKoXebm3fkbeWh5jaaryi', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2010, output_tokens=81)),
#  ToolsBetaMessage(id='msg_01RwTrBM6ehwfT7owxSFKbXe', content=[TextBlock(text="Okay, let's update the space for the front-end development team as per the requirements:", type='text'), ToolUseBlock(id='toolu_01NoTMVWmfL5iaXhYMh7oSEh', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=286)),
#  ToolsBetaMessage(id='msg_01YW65Ppa633dgxZRUiAgfNZ', content=[TextBlock(text='Okay, let\'s update the "pd2023" space to reflect the changes Samantha would like to implement:', type='text'), ToolUseBlock(id='toolu_01H6fWAodT1mW1mFVRDY23hP', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2101, output_tokens=313)),
#  ToolsBetaMessage(id='msg_013RdP3r9ut3iUuVvyLf8CUb', content=[TextBlock(text="Okay, let's create the new space for the events management team at Glorious Events Inc. using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_011rCe1C65BGB9ojgAKBuZBY', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2074, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01LZtgGbXV1enpTNbMfLFAXt', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces. Here are the steps we can take:", type='text'), ToolUseBlock(id='toolu_012AaELmDiZo2QwLw9rcTLBz', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2033, output_tokens=110)),
#  ToolsBetaMessage(id='msg_012QzJqocpqsgbRgKW84u6rV', content=[TextBlock(text="Okay, let's set up the new ClickUp space for Luxe Apparel's Fall Campaign 2023:", type='text'), ToolUseBlock(id='toolu_01JRQJ8EU7r1Q8kqbsZ8KUsk', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2065, output_tokens=254)),
#  ToolsBetaMessage(id='msg_018J79NTdB3XHRftjRg7xR6K', content=[TextBlock(text="Okay, let's handle this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01S8rAt7EFi5rgjmyTCzcoS9', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2057, output_tokens=173)),
#  ToolsBetaMessage(id='msg_01QLaWVjaRzxhFYcMy51PGAp', content=[TextBlock(text='Okay, let\'s add the new "Urgent Review" tag to the "FTProjects" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_016jGoMqyeJTCJUo3vmzweCQ', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2040, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01KQ9vfQZGV3ZpfSB5aUFP3P', content=[TextBlock(text="Okay, let's help Crystal streamline the content planning and creation process for the social media team at Echo Media.", type='text'), ToolUseBlock(id='toolu_01KAEUTAkfA2eiqB9zXE4bmL', input={'team_id': 'EMContent2023', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2038, output_tokens=100)),
#  ToolsBetaMessage(id='msg_01TKZgB5cEJhMUXDEwZu5T92', content=[TextBlock(text="Okay, let's update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01BLqEsmSeHUm6GocQzbWUKC', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2117, output_tokens=300)),
#  ToolsBetaMessage(id='msg_01RojZiTbERYtvGHmxZ6Qy2q', content=[TextBlock(text='Okay, let\'s get the list of tags for the "DSAnalysis" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_01RNyGgGLR4LiEnps6DYjS7a', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=83)),
#  ToolsBetaMessage(id='msg_014WnwCXzFzmqNcK7mG6uVyh', content=[TextBlock(text='Okay, let\'s use the ClickUp tools to help TerraFirma get an overview of the "TF_ProjectX" space before they archive it.', type='text'), ToolUseBlock(id='toolu_017RwtJA74pycNQGqsCQjNo9', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2036, output_tokens=97)),
#  ToolsBetaMessage(id='msg_017miFYKUxYdmgqQ9zM7KMJe', content=[TextBlock(text='Okay, let\'s start by getting a list of all the spaces under the "FI_Team2023" team. We can use the ', type='text'), ToolUseBlock(id='toolu_014xNkfyQSUU1zmqafkSRGMJ', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2102, output_tokens=107)),
#  ToolsBetaMessage(id='msg_012PNg6VYyw3bvhqcSEr3TRp', content=[TextBlock(text='Okay, let\'s set up the new "Design Hub 2023" space in ClickUp to meet Vera\'s requirements:', type='text'), ToolUseBlock(id='toolu_01SHTzAp2iAeg63KvbhPRA3y', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2112, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01RoroQek1hhr71EnM2LKQo1', content=[TextBlock(text='Okay, let\'s help Jess set up the new "Priority" tag in the "WF_Content" ClickUp space:', type='text'), ToolUseBlock(id='toolu_01H8RueFYWvnnTEoEv8TRf8p', input={'team_id': 'YOUR_TEAM_ID', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2081, output_tokens=108)),
#  ToolsBetaMessage(id='msg_01MCsLuCZQBeasZvgjAgXpLo', content=[TextBlock(text="Okay, let's handle this request step-by-step using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_01Q5vW5qWssNS3FQCVTJPS1b', input={'space_id': 'PF_Projects'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2116, output_tokens=79)),
#  ToolsBetaMessage(id='msg_01Q2oeunEx4U5tAvJoXqJHwb', content=[TextBlock(text="Okay, let's handle this step-by-step:", type='text'), ToolUseBlock(id='toolu_01TvKivNtexdHRvkDEutHzQm', input={'space_id': 'GES_InfraDev2022', 'tag__name': 'ArchiveThis', 'tag__tag_fg': 'white', 'tag__tag_bg': 'red', 'tag_name': 'ArchiveThis'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=165)),
#  ToolsBetaMessage(id='msg_012vKUZQft1wLzJ3NiBbWDkP', content=[TextBlock(text='Understood. Let\'s proceed with deleting the "NGS_EarlyConcepts" space from the ClickUp workspace as part of the strategic realignment initiative at NexGen Solutions.', type='text'), ToolUseBlock(id='toolu_01EAu2sWCJUyEsaU3kkcpedd', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2060, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01PDCLoGKYwipY7bKgisFMWP', content=[TextBlock(text='Okay, let\'s get the information Linda needs to audit the tags in the "Marketing2023" space of ClickUp.', type='text'), ToolUseBlock(id='toolu_01QNiwnTtWa4jDqc89HWV71z', input={'space_id': 'Marketing2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=87)),
#  ToolsBetaMessage(id='msg_017KS9vkH386TW1md81nbrGh', content=[TextBlock(text='Okay, let\'s update the "TI_ProductLaunches" space in ClickUp to meet Mitchell\'s requirements:', type='text'), ToolUseBlock(id='toolu_01Dke88zhPqLSiMK3JyPpAMt', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2110, output_tokens=319)),
#  ToolsBetaMessage(id='msg_01MHRZ3Boe3nG6zNaitsVDaU', content=[TextBlock(text='Okay, let\'s gather the necessary information about the "CS_ProjectSpace1" space before making any archiving decisions.', type='text'), ToolUseBlock(id='toolu_01Urq98WkKUYwmqKcfUXfNsZ', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2077, output_tokens=86)),
#  ToolsBetaMessage(id='msg_01WG8sFpVcF3u2gQe3yoDqPY', content=[TextBlock(text='Understood. Let\'s create the new "MilestoneCritical" tag within the "DigitalTrans2023" space on ClickUp.', type='text'), ToolUseBlock(id='toolu_01PM4BrQFXJjP5yyaagZXt96', input={'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2105, output_tokens=177)),
#  ToolsBetaMessage(id='msg_01NznRWhdiBSwCpcUAcpqXdP', content=[TextBlock(text="Okay, let's create the new space for the customer success team using the ClickUp API. Here are the steps:", type='text'), ToolUseBlock(id='toolu_014qAqgZ5qTipV1nyDxfx31U', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2064, output_tokens=256)),
#  ToolsBetaMessage(id='msg_01XUXU27JHVgQtZLPvd6LcNh', content=[TextBlock(text='Okay, let\'s update the "social123" space with the new requirements:', type='text'), ToolUseBlock(id='toolu_01W2MAJ2bs4v7tC45tHSkiuD', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=302)),
#  ToolsBetaMessage(id='msg_01Sn9vNTpBwQJbQg6nYvjy1o', content=[TextBlock(text='Okay, let\'s remove the unused "OldCampaign" tag from the "branddept301" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_0169kRhngyddyjLuUopbAzVL', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2052, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01MHxdVowXHDSRNGgMvy1DrU', content=[TextBlock(text='Okay, let\'s set up the new "Time-Sensitive" tag in the ClickUp space for the engineering team.', type='text'), ToolUseBlock(id='toolu_01GiPEAevViJyTFt27TDiYMo', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2050, output_tokens=157)),
#  ToolsBetaMessage(id='msg_016dnATMYoWqmYvzj7cPWvkm', content=[TextBlock(text='Okay, let\'s remove the "BetaFeature" tag from the "proddev808" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_0171RudJwMywJAQ4znFdqe3Q', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2043, output_tokens=182)),
#  ToolsBetaMessage(id='msg_013xJwHNUV3MSGsC59mKvpux', content=[TextBlock(text='Okay, let\'s set up the new "Employee Relations" space for the HR department in ClickUp:', type='text'), ToolUseBlock(id='toolu_01S5gkgSv1xWDALdMLkfR1JT', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False, 'private': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01SX3B2S3heCxTiCnyN5RmFL', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the "ecominv500" space:', type='text'), ToolUseBlock(id='toolu_01N5FeUZHN93RCHEb6HyWpXg', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2009, output_tokens=84)),
#  ToolsBetaMessage(id='msg_01MU5wBh6BaGQLSFFD4dc1J2', content=[TextBlock(text="Okay, let's handle the decommissioning of the old ClickUp space for the facility upgrades:", type='text'), ToolUseBlock(id='toolu_01LL3ok1NUhr282QeJ5sDb5p', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2012, output_tokens=82)),
#  ToolsBetaMessage(id='msg_015m3KWzaz9rkUf9rrDHmnnG', content=[TextBlock(text="Okay, let's help Natalie set up the new ClickUp space for the community outreach projects. Here are the steps:", type='text'), ToolUseBlock(id='toolu_015g51ct3gSXTmWxNsBSrrC4', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=259)),
#  ToolsBetaMessage(id='msg_01NszJx6AJwRUScGVRuhyjt6', content=[TextBlock(text="Okay, let's update the ClickUp space as requested:", type='text'), ToolUseBlock(id='toolu_01BurSKcBS1Sv8R4zZ6DZFRU', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2045, output_tokens=299)),
#  ToolsBetaMessage(id='msg_0182Zzn2brS4FrLKtRJfKVup', content=[TextBlock(text='Okay, let\'s update the "Digital Design Team" space in ClickUp to meet Samantha\'s requirements:', type='text'), ToolUseBlock(id='toolu_011zqyrrjt8Qorv8p9GwhZTA', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2089, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01N6ttgFKDDczstYnLzZpN4d', content=[TextBlock(text="Okay, let's set up the new space for the content strategy team based on your requirements:", type='text'), ToolUseBlock(id='toolu_01VBfVihJNfxVHKSfonhR5H8', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2053, output_tokens=249)),
#  ToolsBetaMessage(id='msg_01Gom3uPzun6ykzswxGPXu5M', content=[TextBlock(text='Okay, let\'s gather the information about the tags currently in use within the ClickUp development space with the ID "appdev300".', type='text'), ToolUseBlock(id='toolu_011eSad4CM8P5TgQvzi81d9j', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01ArytojyEDK9odxjGXKXk7u', content=[TextBlock(text='Okay, let\'s create the new tag for the "datamodel404" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_016kofc5ECs4m7fTyE9k6FGd', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2048, output_tokens=153)),
#  ToolsBetaMessage(id='msg_01FxHae4JeEtVJaMc8r4nMCN', content=[TextBlock(text='Okay, let\'s delete the "finforecast345" space from ClickUp:', type='text'), ToolUseBlock(id='toolu_015S1mj44C27myeqNxhcwaB7', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2016, output_tokens=78)),
#  ToolsBetaMessage(id='msg_01QkEhm8oG3EjVU6uGqGSxqs', content=[TextBlock(text='Okay, let\'s help Alex remove the "LowPriority" tag from the "gfxdes678" space:', type='text'), ToolUseBlock(id='toolu_01VnyZfLAfdiweCm2vZMUPTr', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=186)),
#  ToolsBetaMessage(id='msg_01FEf6r6YyFma9eKTGrwyCXQ', content=[TextBlock(text="Okay, let's set up the new space for the Q2 Support Updates team:", type='text'), ToolUseBlock(id='toolu_01BavBFdaZHiMtL5F9Y6jxWj', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2056, output_tokens=248)),
#  ToolsBetaMessage(id='msg_01KYHa3T8NHNiEvEFLoMJQc5', content=[TextBlock(text='Okay, let\'s retrieve the details of the ClickUp space with the ID "gamedev909" so the manager can review the current configuration before archiving it.', type='text'), ToolUseBlock(id='toolu_01Cs3Z9GfhrgRirk2QLSj85a', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=93)),
#  ToolsBetaMessage(id='msg_0194kK1XfzkeZ4wcPAwAtcro', content=[TextBlock(text='Okay, let\'s update the "Market Outreach 2023" space as requested:', type='text'), ToolUseBlock(id='toolu_01XZiP1DpYZXmtstdgCCFh4a', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=309)),
#  ToolsBetaMessage(id='msg_015TWmdbz5R4fXBRr3EXxywU', content=[TextBlock(text="Okay, let's set up the dedicated ClickUp space for the Fall Events 2023 team at Occasions Plus. Here are the steps:", type='text'), ToolUseBlock(id='toolu_01X7KPkj2mq3B4DSHCxGrNWM', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2070, output_tokens=261))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

def convert_str_to_bool(nested_dict):
    for key, value in nested_dict.items():
        # If the value is a nested dictionary, recursively process it
        if isinstance(value, dict):
            convert_str_to_bool(value)
        else:
            if value == "True":
                nested_dict[key] = True
            elif value == "False":
                nested_dict[key] = False
    return nested_dict

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    llm_response_dict = convert_str_to_bool(llm_response_dict)

    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'EMContent2023'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'YOUR_TEAM_ID'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': 'red',
#                'tag__tag_fg': 'white',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.54

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_2 = sum(result_list)/len(result_list)
# run_acc_2

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_3 = sum(result_list)/len(result_list)
# run_acc_3

# %%
print("ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
# print(f"Run 2: {run_acc_2}")
# print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy
# =========================================
# Run 1: 0.54
