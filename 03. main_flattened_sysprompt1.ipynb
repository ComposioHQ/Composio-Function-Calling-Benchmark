# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'name': {'type': 'string', 'description': 'The name of the new space'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['team_id', 'name', 'multiple_assignees', 'features']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'name': {'type': 'string', 'description': 'The new name of the space'},
#     'color': {'type': 'string', 'description': 'The color used for the space'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to create',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to delete',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag_name', 'tag']}}]

# %%
from pprint import pprint

def flatten_properties(schema_ariginal, path_prefix=''):
    schema = schema_ariginal.copy()
    # Base case: If the schema is not an object, return it as-is
    if schema.get('type') != 'object':
        return {path_prefix: schema}
    
    flattened = {}
    for prop, details in schema.get('properties', {}).items():
        # Construct the new path prefix based on the current location in the schema
        new_prefix = f"{path_prefix}__{prop}" if path_prefix else prop
        if "description" in details:
            details["description"] = f'{details["description"]}__{schema.get("description", "")}'
        else:
            details["description"] = f'{prop}__{schema.get("description", "")}'
            
            
        # If the property is an object, recurse, otherwise, add to the flattened dict
        if details.get('type') == 'object':
            # Merge the results of the recursive call into the flattened dict
            flattened.update(flatten_properties(details, new_prefix))
        else:
            # Directly add the property with its new path prefix
            flattened[new_prefix] = details
    
    return flattened

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}


def flatten_schema(schema):
  # Flatten the parameters schema
  flattened_parameters = flatten_properties(schema['parameters'])

  # Incorporate the flattened parameters into the original schema
  flattened_schema = {
      "name": schema['name'],
      "description": schema['description'],
      "parameters": {
          "type": "object",
          "properties": flattened_parameters,
          "required": list(flattened_parameters.keys()) #schema['parameters']['required']
      }
  }
  return flattened_schema

pprint(flatten_schema(schema[1]))
# Out:
# {'description': 'Add a new Space to a Workspace.',
#  'name': 'create_space',
#  'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The name of the new '
#                                                        'space__',
#                                         'type': 'string'},
#                                'team_id': {'description': 'The ID of the '
#                                                           'team__',
#                                            'type': 'string'}},
#                 'required': ['team_id',
#                              'name',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
from pprint import pprint

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}

n = 3

pprint(schema[n])
print("-------------")
pprint(flatten_schema(schema[n]))
# Out:
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space',
#                                          'type': 'string'},
#                                'features': {'description': 'Enabled features '
#                                                            'within the space',
#                                             'properties': {'due_dates': {'description': 'Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings',
#                                                                          'properties': {'enabled': {'type': 'boolean'},
#                                                                                         'remap_closed_due_date': {'type': 'boolean'},
#                                                                                         'remap_due_dates': {'type': 'boolean'},
#                                                                                         'start_date': {'type': 'boolean'}},
#                                                                          'type': 'object'},
#                                                            'time_tracking': {'description': 'Time '
#                                                                                             'tracking '
#                                                                                             'feature '
#                                                                                             'settings',
#                                                                              'properties': {'enabled': {'type': 'boolean'}},
#                                                                              'type': 'object'}},
#                                             'type': 'object'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features'],
#                 'type': 'object'}}
# -------------
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not__',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space__',
#                                          'type': 'string'},
#                                'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space__',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not__',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space__',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
    
flattened_schema = [flatten_schema(sc) for sc in schema]


with open('clickup_space_flattened_schema.json', 'w') as f:
    json.dump(flattened_schema, f, indent=4, sort_keys=True)

pprint(flattened_schema)
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide '
#                                                             'whether to '
#                                                             'include archived '
#                                                             'spaces or not__',
#                                              'type': 'boolean'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id', 'archived'],
#                  'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The name of the new '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id',
#                               'name',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                  'Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                     'determine '
#                                                                     'if the '
#                                                                     'administrator '
#                                                                     'can '
#                                                                     'manage '
#                                                                     'the space '
#                                                                     'or not__',
#                                                      'type': 'boolean'},
#                                 'color': {'description': 'The color used for '
#                                                          'the space__',
#                                           'type': 'string'},
#                                 'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The new name of the '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'private': {'description': 'A flag to '
#                                                            'determine if the '
#                                                            'space is private '
#                                                            'or not__',
#                                             'type': 'boolean'},
#                                 'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'name',
#                               'color',
#                               'private',
#                               'admin_can_manage',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'create__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'}},
#                  'required': ['space_id',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'delete__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag_name': {'description': 'The name of the '
#                                                             'tag to delete__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'tag_name',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}}]

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
flattened_schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import os
import json
import dotenv
import anthropic
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()
# openai.api_key = os.getenv("OPENAI_API_KEY")

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in flattened_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import anthropic
client = anthropic.Anthropic()

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system = """
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response #.choices[0].message.tool_calls[0].function
# Out:
# ToolsBetaMessage(id='msg_01LwGJwQwuuupfAbp6bQGcU3', content=[TextBlock(text='To set up the new project space "Innovative Campaigns 2023" for the "Creative Minds" team with the specified requirements, we can use the `create_space` tool from ClickUp. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01T1KqEwniDVJj5e75WpKunP', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1927, output_tokens=281))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        # response.content[1]
        # if llm_response is not None:
        #     func_name = llm_response.name
        #     func_args_dict = json.loads(llm_response.arguments)
        # else:
        #     func_name = None
        #     func_args_dict = None 
        # return {"name": func_name, "arguments": func_args_dict}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [03:21<00:00,  4.03s/it]
# [ToolsBetaMessage(id='msg_01JjiozKqm9C24JTHBufYKxf', content=[TextBlock(text='To view the active and archived Spaces under the "Innovative Solutions" team with the team ID "team123", we can use the `get_spaces` tool:', type='text'), ToolUseBlock(id='toolu_01Ckr9MCN638eo4kC1qKSHix', input={'team_id': 'team123', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1921, output_tokens=109)),
#  ToolsBetaMessage(id='msg_01X3wwQ8UnbWb13rHGkr3YCW', content=[TextBlock(text='To set up the new project space "Innovative Campaigns 2023" for the "Creative Minds" team with the specified requirements, we can use the `create_space` tool from ClickUp. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_011p9u67Era5GzE9cN12418s', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1927, output_tokens=281)),
#  ToolsBetaMessage(id='msg_01VGkWgfeB7psNEJF6nSxNRb', content=[TextBlock(text='To retrieve the list of custom tags created in the ClickUp space with ID "sd456", we can use the "get_space_tags" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_011ZrpWaYznVruLP11rBc8vA', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1915, output_tokens=100)),
#  ToolsBetaMessage(id='msg_017tQfB5ERvXeBtyp5eQQg2W', content=[TextBlock(text='To update the tag in the ClickUp space "prj1122" with the new name "Critical Bug" and the specified colors, we can use the following steps:', type='text'), ToolUseBlock(id='toolu_01AftALyXJN2AW5TJ1fCUUdX', input={'space_id': 'prj1122'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1942, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01KjYVr7sbegdGEVgzCCa6r6', content=[TextBlock(text='To remove the "MinorIssue" tag from the space with ID "qa789", we can use the `delete_space_tag` function. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01LhD9L6qepY8PeEWHRat8XH', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1930, output_tokens=194)),
#  ToolsBetaMessage(id='msg_01DRBiVEH53PpYXYPFp49roh', content=[TextBlock(text='To disable multiple assignees for the "Backend_Development_Space" space while keeping other settings unchanged, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01LboRrzKuhgRbPwTe94wQmi', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1941, output_tokens=320)),
#  ToolsBetaMessage(id='msg_01RBmytegic1UrkazDGw1g3H', content=[TextBlock(text='To delete the unused ClickUp space with the ID "gt678", we can use the "delete_space" tool from the available functions. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01LWjqjWadWMUmqzDUmZJYoY', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1910, output_tokens=95)),
#  ToolsBetaMessage(id='msg_01GR8dp2dT5517LQi7JWf56j', content=[TextBlock(text='To create a new space named "Design Studio 2023" with the specified features enabled, we can use the `create_space` tool:', type='text'), ToolUseBlock(id='toolu_017hXUkQ3Z9UxgGdiz4gCC6w', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1921, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01X9T9W7vEm8iVbQYirWhATS', content=[TextBlock(text='To get the details of the space with ID "ep456", we can use the "get_space" tool like this:', type='text'), ToolUseBlock(id='toolu_01D27h4ZDTcbj35YPwQXA7Sh', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1905, output_tokens=83)),
#  ToolsBetaMessage(id='msg_01JT1JJq6FLsUBVj7BjhoWHy', content=[TextBlock(text='To rename the space with ID "fe987" to "FE Development 2023", make it private, and enable due dates and time tracking features, we can use the `update_space` tool:', type='text'), ToolUseBlock(id='toolu_012xLbzorXsTtSkvCSMQtavN', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#7b68ee', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1937, output_tokens=330)),
#  ToolsBetaMessage(id='msg_01VCQCx8WpAydXTbkKWiQRr3', content=[TextBlock(text="To assist Samantha with her requirements, we can utilize the `update_space` tool from the ClickUp API. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01LmuAyTmBzxvavFwJMLCvVy', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#ffffff', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1996, output_tokens=323)),
#  ToolsBetaMessage(id='msg_01RfsFXYTkfFEwCSEigs6MEn', content=[TextBlock(text='To create a new space in ClickUp for the events management team at Glorious Events Inc., we can use the `create_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01CuiJeCCVJqcxQ7ZHs5fuKY', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1969, output_tokens=265)),
#  ToolsBetaMessage(id='msg_01MKUVFECUh4gMGZjScBYoCT', content=[TextBlock(text='To assist the IT department at Zenith Corp. with their ClickUp workspace audit, we can utilize the following ClickUp tools:', type='text'), ToolUseBlock(id='toolu_016RG1dfXwaRKznCkyLeeNq5', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1928, output_tokens=104)),
#  ToolsBetaMessage(id='msg_01Qf1aE6wSeZ4Nxbmv2RuGE7', content=[TextBlock(text='To create a new ClickUp space for the "Fall Campaign 2023" with the specified requirements, we can utilize the `create_space` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01JX1WZBxoXdjDM6VNbUZe8g', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1960, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01C5YoVB1F7eKpqjp1ZKGVmi', content=[TextBlock(text='To delete the "OldCampaign" tag from the "outreachQ2" space in ClickUp, we can use the `delete_space_tag` function:', type='text'), ToolUseBlock(id='toolu_01S8m9s72N3H9VdnH9tpRXtB', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#00008B', 'tag__tag_bg': '#add8e6'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1952, output_tokens=199)),
#  ToolsBetaMessage(id='msg_0132JC3vkaptD28nNBqNbb38', content=[TextBlock(text='To add the new "Urgent Review" tag to the "FTProjects" space in ClickUp, we can use the `create_space_tag` function:', type='text'), ToolUseBlock(id='toolu_01A8qmgsfrfLwma2k2e4peFk', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1935, output_tokens=166)),
#  ToolsBetaMessage(id='msg_01GAg2hHKbwLR8vvhPDpTRpz', content=[TextBlock(text='To enable time tracking features and update the theme for the "EMContentPlanning" space, we can use the `update_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01BqH4yMXmztYuQDUfLQMAaC', input={'space_id': 'EMContentPlanning', 'name': 'EMContent2023', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1933, output_tokens=321)),
#  ToolsBetaMessage(id='msg_01Mh1wGicUPEi15ja2MEqaqA', content=[TextBlock(text='To update the space with the new name, color, privacy settings, and disable time tracking, we can use the `update_space` tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01RnnicwhRcx3iFjq7Br7eWz', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2012, output_tokens=321)),
#  ToolsBetaMessage(id='msg_015N8ot1bBgBbiBpJBuawWXA', content=[TextBlock(text='To get a list of all existing tags in the "DSAnalysis" ClickUp space, we can use the `get_space_tags` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01NAwRuNi3ENzPeUp1EYwjwW', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1927, output_tokens=101)),
#  ToolsBetaMessage(id='msg_01VH97jjJ61CUtuZCmXa5AHD', content=[TextBlock(text='To assist TerraFirma with getting an overview of the "TF_ProjectX" space before phasing it out, we can utilize the following ClickUp tools:', type='text'), ToolUseBlock(id='toolu_019VP4P2hQSS8fPqy2kjcxjn', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1931, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01Vv5bkWHpKazzR1r4A49qve', content=[TextBlock(text='To get a comprehensive list of all active and archived spaces under the team ID "FI_Team2023", we can use the "get_spaces" tool from the ClickUp API. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_018Me5TvrDTDaa9vqLm9eNed', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1997, output_tokens=126)),
#  ToolsBetaMessage(id='msg_01LCH7bZxcxDZ3HDfBXSEKfB', content=[TextBlock(text='To create the new "Design Hub 2023" space with the specified requirements, we can use the `create_space` tool from ClickUp. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_018ezAHD4StLwLZ8zJm8Pijj', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2007, output_tokens=269)),
#  ToolsBetaMessage(id='msg_01Wjvt2acJEHZ5y8vYH99oAN', content=[TextBlock(text='To assist Jess in creating the new "Priority" tag for the "WF_Content" space in ClickUp, we can utilize the following tool:', type='text'), ToolUseBlock(id='toolu_01XesMNriTcwKC6N91Z1odsA', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1976, output_tokens=161)),
#  ToolsBetaMessage(id='msg_01MHmoSg1vguwXREHMAtwJVK', content=[TextBlock(text='To address the finance team\'s requirements for the "PF_Projects" space in ClickUp, we can utilize the following tools:', type='text'), ToolUseBlock(id='toolu_01UNLk6mi1hsfB8u11RzfaNt', input={'space_id': 'PF_Projects'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2011, output_tokens=87)),
#  ToolsBetaMessage(id='msg_01UekHuVx8JescGE85BmZAd5', content=[TextBlock(text='To delete the obsolete tag "ArchiveThis" from the "GES_InfraDev2022" space, we can use the "delete_space_tag" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01NEiqJiPWS9kVYsNtsYJvg2', input={'space_id': 'GES_InfraDev2022'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1964, output_tokens=114)),
#  ToolsBetaMessage(id='msg_011xSaDLpWiK37rWK17ttwri', content=[TextBlock(text='To delete the "NGS_EarlyConcepts" space from your ClickUp workspace, we can utilize the "delete_space" tool. Here\'s how you can invoke it:', type='text'), ToolUseBlock(id='toolu_01LDSYDAyGDsZbho2x1b5TC8', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1955, output_tokens=103)),
#  ToolsBetaMessage(id='msg_01U5osJGAswNrVEH7SKe6aDM', content=[TextBlock(text='To get a list of all existing tags in the "Marketing2023" space, we can use the `get_space_tags` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_017SMeoLwanKP6TjkLzSS5Qr', input={'space_id': 'Marketing2023'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1964, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01AzGzMvVNTq53RsE4WE7NwG', content=[TextBlock(text='To address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace, we can utilize the following tools:', type='text'), ToolUseBlock(id='toolu_01MUGg5aScgJk1rzy8oXZo1y', input={'space_id': 'TI_ProductLaunches'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2005, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01CvfetivUHELXwdmRZTHPE8', content=[TextBlock(text='To retrieve the details of the space "CS_ProjectSpace1", we can use the `get_space` tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01QEZVtau2DnqCnU3TXU4Y5z', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1972, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01UTaeUYC51NnSPW78292KoK', content=[TextBlock(text='To create the new "MilestoneCritical" tag in the "DigitalTrans2023" space on ClickUp, we can utilize the following tool:', type='text'), ToolUseBlock(id='toolu_019PHXUD8Sc9kxc2VQHS4jta', input={'space_id': 'DigitalTrans2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2000, output_tokens=174)),
#  ToolsBetaMessage(id='msg_01WSEERmccmHdYss6uuwZKDC', content=[TextBlock(text="To create a new space for the customer success team with the specified requirements, we can use the `create_space` tool from ClickUp. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01Vc6zaPrT2m7RpP5jkZPnrZ', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1959, output_tokens=268)),
#  ToolsBetaMessage(id='msg_01H7e3pJGJUvqGfVCtiTMF7m', content=[TextBlock(text='To update the space with ID "social123" to include the new branding color and change the name, while also setting it so that only admins can manage it, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_0127tpdsi9gpm6TuNXTbXbDo', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1950, output_tokens=335)),
#  ToolsBetaMessage(id='msg_01KbNBESvN49wmCGWL6KmnwK', content=[TextBlock(text='To delete the "OldCampaign" tag from the "branddept301" space in ClickUp, we can use the `delete_space_tag` function:', type='text'), ToolUseBlock(id='toolu_016xbg1DMJTooQcDZW9XBXLi', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1947, output_tokens=197)),
#  ToolsBetaMessage(id='msg_01RqzScHRajyYRPSxtpNAYGS', content=[TextBlock(text='To add a new tag called "Time-Sensitive" with the specified colors to the ClickUp space "engteam777", we can use the `create_space_tag` tool:', type='text'), ToolUseBlock(id='toolu_01A3m5WfbUzUenRDuda6ano3', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1945, output_tokens=171)),
#  ToolsBetaMessage(id='msg_015DsxtLmzJt8DhfaL9NZWau', content=[TextBlock(text='To delete the "BetaFeature" tag from the "proddev808" space in ClickUp, we can use the "delete_space_tag" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_018gwknUZKMfSUM8RuALfLaJ', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_bg': '#FFFF00', 'tag__tag_fg': '#000000'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1938, output_tokens=199)),
#  ToolsBetaMessage(id='msg_01UXZk11tedtQ5Nava9JvRhz', content=[TextBlock(text='To create the "Employee Relations" private space for the "hrdept201" team with multiple assignees enabled and without time tracking or due dates, we can use the `create_space` tool like this:', type='text'), ToolUseBlock(id='toolu_01Eq3SriKFdfNVxi17WZi6RA', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1937, output_tokens=270)),
#  ToolsBetaMessage(id='msg_019Eba1AnXay8ExKzSNVy7xT', content=[TextBlock(text="To retrieve all information from the ClickUp space dedicated to inventory management, we can use the `get_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_0111swmxhq8No8ythcD2MTzf', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1904, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01PGFGb4Dkk26DaGdNMJdALg', content=[TextBlock(text='To delete the ClickUp space with the ID "eduop876", we can use the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01WSuK835AZqBBagN71eiBug', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1907, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01RWoJ7NEMgjEhXhYDqBTimh', content=[TextBlock(text="To create the new ClickUp space with the specified requirements, we can use the `create_space` tool. Here's how we would invoke it:", type='text'), ToolUseBlock(id='toolu_01XCQPCdc3sx4rqUW2JFKbVP', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1941, output_tokens=262)),
#  ToolsBetaMessage(id='msg_01EQqphVyp3UgGHyXeZe4gYG', content=[TextBlock(text='To make the requested changes to the ClickUp space with ID "globalsales400", we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01SHQQfULWSdW1Ta3tyBzFNL', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1940, output_tokens=319)),
#  ToolsBetaMessage(id='msg_017n7yGcqg129KfDRuz3q45U', content=[TextBlock(text='To update the "Digital Design Team" space with the new specifications, we can use the `update_space` tool from the ClickUp API. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_015BhNZMMyasFnchzQES5Tky', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1984, output_tokens=324)),
#  ToolsBetaMessage(id='msg_01FQa7PkrejG5Vh9NebaLEqE', content=[TextBlock(text="To create a new ClickUp space for the content strategy team with the specified requirements, we can use the `create_space` tool. Here's how we can invoke it:", type='text'), ToolUseBlock(id='toolu_01N4ihk94wGemwA8beJHk54d', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1948, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01HoyVK3H9b3Zstzoe6k6frF', content=[TextBlock(text='To view the list of task tags available in the ClickUp space with ID "appdev300", we can use the "get_space_tags" tool:', type='text'), ToolUseBlock(id='toolu_01QV7rv4fAsMhML6QPms86Qy', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1930, output_tokens=94)),
#  ToolsBetaMessage(id='msg_01NyXbj78z5oYPZAywYQ5kTv', content=[TextBlock(text='To add a new tag named "Urgent Discrepancy" with the specified colors to the space with ID "datamodel404", we can use the `create_space_tag` tool:', type='text'), ToolUseBlock(id='toolu_013kyMCcid3qwfWLN1p6GoUS', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1943, output_tokens=172)),
#  ToolsBetaMessage(id='msg_015zsu8tBgMUjtHMmeNxEuKv', content=[TextBlock(text='To delete the "finforecast345" space from your ClickUp workspace, we can use the "delete_space" tool. Here\'s how we can invoke it:', type='text'), ToolUseBlock(id='toolu_01MAoGMb393HPZKPyJX5NuEa', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1911, output_tokens=95)),
#  ToolsBetaMessage(id='msg_017M7okZiie5NLzkN3etvZzo', content=[TextBlock(text='To delete the "LowPriority" tag from the "gfxdes678" space, we can use the `delete_space_tag` tool. Here\'s how we invoke it:', type='text'), ToolUseBlock(id='toolu_01EJ7o3WHYXwykv55V6jK1S9', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1950, output_tokens=200)),
#  ToolsBetaMessage(id='msg_01Nx5qjPKNmqCTfrmnjnR4PN', content=[TextBlock(text='To create the new space for the Q2 Support Updates with the specified requirements, we can use the `create_space` tool:', type='text'), ToolUseBlock(id='toolu_018Wq6TrSay4js25Tyo4PXSx', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1951, output_tokens=257)),
#  ToolsBetaMessage(id='msg_019BvLrePRtNoA8ciRkx17it', content=[TextBlock(text='To retrieve the complete current configuration of the space with ID "gamedev909", you can use the "get_space" tool. Here\'s how you can invoke it:', type='text'), ToolUseBlock(id='toolu_01NKYXcYChkm8ufD5JDSUWwe', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1927, output_tokens=93)),
#  ToolsBetaMessage(id='msg_011PNTPS6AZZKGHD44nhhwTD', content=[TextBlock(text='To rename the ClickUp space with ID "mktoutreach768" to "Market Outreach 2023", set its color to navy blue ("#000080"), and make it private, we can use the "update_space" tool with the following parameters:', type='text'), ToolUseBlock(id='toolu_01PHjroZcDcCrJuk62v6mNzh', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1950, output_tokens=346)),
#  ToolsBetaMessage(id='msg_012gc4hkskaj2fecJNNpQCCx', content=[TextBlock(text='To set up the "Fall Events 2023" space for the "eventeam500" team with the specified requirements, we can use the following ClickUp tools:', type='text'), ToolUseBlock(id='toolu_019EQo7szeHNzb4d9NCCg9kv', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-sonnet-20240229', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=1965, output_tokens=265))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []


def convert_str_to_bool(nested_dict):
    for key, value in nested_dict.items():
        # If the value is a nested dictionary, recursively process it
        if isinstance(value, dict):
            convert_str_to_bool(value)
        else:
            if value == "True":
                nested_dict[key] = True
            elif value == "False":
                nested_dict[key] = False
    return nested_dict

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    llm_response_dict = convert_str_to_bool(llm_response_dict)

    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'team123'}, 'name': 'get_spaces'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#7b68ee',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContent2023',
#                'private': False,
#                'space_id': 'EMContentPlanning'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'TI_ProductLaunches'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.6

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_2 = sum(result_list)/len(result_list)
# run_acc_2

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_3 = sum(result_list)/len(result_list)
# run_acc_3

# %%
print("ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
# print(f"Run 2: {run_acc_2}")
# print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy
# =========================================
# Run 1: 0.6
