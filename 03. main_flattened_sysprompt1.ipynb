# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'name': {'type': 'string', 'description': 'The name of the new space'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['team_id', 'name', 'multiple_assignees', 'features']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'name': {'type': 'string', 'description': 'The new name of the space'},
#     'color': {'type': 'string', 'description': 'The color used for the space'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space'},
#     'features': {'type': 'object',
#      'description': 'Enabled features within the space',
#      'properties': {'due_dates': {'type': 'object',
#        'description': 'Due dates feature settings',
#        'properties': {'enabled': {'type': 'boolean'},
#         'start_date': {'type': 'boolean'},
#         'remap_due_dates': {'type': 'boolean'},
#         'remap_closed_due_date': {'type': 'boolean'}}},
#       'time_tracking': {'type': 'object',
#        'description': 'Time tracking feature settings',
#        'properties': {'enabled': {'type': 'boolean'}}}}}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to create',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete'},
#     'tag': {'type': 'object',
#      'description': 'The properties of the tag to delete',
#      'properties': {'name': {'type': 'string',
#        'description': 'The name of the tag'},
#       'tag_fg': {'type': 'string',
#        'description': 'The foreground color of the tag'},
#       'tag_bg': {'type': 'string',
#        'description': 'The background color of the tag'}}}},
#    'required': ['space_id', 'tag_name', 'tag']}}]

# %%
from pprint import pprint

def flatten_properties(schema_ariginal, path_prefix=''):
    schema = schema_ariginal.copy()
    # Base case: If the schema is not an object, return it as-is
    if schema.get('type') != 'object':
        return {path_prefix: schema}
    
    flattened = {}
    for prop, details in schema.get('properties', {}).items():
        # Construct the new path prefix based on the current location in the schema
        new_prefix = f"{path_prefix}__{prop}" if path_prefix else prop
        if "description" in details:
            details["description"] = f'{details["description"]}__{schema.get("description", "")}'
        else:
            details["description"] = f'{prop}__{schema.get("description", "")}'
            
            
        # If the property is an object, recurse, otherwise, add to the flattened dict
        if details.get('type') == 'object':
            # Merge the results of the recursive call into the flattened dict
            flattened.update(flatten_properties(details, new_prefix))
        else:
            # Directly add the property with its new path prefix
            flattened[new_prefix] = details
    
    return flattened

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}


def flatten_schema(schema):
  # Flatten the parameters schema
  flattened_parameters = flatten_properties(schema['parameters'])

  # Incorporate the flattened parameters into the original schema
  flattened_schema = {
      "name": schema['name'],
      "description": schema['description'],
      "parameters": {
          "type": "object",
          "properties": flattened_parameters,
          "required": list(flattened_parameters.keys()) #schema['parameters']['required']
      }
  }
  return flattened_schema

pprint(flatten_schema(schema[1]))
# Out:
# {'description': 'Add a new Space to a Workspace.',
#  'name': 'create_space',
#  'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The name of the new '
#                                                        'space__',
#                                         'type': 'string'},
#                                'team_id': {'description': 'The ID of the '
#                                                           'team__',
#                                            'type': 'string'}},
#                 'required': ['team_id',
#                              'name',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
from pprint import pprint

# Original schema
# schema = {'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not'}},
#    'required': ['team_id', 'archived']}}

n = 3

pprint(schema[n])
print("-------------")
pprint(flatten_schema(schema[n]))
# Out:
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space',
#                                          'type': 'string'},
#                                'features': {'description': 'Enabled features '
#                                                            'within the space',
#                                             'properties': {'due_dates': {'description': 'Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings',
#                                                                          'properties': {'enabled': {'type': 'boolean'},
#                                                                                         'remap_closed_due_date': {'type': 'boolean'},
#                                                                                         'remap_due_dates': {'type': 'boolean'},
#                                                                                         'start_date': {'type': 'boolean'}},
#                                                                          'type': 'object'},
#                                                            'time_tracking': {'description': 'Time '
#                                                                                             'tracking '
#                                                                                             'feature '
#                                                                                             'settings',
#                                                                              'properties': {'enabled': {'type': 'boolean'}},
#                                                                              'type': 'object'}},
#                                             'type': 'object'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features'],
#                 'type': 'object'}}
# -------------
# {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                 'Space.',
#  'name': 'update_space',
#  'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                    'determine '
#                                                                    'if the '
#                                                                    'administrator '
#                                                                    'can manage '
#                                                                    'the space '
#                                                                    'or not__',
#                                                     'type': 'boolean'},
#                                'color': {'description': 'The color used for '
#                                                         'the space__',
#                                          'type': 'string'},
#                                'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                'dates '
#                                                                                'feature '
#                                                                                'settings__Enabled '
#                                                                                'features '
#                                                                                'within '
#                                                                                'the '
#                                                                                'space__',
#                                                                 'type': 'boolean'},
#                                'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                              'dates '
#                                                                                              'feature '
#                                                                                              'settings__Enabled '
#                                                                                              'features '
#                                                                                              'within '
#                                                                                              'the '
#                                                                                              'space__',
#                                                                               'type': 'boolean'},
#                                'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                        'dates '
#                                                                                        'feature '
#                                                                                        'settings__Enabled '
#                                                                                        'features '
#                                                                                        'within '
#                                                                                        'the '
#                                                                                        'space__',
#                                                                         'type': 'boolean'},
#                                'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                   'dates '
#                                                                                   'feature '
#                                                                                   'settings__Enabled '
#                                                                                   'features '
#                                                                                   'within '
#                                                                                   'the '
#                                                                                   'space__',
#                                                                    'type': 'boolean'},
#                                'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                    'tracking '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                'multiple_assignees': {'description': 'Enable '
#                                                                      'or '
#                                                                      'disable '
#                                                                      'multiple '
#                                                                      'assignees '
#                                                                      'for '
#                                                                      'tasks '
#                                                                      'within '
#                                                                      'the '
#                                                                      'space__',
#                                                       'type': 'boolean'},
#                                'name': {'description': 'The new name of the '
#                                                        'space__',
#                                         'type': 'string'},
#                                'private': {'description': 'A flag to determine '
#                                                           'if the space is '
#                                                           'private or not__',
#                                            'type': 'boolean'},
#                                'space_id': {'description': 'The ID of the '
#                                                            'space__',
#                                             'type': 'string'}},
#                 'required': ['space_id',
#                              'name',
#                              'color',
#                              'private',
#                              'admin_can_manage',
#                              'multiple_assignees',
#                              'features__due_dates__enabled',
#                              'features__due_dates__start_date',
#                              'features__due_dates__remap_due_dates',
#                              'features__due_dates__remap_closed_due_date',
#                              'features__time_tracking__enabled'],
#                 'type': 'object'}}

# %%
def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_schema.json") as f:
    schema = json.load(f)
    
    
flattened_schema = [flatten_schema(sc) for sc in schema]


with open('clickup_space_flattened_schema.json', 'w') as f:
    json.dump(flattened_schema, f, indent=4, sort_keys=True)

pprint(flattened_schema)
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide '
#                                                             'whether to '
#                                                             'include archived '
#                                                             'spaces or not__',
#                                              'type': 'boolean'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id', 'archived'],
#                  'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The name of the new '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'team_id': {'description': 'The ID of the '
#                                                            'team__',
#                                             'type': 'string'}},
#                  'required': ['team_id',
#                               'name',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a '
#                  'Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to '
#                                                                     'determine '
#                                                                     'if the '
#                                                                     'administrator '
#                                                                     'can '
#                                                                     'manage '
#                                                                     'the space '
#                                                                     'or not__',
#                                                      'type': 'boolean'},
#                                 'color': {'description': 'The color used for '
#                                                          'the space__',
#                                           'type': 'string'},
#                                 'features__due_dates__enabled': {'description': 'enabled__Due '
#                                                                                 'dates '
#                                                                                 'feature '
#                                                                                 'settings__Enabled '
#                                                                                 'features '
#                                                                                 'within '
#                                                                                 'the '
#                                                                                 'space__',
#                                                                  'type': 'boolean'},
#                                 'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due '
#                                                                                               'dates '
#                                                                                               'feature '
#                                                                                               'settings__Enabled '
#                                                                                               'features '
#                                                                                               'within '
#                                                                                               'the '
#                                                                                               'space__',
#                                                                                'type': 'boolean'},
#                                 'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due '
#                                                                                         'dates '
#                                                                                         'feature '
#                                                                                         'settings__Enabled '
#                                                                                         'features '
#                                                                                         'within '
#                                                                                         'the '
#                                                                                         'space__',
#                                                                          'type': 'boolean'},
#                                 'features__due_dates__start_date': {'description': 'start_date__Due '
#                                                                                    'dates '
#                                                                                    'feature '
#                                                                                    'settings__Enabled '
#                                                                                    'features '
#                                                                                    'within '
#                                                                                    'the '
#                                                                                    'space__',
#                                                                     'type': 'boolean'},
#                                 'features__time_tracking__enabled': {'description': 'enabled__Time '
#                                                                                     'tracking '
#                                                                                     'feature '
#                                                                                     'settings__Enabled '
#                                                                                     'features '
#                                                                                     'within '
#                                                                                     'the '
#                                                                                     'space__',
#                                                                      'type': 'boolean'},
#                                 'multiple_assignees': {'description': 'Enable '
#                                                                       'or '
#                                                                       'disable '
#                                                                       'multiple '
#                                                                       'assignees '
#                                                                       'for '
#                                                                       'tasks '
#                                                                       'within '
#                                                                       'the '
#                                                                       'space__',
#                                                        'type': 'boolean'},
#                                 'name': {'description': 'The new name of the '
#                                                         'space__',
#                                          'type': 'string'},
#                                 'private': {'description': 'A flag to '
#                                                            'determine if the '
#                                                            'space is private '
#                                                            'or not__',
#                                             'type': 'boolean'},
#                                 'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'name',
#                               'color',
#                               'private',
#                               'admin_can_manage',
#                               'multiple_assignees',
#                               'features__due_dates__enabled',
#                               'features__due_dates__start_date',
#                               'features__due_dates__remap_due_dates',
#                               'features__due_dates__remap_closed_due_date',
#                               'features__time_tracking__enabled'],
#                  'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'}},
#                  'required': ['space_id'],
#                  'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'create__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'create__',
#                                                 'type': 'string'}},
#                  'required': ['space_id',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the '
#                                                             'space__',
#                                              'type': 'string'},
#                                 'tag__name': {'description': 'The name of the '
#                                                              'tag__The '
#                                                              'properties of '
#                                                              'the tag to '
#                                                              'delete__',
#                                               'type': 'string'},
#                                 'tag__tag_bg': {'description': 'The background '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag__tag_fg': {'description': 'The foreground '
#                                                                'color of the '
#                                                                'tag__The '
#                                                                'properties of '
#                                                                'the tag to '
#                                                                'delete__',
#                                                 'type': 'string'},
#                                 'tag_name': {'description': 'The name of the '
#                                                             'tag to delete__',
#                                              'type': 'string'}},
#                  'required': ['space_id',
#                               'tag_name',
#                               'tag__name',
#                               'tag__tag_fg',
#                               'tag__tag_bg'],
#                  'type': 'object'}}]

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
flattened_schema
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'parameters': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import os
import json
import dotenv
import anthropic
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()
# openai.api_key = os.getenv("OPENAI_API_KEY")

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in flattened_schema]
tools
# Out:
# [{'name': 'get_spaces',
#   'description': 'View the Spaces available in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'archived': {'type': 'boolean',
#      'description': 'A flag to decide whether to include archived spaces or not__'}},
#    'required': ['team_id', 'archived']}},
#  {'name': 'create_space',
#   'description': 'Add a new Space to a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'team_id': {'type': 'string',
#      'description': 'The ID of the team__'},
#     'name': {'type': 'string', 'description': 'The name of the new space__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'get_space',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'update_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'name': {'type': 'string', 'description': 'The new name of the space__'},
#     'color': {'type': 'string',
#      'description': 'The color used for the space__'},
#     'private': {'type': 'boolean',
#      'description': 'A flag to determine if the space is private or not__'},
#     'admin_can_manage': {'type': 'boolean',
#      'description': 'A flag to determine if the administrator can manage the space or not__'},
#     'multiple_assignees': {'type': 'boolean',
#      'description': 'Enable or disable multiple assignees for tasks within the space__'},
#     'features__due_dates__enabled': {'type': 'boolean',
#      'description': 'enabled__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__start_date': {'type': 'boolean',
#      'description': 'start_date__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_due_dates': {'type': 'boolean',
#      'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__'},
#     'features__due_dates__remap_closed_due_date': {'type': 'boolean',
#      'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__'},
#     'features__time_tracking__enabled': {'type': 'boolean',
#      'description': 'enabled__Time tracking feature settings__Enabled features within the space__'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled']}},
#  {'name': 'delete_space',
#   'description': 'Delete a Space from your Workspace.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'get_space_tags',
#   'description': 'View the task Tags available in a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'}},
#    'required': ['space_id']}},
#  {'name': 'create_space_tag',
#   'description': 'Add a new task Tag to a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to create__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to create__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to create__'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg']}},
#  {'name': 'delete_space_tag',
#   'description': 'Delete a task Tag from a Space.',
#   'input_schema': {'type': 'object',
#    'properties': {'space_id': {'type': 'string',
#      'description': 'The ID of the space__'},
#     'tag_name': {'type': 'string',
#      'description': 'The name of the tag to delete__'},
#     'tag__name': {'type': 'string',
#      'description': 'The name of the tag__The properties of the tag to delete__'},
#     'tag__tag_fg': {'type': 'string',
#      'description': 'The foreground color of the tag__The properties of the tag to delete__'},
#     'tag__tag_bg': {'type': 'string',
#      'description': 'The background color of the tag__The properties of the tag to delete__'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg']}}]

# %%
import anthropic
client = anthropic.Anthropic()

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system = """
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response #.choices[0].message.tool_calls[0].function
# Out:
# ToolsBetaMessage(id='msg_01XPMXhPzNvEwMYWpnjkcERd', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_01M3W8ZSyJiamVrv73XoQf2L', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        # response.content[1]
        # if llm_response is not None:
        #     func_name = llm_response.name
        #     func_args_dict = json.loads(llm_response.arguments)
        # else:
        #     func_name = None
        #     func_args_dict = None 
        # return {"name": func_name, "arguments": func_args_dict}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:45<00:00,  2.10s/it]
# [ToolsBetaMessage(id='msg_01Qzqo74N9N7xJ1vjTViucef', content=[TextBlock(text='Okay, let\'s use the ClickUp API to check the active spaces under the "Innovative Solutions" team.', type='text'), ToolUseBlock(id='toolu_019TiMupAMU8UmdBQTS5S2Fe', input={'team_id': 'team123', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=99)),
#  ToolsBetaMessage(id='msg_016FKGZSfxRzo5p5nK7u5HJd', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_01JtutAYGjA13y7Fg2kRAnZM', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255)),
#  ToolsBetaMessage(id='msg_01TtFJA3AXGi1GRTAD6terwi', content=[TextBlock(text='Okay, let\'s retrieve the custom tags for the ClickUp space with the ID "sd456" before archiving it.', type='text'), ToolUseBlock(id='toolu_011v1Ns78rdRzCFBJ4Fo4VUF', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2020, output_tokens=86)),
#  ToolsBetaMessage(id='msg_01KHUFWVVFQYZmeWKGeEYtvW', content=[TextBlock(text='Okay, let\'s update the tag in the "prj1122" space as requested:', type='text'), ToolUseBlock(id='toolu_015hwtztVoM9KKAG9Rdqxg3B', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2047, output_tokens=177)),
#  ToolsBetaMessage(id='msg_014fr2Zk6br6kPjmug986G2S', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" in ClickUp.', type='text'), ToolUseBlock(id='toolu_015g61qCjxC9KXFsynT7e7tc', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=182)),
#  ToolsBetaMessage(id='msg_01RbAWkt4msGWzoavE9m6CVJ', content=[TextBlock(text='Okay, let\'s update the "Backend_Development_Space" to disallow multiple assignees while keeping the other settings unchanged.', type='text'), ToolUseBlock(id='toolu_01HdE7oQ3mXU8r2r1NsVsCh9', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=311)),
#  ToolsBetaMessage(id='msg_01DsZYebVfMXYVgW7JV4883d', content=[TextBlock(text='Okay, let\'s delete the unused ClickUp space with the ID "gt678":', type='text'), ToolUseBlock(id='toolu_019pfb2zVbtcqUcwEYSneVfg', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2015, output_tokens=76)),
#  ToolsBetaMessage(id='msg_0189MzajyKac49xizSWWU5dk', content=[TextBlock(text="Okay, let's create the new space for the Design Studio 2023 project with the requested features:", type='text'), ToolUseBlock(id='toolu_014vm3ruJZcZFnx3oiRhJsGG', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=250)),
#  ToolsBetaMessage(id='msg_01M1BoWgDhHQ2Ur1c6xY9okR', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the space with ID "ep456".', type='text'), ToolUseBlock(id='toolu_014jKJsQtypMFMTTr7LH3iAB', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2010, output_tokens=81)),
#  ToolsBetaMessage(id='msg_0135rrexuSY1QLEMR4v23Lg1', content=[TextBlock(text="Okay, let's update the space for the front-end development team as per the requirements:", type='text'), ToolUseBlock(id='toolu_01EWqqd9uC4BBZ3X7UFQo6cs', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=286)),
#  ToolsBetaMessage(id='msg_01LHHTv12YgD6kEpUQodRc35', content=[TextBlock(text='Okay, let\'s update the "pd2023" space to reflect the changes Samantha would like to implement:', type='text'), ToolUseBlock(id='toolu_01WJ8smAbggRdaWT48wVAoLk', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2101, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01FTYKjpKkrgHTxspVS6wMav', content=[TextBlock(text="Okay, let's create the new space for the events management team at Glorious Events Inc. using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_01P7sJiE8yfihCZT7KMFJjnE', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2074, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01ETdWcZR1Hjw8MmyLYC7JWy', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces. Here are the steps we can take:", type='text'), ToolUseBlock(id='toolu_01ML8FitJtZRRcfdX9EEXqVs', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2033, output_tokens=110)),
#  ToolsBetaMessage(id='msg_01YKCu9MheutxMJgR2okE3Gy', content=[TextBlock(text="Okay, let's set up the new ClickUp space for Luxe Apparel's Fall Campaign 2023:", type='text'), ToolUseBlock(id='toolu_01GYvLN3BK3bd2tyaNSUmwde', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2065, output_tokens=254)),
#  ToolsBetaMessage(id='msg_01B52WHy53gGWRrcL362kLzs', content=[TextBlock(text="Okay, let's handle this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01NkNWgRiTNdz3sQJ8zdfFd5', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2057, output_tokens=173)),
#  ToolsBetaMessage(id='msg_014TvywsxBMmTMwXopRvCZTj', content=[TextBlock(text='Okay, let\'s add the new "Urgent Review" tag to the "FTProjects" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_018ATwFsrGBwz9hWuckmmYQ1', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2040, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01BRHpWN1jyccQgMwZJWAP41', content=[TextBlock(text="Okay, let's help Crystal streamline the content planning and creation process for the social media team at Echo Media.", type='text'), ToolUseBlock(id='toolu_01LJd4KCgUr9sVs7smnLYQPC', input={'team_id': 'EMContent2023', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2038, output_tokens=100)),
#  ToolsBetaMessage(id='msg_01YVzj9QYABCNMkh5EQ7jPit', content=[TextBlock(text="Okay, let's update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_011p9HRi6GDbzJoFYqV67UaA', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2117, output_tokens=300)),
#  ToolsBetaMessage(id='msg_01Kpts1PXEvABEMqpgVjYCfL', content=[TextBlock(text='Okay, let\'s get the list of tags for the "DSAnalysis" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_01EBH4fiEqhGPGBfHiVCZpCR', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=83)),
#  ToolsBetaMessage(id='msg_01Rpt2SKGJT7C1y7USAhjKze', content=[TextBlock(text='Okay, let\'s help TerraFirma get a final overview of the "TF_ProjectX" space before they phase it out. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01MHaXzK298CFNFFJGqqimCM', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2036, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01AaT3mW7aNA7HzJ9Cvgdi9f', content=[TextBlock(text='Okay, let\'s use the ClickUp API to gather the information needed for the audit of the "FI_Team2023" team\'s spaces.', type='text'), ToolUseBlock(id='toolu_01CtF48CLm3ztg7fMuUz4hUL', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2102, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01BmDdh5bdUw3rPHhMMvkhbS', content=[TextBlock(text='Okay, let\'s set up the new "Design Hub 2023" space in ClickUp to meet Vera\'s requirements:', type='text'), ToolUseBlock(id='toolu_01JLnovSvpXcuer4GQEmX2gL', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2112, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01NQFehSoqEAiaHqna2EUy1t', content=[TextBlock(text='Okay, let\'s help Jess set up the new "Priority" tag in the "WF_Content" ClickUp space:', type='text'), ToolUseBlock(id='toolu_01VcmpQYmG3H2fQ2jNvYPgfQ', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2081, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01Sk6ZvVmfy5KiPE9ubJrczT', content=[TextBlock(text="Okay, let's handle this request step-by-step using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_012BT1u8jtq1S5jWt7XES1oN', input={'space_id': 'PF_Projects'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2116, output_tokens=79)),
#  ToolsBetaMessage(id='msg_01783RtsjCrTd8uvt7QrvZ6G', content=[TextBlock(text="Okay, let's handle this step-by-step:", type='text'), ToolUseBlock(id='toolu_01YBRaWeXAnz8csVJcyEH11h', input={'space_id': 'GES_InfraDev2022', 'tag_name': 'ArchiveThis', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=169)),
#  ToolsBetaMessage(id='msg_01BAyfzWubogshh9bom98JsW', content=[TextBlock(text='Understood. Let\'s proceed with deleting the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment initiative at NexGen Solutions.', type='text'), ToolUseBlock(id='toolu_01UnWuVNG3besmMM6iozu9Dh', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2060, output_tokens=103)),
#  ToolsBetaMessage(id='msg_017Cqd7zfKL28YYszMq6g1HD', content=[TextBlock(text='Okay, let\'s get the information Linda needs to audit the tags in the "Marketing2023" space of ClickUp.', type='text'), ToolUseBlock(id='toolu_016pDnQpc2qZHx8VAVmWJFXe', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=95)),
#  ToolsBetaMessage(id='msg_01MS2edZV7kWvKbYyTfmv1dt', content=[TextBlock(text='Okay, let\'s update the "TI_ProductLaunches" space in ClickUp to meet Mitchell\'s requirements:', type='text'), ToolUseBlock(id='toolu_01RfnkSFHiyDSWUjBE4njM83', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2110, output_tokens=319)),
#  ToolsBetaMessage(id='msg_016DKE6iBtPrAhDHbsuch3jJ', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the "CS_ProjectSpace1" space so the team can make an informed decision about archiving it.', type='text'), ToolUseBlock(id='toolu_013fucKmaChRPLctziNgQrkZ', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2077, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01EU5yHeaupaVdaYjoMd7zRt', content=[TextBlock(text='Understood. Let\'s create the new "MilestoneCritical" tag within the "DigitalTrans2023" space on ClickUp to support the digital transformation team\'s needs.', type='text'), ToolUseBlock(id='toolu_01Y6rcM9uLPqccpy6PLECr9e', input={'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2105, output_tokens=185)),
#  ToolsBetaMessage(id='msg_011gxoMJTaMTkThvKVejsrKG', content=[TextBlock(text="Okay, let's create the new space for the customer success team using the ClickUp API. Here are the steps:", type='text'), ToolUseBlock(id='toolu_01GrzEyXRi3EHU7r7CH5g73L', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2064, output_tokens=256)),
#  ToolsBetaMessage(id='msg_012fS4nqntyWR5gJjKw9r1GD', content=[TextBlock(text='Okay, let\'s update the "social123" space to match the new requirements:', type='text'), ToolUseBlock(id='toolu_01LxGeGJHxh9oaAckbRCf3CH', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=303)),
#  ToolsBetaMessage(id='msg_014KdpacpufGN3yQG3j8Vj3n', content=[TextBlock(text='Okay, let\'s remove the unused "OldCampaign" tag from the "branddept301" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01FoM7djpMS39pREHJjji54c', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2052, output_tokens=189)),
#  ToolsBetaMessage(id='msg_015kzRfq9yCuqxALNFGRH9KR', content=[TextBlock(text='Okay, let\'s set up the new "Time-Sensitive" tag in the ClickUp space for the engineering team.', type='text'), ToolUseBlock(id='toolu_015gdXw3AASRrsb9mZW1rAXt', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2050, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01PLmmboPv1y1KGn7ZeBPWWY', content=[TextBlock(text='Okay, let\'s remove the "BetaFeature" tag from the "proddev808" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01MUVgTCXiVXmGd4fQHtv3Ju', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2043, output_tokens=182)),
#  ToolsBetaMessage(id='msg_018nH7z7qFZvyZTKWsPPPMHy', content=[TextBlock(text='Okay, let\'s set up the new "Employee Relations" space for the HR department in ClickUp:', type='text'), ToolUseBlock(id='toolu_01QW7XRh1BZk2oB6sbQojdAU', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01C4btfz7mfdw8aTu6ik3ovB', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve all the information from the "ecominv500" space dedicated to inventory management.', type='text'), ToolUseBlock(id='toolu_011MVxKqbZCqGPyvkNbBSwKN', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2009, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01AMJwdXt7W6y3gXjUenHWQJ', content=[TextBlock(text="Okay, let's handle the decommissioning of the old ClickUp space for the facility upgrades:", type='text'), ToolUseBlock(id='toolu_01SYhNLk1SYatFxGHitbyFmq', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2012, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01HPd47bZXYFGcaraZAtjWd8', content=[TextBlock(text="Okay, let's help Natalie set up the new ClickUp space for the community outreach projects:", type='text'), ToolUseBlock(id='toolu_01LqQa6xS3K3HC2tnwFpkPYx', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=254)),
#  ToolsBetaMessage(id='msg_014ZqygpJbgjSeK4YdFSC9Vv', content=[TextBlock(text="Okay, let's update the ClickUp space as requested:", type='text'), ToolUseBlock(id='toolu_01XL6uegqiTbhtk5GivXC4dn', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2045, output_tokens=299)),
#  ToolsBetaMessage(id='msg_01UNMqXAFj6ynPdmAQtQnsof', content=[TextBlock(text='Okay, let\'s update the "Digital Design Team" space in ClickUp to meet Samantha\'s requirements:', type='text'), ToolUseBlock(id='toolu_013YedVyW73iPJkn52YR3124', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2089, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01X78aFVL4MXbkEdMpx3rt6w', content=[TextBlock(text="Okay, let's set up the new space for the content strategy team based on your requirements:", type='text'), ToolUseBlock(id='toolu_01Qunek9CfXJ1JGeJoYSVykD', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2053, output_tokens=249)),
#  ToolsBetaMessage(id='msg_01E5iZmqwG4e2kA735jRdKyJ', content=[TextBlock(text='Okay, let\'s gather the information about the tags currently in use within the ClickUp development space with the ID "appdev300":', type='text'), ToolUseBlock(id='toolu_019eDGqqDf3LvLUWTstzdwv2', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=89)),
#  ToolsBetaMessage(id='msg_012ddrgamwTSyVxC1WB1EWFS', content=[TextBlock(text='Okay, let\'s create the new tag for the "datamodel404" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_01FXHcEtLowuevZBSVSaLh7R', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2048, output_tokens=153)),
#  ToolsBetaMessage(id='msg_01UH943gMD514FHwGnvghFGQ', content=[TextBlock(text='Okay, let\'s delete the "finforecast345" space from the ClickUp workspace. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01GaJSr9zZVRvfXWuWEKseB6', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2016, output_tokens=85)),
#  ToolsBetaMessage(id='msg_014KbqbVK61uJ3gAzqkRw2KN', content=[TextBlock(text='Okay, let\'s help Alex remove the "LowPriority" tag from the "gfxdes678" space:', type='text'), ToolUseBlock(id='toolu_01Kv9kAd8HUsjPqmUX5cYGZ2', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=186)),
#  ToolsBetaMessage(id='msg_01A4f7x7uvA9Zfg45GsxMgBM', content=[TextBlock(text="Okay, let's create the new space for the Q2 Support Updates team:", type='text'), ToolUseBlock(id='toolu_013PdXLsYzTu9aCDxtGiB8vY', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2056, output_tokens=247)),
#  ToolsBetaMessage(id='msg_01VLqwG4cxoEFXER3SLb6RkU', content=[TextBlock(text='Okay, let\'s retrieve the details of the ClickUp space with the ID "gamedev909" so the manager can review the current configuration before archiving it.', type='text'), ToolUseBlock(id='toolu_01ED1u4UjCrr6FcRGT26q5jD', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01Qqawm2rxaLPq3Jt2aAEjcb', content=[TextBlock(text='Okay, let\'s update the "Market Outreach 2023" space as requested:', type='text'), ToolUseBlock(id='toolu_01N9rdKsCUcdRpmZ7Teq2qsE', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01WvuzW6PBhgqQNKn9N1Ac2P', content=[TextBlock(text="Okay, let's set up the dedicated ClickUp space for the Fall Events 2023 as per the requirements:", type='text'), ToolUseBlock(id='toolu_01AE9PUPQp1X4HmWic8RzPwH', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2070, output_tokens=255))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'EMContent2023'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.54

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:46<00:00,  2.13s/it]
# [ToolsBetaMessage(id='msg_01LAec9zGGseMuBkHw7ZASiz', content=[TextBlock(text='Okay, let\'s use the ClickUp API to check the active spaces under the "Innovative Solutions" team.', type='text'), ToolUseBlock(id='toolu_018MndyCJiBPU9xgt3Rxpnxj', input={'team_id': 'team123', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=99)),
#  ToolsBetaMessage(id='msg_01ABWaAdDZwAcQkytumMZKPL', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_01SQvmsPi3SrGak9Xg9h5tWi', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255)),
#  ToolsBetaMessage(id='msg_01Xt8umMMYUjeUAwxRkGiNuM', content=[TextBlock(text='Okay, let\'s retrieve the custom tags for the ClickUp space with the ID "sd456" before archiving it.', type='text'), ToolUseBlock(id='toolu_01Wui37XhAhqM3auMt6F46sV', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2020, output_tokens=86)),
#  ToolsBetaMessage(id='msg_013JescCeqRPCHrmtGTd74SZ', content=[TextBlock(text='Okay, let\'s update the tag in the "prj1122" space as requested:', type='text'), ToolUseBlock(id='toolu_017Mvqvc8XBVzrTyRCLFEqo3', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2047, output_tokens=177)),
#  ToolsBetaMessage(id='msg_011hUb9ziHTnDMLL8KyqNGYj', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" in ClickUp.', type='text'), ToolUseBlock(id='toolu_01YDSGLkWQvajwsPUGXmYWWh', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=182)),
#  ToolsBetaMessage(id='msg_01F9732azpjwHkFtnEc89jjn', content=[TextBlock(text='Okay, let\'s update the "Backend_Development_Space" to disallow multiple assignees while keeping the other settings unchanged.', type='text'), ToolUseBlock(id='toolu_01ASRYpTMypY1spXaKSjfysC', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=311)),
#  ToolsBetaMessage(id='msg_01BpoFtE3WnZKrvrnVmUK3Lu', content=[TextBlock(text='Okay, let\'s delete the unused ClickUp space with the ID "gt678":', type='text'), ToolUseBlock(id='toolu_01MGRFj9yuwDrF2vT7iHtb55', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2015, output_tokens=76)),
#  ToolsBetaMessage(id='msg_017fhAFF8MVuGPcDUwJrBNA3', content=[TextBlock(text="Okay, let's create the new space for the Design Studio 2023 project with the requested features:", type='text'), ToolUseBlock(id='toolu_01LU1YccoaHDgnVoLm5v4UnE', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=250)),
#  ToolsBetaMessage(id='msg_019bccyJHEDNL9P66VHZWBMk', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the space with ID "ep456".', type='text'), ToolUseBlock(id='toolu_01DekTmRq7HSNwg2JonoPavL', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2010, output_tokens=81)),
#  ToolsBetaMessage(id='msg_01VwZwY4ecFtLXM7exGHA8Za', content=[TextBlock(text="Okay, let's update the space for the front-end development team as per the requirements:", type='text'), ToolUseBlock(id='toolu_011uKVcHBJNB7vhyFNiJx21J', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=286)),
#  ToolsBetaMessage(id='msg_01F9xGJfHkQWKPPkeZf95pTG', content=[TextBlock(text='Okay, let\'s update the "pd2023" space to reflect the changes Samantha would like to implement:', type='text'), ToolUseBlock(id='toolu_011bJCYXoiC1X3caJ46AfPuz', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2101, output_tokens=313)),
#  ToolsBetaMessage(id='msg_014QB67JvQRHX95rHrsCaUZW', content=[TextBlock(text="Okay, let's create the new space for the events management team at Glorious Events Inc. using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_017t8fXvV1p6gNVgRhZ4oqxo', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2074, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01JRfn69QQvh9cwwAuBYrguj', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces. Here are the steps we can take:", type='text'), ToolUseBlock(id='toolu_01AaXxHFwCNjTKGnPwyTahDF', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2033, output_tokens=110)),
#  ToolsBetaMessage(id='msg_01Xd1jqDvo3cLiS4Y9taRR1H', content=[TextBlock(text="Okay, let's set up the new ClickUp space for Luxe Apparel's Fall Campaign 2023:", type='text'), ToolUseBlock(id='toolu_016aS1TiAKxnJe2SC7MNSYwa', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2065, output_tokens=254)),
#  ToolsBetaMessage(id='msg_01J6s8ymGn2mN3dqgzZdUkpk', content=[TextBlock(text="Okay, let's handle this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01B8ZMo9ZxEairF2s67YvFmz', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2057, output_tokens=173)),
#  ToolsBetaMessage(id='msg_01NCKroYFTDRvwuYCTtzJURw', content=[TextBlock(text='Okay, let\'s add the new "Urgent Review" tag to the "FTProjects" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_011WpHFxzarjaDxzPMUeMWKv', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2040, output_tokens=157)),
#  ToolsBetaMessage(id='msg_016rkyUTCLyzaJW2pHFLtUcn', content=[TextBlock(text="Okay, let's help Crystal streamline the content planning and creation process for the social media team at Echo Media.", type='text'), ToolUseBlock(id='toolu_01ECYw9jQVTqRXTbDGf2jyv8', input={'team_id': 'EMContent2023', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2038, output_tokens=100)),
#  ToolsBetaMessage(id='msg_015YHgFuk3PdL79k3ppmmYBR', content=[TextBlock(text="Okay, let's update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01NRFnq77mbZhRLJCpv3osRK', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2117, output_tokens=300)),
#  ToolsBetaMessage(id='msg_01BCFrtrCDnmfE5WcBwsAQBr', content=[TextBlock(text='Okay, let\'s get the list of tags for the "DSAnalysis" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_015uhQC5t5RwguxRZirgGf3y', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=83)),
#  ToolsBetaMessage(id='msg_019Uo6Qwy8zTCQP4N2npvn1p', content=[TextBlock(text='Okay, let\'s help TerraFirma get a final overview of the "TF_ProjectX" space before they phase it out. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01TcKUHvCGUK2DMJhU42qTCi', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2036, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01Pas3axQ4kWtPLiQ3dWRAuz', content=[TextBlock(text='Okay, let\'s use the ClickUp API to gather the information needed for the audit of the "FI_Team2023" team\'s spaces.', type='text'), ToolUseBlock(id='toolu_01KetaqrcVGVErMeY7UERAc1', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2102, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01NshzCCbCVZiRXr65DicPEN', content=[TextBlock(text='Okay, let\'s set up the new "Design Hub 2023" space in ClickUp to meet Vera\'s requirements:', type='text'), ToolUseBlock(id='toolu_01R3UdZVFa1isFvWpKu6KMHF', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2112, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01JnPPzGdyYt8jXWvhA1R3YB', content=[TextBlock(text='Okay, let\'s help Jess set up the new "Priority" tag in the "WF_Content" ClickUp space:', type='text'), ToolUseBlock(id='toolu_01HCyprK31ro4xwkA1iesSp5', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2081, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01BgTdQQ8hVcLCN24ySEk75i', content=[TextBlock(text="Okay, let's handle this request step-by-step using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_01NcWUx7q2utnKkmgbuqHAiD', input={'space_id': 'PF_Projects'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2116, output_tokens=79)),
#  ToolsBetaMessage(id='msg_013MaagbL1Rz2ceNZDGYmekm', content=[TextBlock(text="Okay, let's handle this step-by-step:", type='text'), ToolUseBlock(id='toolu_0118b2LRVxSqF6zcLaaYgTo7', input={'space_id': 'GES_InfraDev2022', 'tag_name': 'ArchiveThis', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=169)),
#  ToolsBetaMessage(id='msg_01NsczD5zvAKnSQLpcuCXWx9', content=[TextBlock(text='Understood. Let\'s proceed with deleting the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment initiative at NexGen Solutions.', type='text'), ToolUseBlock(id='toolu_015pAQcGyWodyxT7P42ohzcA', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2060, output_tokens=103)),
#  ToolsBetaMessage(id='msg_01HzPTin1qoHKqwKiHxmV8QG', content=[TextBlock(text='Okay, let\'s get the information Linda needs to audit the tags in the "Marketing2023" space of ClickUp.', type='text'), ToolUseBlock(id='toolu_013DUoT9jwgZThMfo6RFoXRD', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=95)),
#  ToolsBetaMessage(id='msg_017wrSTn5fsRTtNbT3Bt74N3', content=[TextBlock(text='Okay, let\'s update the "TI_ProductLaunches" space in ClickUp to meet Mitchell\'s requirements:', type='text'), ToolUseBlock(id='toolu_01S2pdZ4N5qKKcp9GcuLZZii', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2110, output_tokens=319)),
#  ToolsBetaMessage(id='msg_011eKgT6J2rs2RggS2WSW3N7', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the "CS_ProjectSpace1" space so the team can make an informed decision about archiving it.', type='text'), ToolUseBlock(id='toolu_01DmXRE9AA5JP6yweKpXwx6b', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2077, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01Ez5dazJq5HRTuz6FGssucu', content=[TextBlock(text='Understood. Let\'s create the new "MilestoneCritical" tag within the "DigitalTrans2023" space on ClickUp to support the digital transformation team\'s needs.', type='text'), ToolUseBlock(id='toolu_01ST3gWgdQtxqGfjqMZgQ5B4', input={'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2105, output_tokens=185)),
#  ToolsBetaMessage(id='msg_015uiRFXwY3ee6x21JL4siaw', content=[TextBlock(text="Okay, let's create the new space for the customer success team using the ClickUp API. Here are the steps:", type='text'), ToolUseBlock(id='toolu_01V8josNE5w6G38fZ4qTxRfQ', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2064, output_tokens=256)),
#  ToolsBetaMessage(id='msg_014c75NZsUDBUJ2p6KxYXb1R', content=[TextBlock(text='Okay, let\'s update the "social123" space to match the new requirements:', type='text'), ToolUseBlock(id='toolu_01Fg9cTsgJ49xixJvLA5uL25', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=303)),
#  ToolsBetaMessage(id='msg_01V8FQ6t3fG2PspeEcmdZ3D4', content=[TextBlock(text='Okay, let\'s remove the unused "OldCampaign" tag from the "branddept301" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01NwJwTKBte6yvy6kJHcgQpQ', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2052, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01YCPu9optZQo56Z2nwhd5FK', content=[TextBlock(text='Okay, let\'s set up the new "Time-Sensitive" tag in the ClickUp space for the engineering team.', type='text'), ToolUseBlock(id='toolu_01BvGz8GdgFiVbQWjpRukR3U', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2050, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01MV1xB3e4v62gKitpfPVbkL', content=[TextBlock(text='Okay, let\'s remove the "BetaFeature" tag from the "proddev808" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01MtUzTeG393gUWW56p8wyzR', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2043, output_tokens=182)),
#  ToolsBetaMessage(id='msg_01RTLbs2iVKktYMB4H9aFCJg', content=[TextBlock(text='Okay, let\'s set up the new "Employee Relations" space for the HR department in ClickUp:', type='text'), ToolUseBlock(id='toolu_019ZzfJKbmz5BENKuU1kroVu', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01SkWYAa2vwTEhQfrn26tPEh', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve all the information from the "ecominv500" space dedicated to inventory management.', type='text'), ToolUseBlock(id='toolu_01JvAagnNQLSfaDUFbU93iaP', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2009, output_tokens=89)),
#  ToolsBetaMessage(id='msg_019amD6Y2GfAXt9apMwH5P9H', content=[TextBlock(text="Okay, let's handle the decommissioning of the old ClickUp space for the facility upgrades:", type='text'), ToolUseBlock(id='toolu_01YNrVSYaAGKFoTGkKv4YoLg', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2012, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01AuVAdzf44Bs5kN4RCC4aa3', content=[TextBlock(text="Okay, let's help Natalie set up the new ClickUp space for the community outreach projects:", type='text'), ToolUseBlock(id='toolu_01S6836Ev97eSsrsuxghVA4r', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=254)),
#  ToolsBetaMessage(id='msg_01UPVWxooLnkgRLdLXkkS5e5', content=[TextBlock(text="Okay, let's update the ClickUp space as requested:", type='text'), ToolUseBlock(id='toolu_018UbXabfFJGicpVLaSdyYnR', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2045, output_tokens=299)),
#  ToolsBetaMessage(id='msg_01XfE4Sq7ZjVbt3dBdQ4zujR', content=[TextBlock(text='Okay, let\'s update the "Digital Design Team" space in ClickUp to meet Samantha\'s requirements:', type='text'), ToolUseBlock(id='toolu_01C8goVA6kceJTC2TJAnqaVc', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2089, output_tokens=310)),
#  ToolsBetaMessage(id='msg_018MWVuEfFKMVwXwrFLm9Dvo', content=[TextBlock(text="Okay, let's set up the new space for the content strategy team based on your requirements:", type='text'), ToolUseBlock(id='toolu_01Du2VGphYuT3krEJp7G7SEZ', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2053, output_tokens=249)),
#  ToolsBetaMessage(id='msg_01PkpBYQt1gVMhufaroiwLjv', content=[TextBlock(text='Okay, let\'s gather the information about the tags currently in use within the ClickUp development space with the ID "appdev300":', type='text'), ToolUseBlock(id='toolu_01Dq5Gyb9uVeEzYiRyMfRodL', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01X7Ev83q5ueEGUAapKgpwCN', content=[TextBlock(text='Okay, let\'s create the new tag for the "datamodel404" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_01RssoXNZ6d3a7kXS8Fm5sn8', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2048, output_tokens=153)),
#  ToolsBetaMessage(id='msg_01EyMqDSihEtpntxyALuYEyT', content=[TextBlock(text='Okay, let\'s delete the "finforecast345" space from the ClickUp workspace. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01Mx13vpt7np9px2MXmfqmoZ', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2016, output_tokens=85)),
#  ToolsBetaMessage(id='msg_01PnwTw3nBvcBNdEtGFNTF5p', content=[TextBlock(text='Okay, let\'s help Alex remove the "LowPriority" tag from the "gfxdes678" space:', type='text'), ToolUseBlock(id='toolu_016Mvn7UDqLanpRDt5KGDBqz', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=186)),
#  ToolsBetaMessage(id='msg_01T5XSZ7td826MMuwqbu2Bgx', content=[TextBlock(text="Okay, let's create the new space for the Q2 Support Updates team:", type='text'), ToolUseBlock(id='toolu_01GQH7motasDc1uQ7ah7uQe5', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2056, output_tokens=247)),
#  ToolsBetaMessage(id='msg_01VZmVXuL5EFVoM6ewptjrZx', content=[TextBlock(text='Okay, let\'s retrieve the details of the ClickUp space with the ID "gamedev909" so the manager can review the current configuration before archiving it.', type='text'), ToolUseBlock(id='toolu_01EwsoyLc6efyPggopMYFAz5', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01HAZcMdvx3TtNbZKvLsj5er', content=[TextBlock(text='Okay, let\'s update the "Market Outreach 2023" space as requested:', type='text'), ToolUseBlock(id='toolu_011hnbLJLQV9wFCqxHRavH2f', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01DAXDTZ67ihiuiSTv3Jt3ds', content=[TextBlock(text="Okay, let's set up the dedicated ClickUp space for the Fall Events 2023 as per the requirements:", type='text'), ToolUseBlock(id='toolu_01PJP6hKPtgPmKWiQ3KV6Pya', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2070, output_tokens=255))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_2 = sum(result_list)/len(result_list)
run_acc_2
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'EMContent2023'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.54

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:46<00:00,  2.13s/it]
# [ToolsBetaMessage(id='msg_01FBuSnJWRK7QKZKZBH74MH8', content=[TextBlock(text='Okay, let\'s use the ClickUp API to check the active spaces under the "Innovative Solutions" team.', type='text'), ToolUseBlock(id='toolu_01NxGoWZ1PVUGQd56Sru8gjt', input={'team_id': 'team123', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=99)),
#  ToolsBetaMessage(id='msg_01NERCGgPvqJkUxz7UhfRanA', content=[TextBlock(text='Okay, let\'s set up the new project space for the "Creative Minds" team as per Ella\'s requirements:', type='text'), ToolUseBlock(id='toolu_012Qye2nzhNMnEhDBVSgG758', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=255)),
#  ToolsBetaMessage(id='msg_01VyohAhsvusxPe6g8BEgKYx', content=[TextBlock(text='Okay, let\'s retrieve the custom tags for the ClickUp space with the ID "sd456" before archiving it.', type='text'), ToolUseBlock(id='toolu_01MQREuCxwMtAVMReNUqprMS', input={'space_id': 'sd456'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2020, output_tokens=86)),
#  ToolsBetaMessage(id='msg_01K7k2K56e6eanzjLXo5ckVF', content=[TextBlock(text='Okay, let\'s update the tag in the "prj1122" space as requested:', type='text'), ToolUseBlock(id='toolu_01Ky62RyFYM3aBJMEJnsjYuP', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2047, output_tokens=177)),
#  ToolsBetaMessage(id='msg_016A7u4J5yDv14HUB9nUtQi4', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the space with ID "qa789" in ClickUp.', type='text'), ToolUseBlock(id='toolu_0148Ki1tM8pJnWXXAkN4M3dH', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=182)),
#  ToolsBetaMessage(id='msg_0147JoGfn8dqWZGHgxqVvY3S', content=[TextBlock(text='Okay, let\'s update the "Backend_Development_Space" to disallow multiple assignees while keeping the other settings unchanged.', type='text'), ToolUseBlock(id='toolu_01HWnNuFchb7HdUwR2kigRAt', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=311)),
#  ToolsBetaMessage(id='msg_016seDS58wKbbJv5QZkmwCp3', content=[TextBlock(text='Okay, let\'s delete the unused ClickUp space with the ID "gt678":', type='text'), ToolUseBlock(id='toolu_01EUstgEedGyR7nM8z3ZdH42', input={'space_id': 'gt678'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2015, output_tokens=76)),
#  ToolsBetaMessage(id='msg_01KUtGJ1qpTZSmx3SuPXAoqm', content=[TextBlock(text="Okay, let's create the new space for the Design Studio 2023 project with the requested features:", type='text'), ToolUseBlock(id='toolu_01FCodb7tdGV9XXwYVn2BQDG', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2026, output_tokens=250)),
#  ToolsBetaMessage(id='msg_01SNMekWFF7LRZy5jDzTbbzm', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the space with ID "ep456".', type='text'), ToolUseBlock(id='toolu_01MJeTYvgsnsN8Steyd6vKNT', input={'space_id': 'ep456'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2010, output_tokens=81)),
#  ToolsBetaMessage(id='msg_01XKcWxNk5Gr8TtyQi6QmU2n', content=[TextBlock(text="Okay, let's update the space for the front-end development team as per the requirements:", type='text'), ToolUseBlock(id='toolu_019uSbuafmE5qbA6UmPwr7L5', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=286)),
#  ToolsBetaMessage(id='msg_015mGEoPNfjZb6ETGSRsvQJH', content=[TextBlock(text='Okay, let\'s update the "pd2023" space to reflect the changes Samantha would like to implement:', type='text'), ToolUseBlock(id='toolu_01Lp1rXM1wFo8t52THT6WFNV', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2101, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01AtRJRGroghBk97SMec8Dd4', content=[TextBlock(text="Okay, let's create the new space for the events management team at Glorious Events Inc. using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_01V2HgQY8WftWcZ9AisfytYG', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2074, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01Koa1dBCFXzsr4r91QkhWEH', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces. Here are the steps we can take:", type='text'), ToolUseBlock(id='toolu_01L1gmj9kitaDm55j8dmV8vQ', input={'team_id': 'it7890', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2033, output_tokens=110)),
#  ToolsBetaMessage(id='msg_01P2pE6S6rbrkDpomwJ55i2D', content=[TextBlock(text="Okay, let's set up the new ClickUp space for Luxe Apparel's Fall Campaign 2023:", type='text'), ToolUseBlock(id='toolu_01PHMhjXFGVo27A4n6AyymkD', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2065, output_tokens=254)),
#  ToolsBetaMessage(id='msg_01BPi8xKDCk6eqVbxX537Jjg', content=[TextBlock(text="Okay, let's handle this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01FqLM88JHwUrAqDnmvvHkje', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2057, output_tokens=173)),
#  ToolsBetaMessage(id='msg_01K8MLQDRvyVqrqRmTciKp3Q', content=[TextBlock(text='Okay, let\'s add the new "Urgent Review" tag to the "FTProjects" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_01LjZcYgrnwcBfijbojRwaXL', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2040, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01ULD2C8V6PNKCD6H414nUdj', content=[TextBlock(text="Okay, let's help Crystal streamline the content planning and creation process for the social media team at Echo Media.", type='text'), ToolUseBlock(id='toolu_01QruuamD68c7XXgCSiHxYYh', input={'team_id': 'EMContent2023', 'archived': False}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2038, output_tokens=100)),
#  ToolsBetaMessage(id='msg_0192AmGnReo31wNCKrq6LRGE', content=[TextBlock(text="Okay, let's update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_0151N8JLAGoKYfdg8Uo9cXA4', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2117, output_tokens=300)),
#  ToolsBetaMessage(id='msg_01Tbd3bgaABpMFvAeFgbGqUg', content=[TextBlock(text='Okay, let\'s get the list of tags for the "DSAnalysis" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_0187nrFawTmsEu9VNk12sHGN', input={'space_id': 'DSAnalysis'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=83)),
#  ToolsBetaMessage(id='msg_011ZtZFonhdKUxwRkbDB6hm1', content=[TextBlock(text='Okay, let\'s help TerraFirma get a final overview of the "TF_ProjectX" space before they phase it out. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01F5GgyjsJkrFuMKhTKBVzuU', input={'space_id': 'TF_ProjectX'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2036, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01MHbiJN5392zzEz78t5gMFw', content=[TextBlock(text='Okay, let\'s use the ClickUp API to gather the information needed for the audit of the "FI_Team2023" team\'s spaces.', type='text'), ToolUseBlock(id='toolu_01A9bHmUpTzeqoRXkgLAqzti', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_spaces', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2102, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01QfTEsRvPY5GWVDweVCeBZw', content=[TextBlock(text='Okay, let\'s set up the new "Design Hub 2023" space in ClickUp to meet Vera\'s requirements:', type='text'), ToolUseBlock(id='toolu_018MRSTAUxiQRoEo5pEC9Y5L', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2112, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01Nn5mqWTuiMg5HH3FjLYjtm', content=[TextBlock(text='Okay, let\'s help Jess set up the new "Priority" tag in the "WF_Content" ClickUp space:', type='text'), ToolUseBlock(id='toolu_01B9RQAQut7oZjDj55Lk664i', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2081, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01WxKR4duVWFheQZ6MFNk6qY', content=[TextBlock(text="Okay, let's handle this request step-by-step using the ClickUp API:", type='text'), ToolUseBlock(id='toolu_01Wdab9xeWLYEostEEahwAft', input={'space_id': 'PF_Projects'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2116, output_tokens=79)),
#  ToolsBetaMessage(id='msg_01RUgDWMZGUj5ofmYtNo87LP', content=[TextBlock(text="Okay, let's handle this step-by-step:", type='text'), ToolUseBlock(id='toolu_014jWWEXhMjTjXY8XroymoAg', input={'space_id': 'GES_InfraDev2022', 'tag_name': 'ArchiveThis', 'tag__name': 'ArchiveThis', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=169)),
#  ToolsBetaMessage(id='msg_0133RQEQHa7LWdiAutVpmi9G', content=[TextBlock(text='Understood. Let\'s proceed with deleting the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment initiative at NexGen Solutions.', type='text'), ToolUseBlock(id='toolu_014eVtVh6ArGcYRqRdjLngGc', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2060, output_tokens=103)),
#  ToolsBetaMessage(id='msg_01FbDnvkF9PrkssXxgoCxKB8', content=[TextBlock(text='Okay, let\'s get the information Linda needs to audit the tags in the "Marketing2023" space of ClickUp.', type='text'), ToolUseBlock(id='toolu_01Eb8pxUAZ5D9ZFz8UCcAY3r', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2069, output_tokens=95)),
#  ToolsBetaMessage(id='msg_01B4HeJD4zCFQPUCRvsirs9a', content=[TextBlock(text='Okay, let\'s update the "TI_ProductLaunches" space in ClickUp to meet Mitchell\'s requirements:', type='text'), ToolUseBlock(id='toolu_01Rnc33EdDreXGNvseHDHFn1', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2110, output_tokens=319)),
#  ToolsBetaMessage(id='msg_01SbE5FiZPVVQxCSbmSqJX6Q', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve the details of the "CS_ProjectSpace1" space so the team can make an informed decision about archiving it.', type='text'), ToolUseBlock(id='toolu_015TyGxYeutSLCL67aLFWyzi', input={'space_id': 'CS_ProjectSpace1'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2077, output_tokens=98)),
#  ToolsBetaMessage(id='msg_013ki5YvjeuUysdJU6R1rq4d', content=[TextBlock(text='Understood. Let\'s create the new "MilestoneCritical" tag within the "DigitalTrans2023" space on ClickUp to support the digital transformation team\'s needs.', type='text'), ToolUseBlock(id='toolu_011CUkE24YqXVMbEr2xhQ3DA', input={'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023', 'tag__name': 'MilestoneCritical', 'tag__tag_bg': '#00008B', 'tag__tag_fg': '#FFFFFF'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2105, output_tokens=185)),
#  ToolsBetaMessage(id='msg_01CCnWr3SD1ZhYt7gG8n25DF', content=[TextBlock(text="Okay, let's create the new space for the customer success team using the ClickUp API. Here are the steps:", type='text'), ToolUseBlock(id='toolu_01GPnaFom4mh5x8HnV4aQJUa', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2064, output_tokens=256)),
#  ToolsBetaMessage(id='msg_01Lcv6FTixmX2Wryiu2jZied', content=[TextBlock(text='Okay, let\'s update the "social123" space to match the new requirements:', type='text'), ToolUseBlock(id='toolu_01A5ZQTai9y63MngHvReEzbD', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=303)),
#  ToolsBetaMessage(id='msg_01R3KqDmdK8254KaCtd57urY', content=[TextBlock(text='Okay, let\'s remove the unused "OldCampaign" tag from the "branddept301" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01MQffhfk2cFAzaFUi5JVe7t', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2052, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01LByknwof7dnxr1gpEHFUro', content=[TextBlock(text='Okay, let\'s set up the new "Time-Sensitive" tag in the ClickUp space for the engineering team.', type='text'), ToolUseBlock(id='toolu_01WtET4K2uc1UaVnVwS7C3uc', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2050, output_tokens=157)),
#  ToolsBetaMessage(id='msg_01QW9cfb4pQzwwwbwqhZsxUm', content=[TextBlock(text='Okay, let\'s remove the "BetaFeature" tag from the "proddev808" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01TfHyxWpwaCD9oBCbN5dcs2', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2043, output_tokens=182)),
#  ToolsBetaMessage(id='msg_01GiAadTspfXPDcFWsw3U5pL', content=[TextBlock(text='Okay, let\'s set up the new "Employee Relations" space for the HR department in ClickUp:', type='text'), ToolUseBlock(id='toolu_01ANaAFjqQcb3GxUdkAzMfpi', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2042, output_tokens=266)),
#  ToolsBetaMessage(id='msg_01DWej9E7rbzPje3NBEytfsr', content=[TextBlock(text='Okay, let\'s use the ClickUp API to retrieve all the information from the "ecominv500" space dedicated to inventory management.', type='text'), ToolUseBlock(id='toolu_01HqenfNFbhJusyV2Neb5AR8', input={'space_id': 'ecominv500'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2009, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01HwJYktBYE1AkBZ1icezJ11', content=[TextBlock(text="Okay, let's handle the decommissioning of the old ClickUp space for the facility upgrades:", type='text'), ToolUseBlock(id='toolu_01SzivQNq2kxUn57NmHx1ZoV', input={'space_id': 'eduop876'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2012, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01VCkZDeRNV73qFEP1VVaGjW', content=[TextBlock(text="Okay, let's help Natalie set up the new ClickUp space for the community outreach projects:", type='text'), ToolUseBlock(id='toolu_01Bk5Ysgz47ZqY71evsixrfb', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2046, output_tokens=254)),
#  ToolsBetaMessage(id='msg_01D1WHiuwJHkXy7mw9N6fh8i', content=[TextBlock(text="Okay, let's update the ClickUp space as requested:", type='text'), ToolUseBlock(id='toolu_01RoL8ikpVq1uKe412Bm5WTA', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2045, output_tokens=299)),
#  ToolsBetaMessage(id='msg_01SQHLYeD6mJ9qejSZJhJYLK', content=[TextBlock(text='Okay, let\'s update the "Digital Design Team" space in ClickUp to meet Samantha\'s requirements:', type='text'), ToolUseBlock(id='toolu_01GFVsy3XU4butdmUHo2vZ9j', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2089, output_tokens=310)),
#  ToolsBetaMessage(id='msg_01YSJWWdhZMjCBrQGv5V7ApG', content=[TextBlock(text="Okay, let's set up the new space for the content strategy team based on your requirements:", type='text'), ToolUseBlock(id='toolu_0129tsi9RgitffBm87Kp3zAj', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2053, output_tokens=249)),
#  ToolsBetaMessage(id='msg_017NagGcpqyiAMJmoDMi6JFY', content=[TextBlock(text='Okay, let\'s gather the information about the tags currently in use within the ClickUp development space with the ID "appdev300":', type='text'), ToolUseBlock(id='toolu_01AyLg2LoLhRyZi4kyHhtPxM', input={'space_id': 'appdev300'}, name='get_space_tags', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2035, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01Fb5EFNPuHcUfyjevyZHrys', content=[TextBlock(text='Okay, let\'s create the new tag for the "datamodel404" space in ClickUp:', type='text'), ToolUseBlock(id='toolu_016YzEAFF7fzV3UDKP5ZYp6p', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='create_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2048, output_tokens=153)),
#  ToolsBetaMessage(id='msg_01TUagMfFaH6HFqEZ58d9cUh', content=[TextBlock(text='Okay, let\'s delete the "finforecast345" space from the ClickUp workspace. Here are the steps:', type='text'), ToolUseBlock(id='toolu_01VbPwhE5yEPQJVZKQN8MyM9', input={'space_id': 'finforecast345'}, name='delete_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2016, output_tokens=85)),
#  ToolsBetaMessage(id='msg_011nQZQiK5z7heRoWrNKVys9', content=[TextBlock(text='Okay, let\'s help Alex remove the "LowPriority" tag from the "gfxdes678" space:', type='text'), ToolUseBlock(id='toolu_01CDw2PkGW8V959Rz93KvVcM', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='delete_space_tag', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=186)),
#  ToolsBetaMessage(id='msg_01CkmS54uZpPVAD5rtiA2aUt', content=[TextBlock(text="Okay, let's create the new space for the Q2 Support Updates team:", type='text'), ToolUseBlock(id='toolu_013xkyLJJ4qmvTZfRtMo46pu', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2056, output_tokens=247)),
#  ToolsBetaMessage(id='msg_017oidjggm4zhEL6ALPRHWf3', content=[TextBlock(text='Okay, let\'s retrieve the details of the ClickUp space with the ID "gamedev909" so the manager can review the current configuration before archiving it.', type='text'), ToolUseBlock(id='toolu_018bfqUQPqZyhaMFxpHigdWp', input={'space_id': 'gamedev909'}, name='get_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2032, output_tokens=93)),
#  ToolsBetaMessage(id='msg_01EXWSBomPjFEZbpPJkXrC1h', content=[TextBlock(text='Okay, let\'s update the "Market Outreach 2023" space as requested:', type='text'), ToolUseBlock(id='toolu_017xbB4jz14wAjMKjRkdk6NE', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='update_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2055, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01DtZRhWU1QC7BZ8WBWsA5xv', content=[TextBlock(text="Okay, let's set up the dedicated ClickUp space for the Fall Events 2023 as per the requirements:", type='text'), ToolUseBlock(id='toolu_01MD15VLK1MZGkfVUDX7J5Tf', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2070, output_tokens=255))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_3 = sum(result_list)/len(result_list)
run_acc_3
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'EMContent2023'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DIGITALTRANS2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.54

# %%
print("ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
print(f"Run 2: {run_acc_2}")
print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Simple System Prompt : Accuracy
# =========================================
# Run 1: 0.54
# Run 2: 0.54
# Run 3: 0.54
