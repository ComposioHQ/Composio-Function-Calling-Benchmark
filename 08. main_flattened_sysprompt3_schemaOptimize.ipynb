# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.

# %%
schema_func_name_dict = {
    "get_spaces": "get_all_clickup_spaces_available",
    "create_space": "create_a_new_clickup_space",
    "get_space": "get_a_specific_clickup_space_details",
    "update_space": "modify_an_existing_clickup_space",
    "delete_space": "delete_an_existing_clickup_space",
    "get_space_tags": "get_all_tags_of_a_clickup_space",
    "create_space_tag": "assign_a_tag_to_a_clickup_space",
    "delete_space_tag": "remove_a_tag_from_a_clickup_space",
}

optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["name"] = schema_func_name_dict[temp_dict["name"]]
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_all_clickup_spaces_available',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_a_new_clickup_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_a_specific_clickup_space_details',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'modify_an_existing_clickup_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_an_existing_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_all_tags_of_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'assign_a_tag_to_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'remove_a_tag_from_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in optimized_schema]
tools
# Out:
# [{'name': 'get_all_clickup_spaces_available',
#   'description': 'View the Spaces available in a Workspace.',
#   'input_schema': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'name': 'create_a_new_clickup_space',
#   'description': 'Add a new Space to a Workspace.',
#   'input_schema': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'get_a_specific_clickup_space_details',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'modify_an_existing_clickup_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'input_schema': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'delete_an_existing_clickup_space',
#   'description': 'Delete a Space from your Workspace.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'get_all_tags_of_a_clickup_space',
#   'description': 'View the task Tags available in a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'assign_a_tag_to_a_clickup_space',
#   'description': 'Add a new task Tag to a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'name': 'remove_a_tag_from_a_clickup_space',
#   'description': 'Delete a task Tag from a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
import anthropic
client = anthropic.Anthropic()


tool_trailer = "\n".join([f'{sc["name"]} - {sc["description"]}' for sc in optimized_schema])

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-haiku-20240307",
  system =  f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

The Functions provided to you are:
{tool_trailer}

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response
# Out:
# ToolsBetaMessage(id='msg_0161PRhAjgS46VCJtJNeF87y', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_01VvsjtZz1HsRWNSShsT4Vez', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2395, output_tokens=269))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:38<00:00,  1.97s/it]
# [ToolsBetaMessage(id='msg_01UVDH1SBCVeGwyM7jUzu81Q', content=[TextBlock(text='Okay, let\'s use the appropriate tool to get the list of active spaces under the "Innovative Solutions" team.', type='text'), ToolUseBlock(id='toolu_01LDh47HqGP9VhkSV4hNEZZ1', input={'team_id': 'team123', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2389, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01YZzDRALyg77B35qyAA5CNw', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_01EuQzdUTnxSQZqGe4AWaGHr', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2395, output_tokens=269)),
#  ToolsBetaMessage(id='msg_013pj2FGNe5A8Lq58gxH1Tse', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the list of custom tags for the ClickUp space with the ID "sd456".', type='text'), ToolUseBlock(id='toolu_01VT5DUbRrBW6vRTPjfsWiy8', input={'space_id': 'sd456'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2383, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01H6XeXiuiNgmYYuxGKf51Zb', content=[TextBlock(text="Okay, let's address this issue step-by-step:", type='text'), ToolUseBlock(id='toolu_01VxLwE7AgWk168gcK17eHt5', input={'space_id': 'prj1122'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2410, output_tokens=84)),
#  ToolsBetaMessage(id='msg_01BDb7PZMpVqSNdrGYPsKQAw', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the "qa789" space in ClickUp.', type='text'), ToolUseBlock(id='toolu_01GnPgX9S7UJu6xe9vY1G44b', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2398, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01EbSJDAph9an6VrnK79MqnG', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Backend_Development_Space" as per Thomas\' requirements.', type='text'), ToolUseBlock(id='toolu_01WDNLbdAd4GyFPuyukrJytQ', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2409, output_tokens=319)),
#  ToolsBetaMessage(id='msg_017zjBeQRpxDvFQDzNPkDVig', content=[TextBlock(text="Okay, let's use the appropriate tool to delete the unused ClickUp space for GlobalTech.", type='text'), ToolUseBlock(id='toolu_018LanS7QcP6BgHug9b2e9ST', input={'space_id': 'gt678'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2378, output_tokens=86)),
#  ToolsBetaMessage(id='msg_01PJ2hZyLq4hULkXSmFiQ9ap', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space as per the requirements.", type='text'), ToolUseBlock(id='toolu_01BP6YaCLLXVUHhqZc8H1ijz', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2389, output_tokens=256)),
#  ToolsBetaMessage(id='msg_016RbFdTBDGnMRuZBFZYo8ay', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the specific space requested by the project manager.", type='text'), ToolUseBlock(id='toolu_01SaMQghoXaWSmCBwwz9QutU', input={'space_id': 'ep456'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2373, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01FE3dEQXtDtvKy576FXWvZs', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01TTvhMH3SxDVstec2yTXSKU', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#123456', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2405, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01Bi1RvWwmHs4hMRwL4dW4is', content=[TextBlock(text='Okay, let\'s use the relevant tools to implement the changes Samantha requested for the "pd2023" space at Neptune Technologies:', type='text'), ToolUseBlock(id='toolu_01LAQDHF7eyAEw6hh51BEvgs', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': '#ffffff', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2464, output_tokens=325)),
#  ToolsBetaMessage(id='msg_01SgsouxFxbNrcLt2HB8Y1ta', content=[TextBlock(text="Okay, let's create a new ClickUp space for the Glorious Events Inc. team to manage their event planning for 2023.", type='text'), ToolUseBlock(id='toolu_01VQ7tBYCmtN1AJ1fxgJau12', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2437, output_tokens=267)),
#  ToolsBetaMessage(id='msg_016mQib4KsqQk5RPcG7VsXSL', content=[TextBlock(text='Okay, let\'s use the relevant ClickUp tools to assist the IT department at Zenith Corp. with their project space audit and clean-up.\n\nFirst, we\'ll get a list of all the spaces available in the "it7890" team:', type='text'), ToolUseBlock(id='toolu_01Aopro9UX5ZfKirgiTVYXxH', input={'team_id': 'it7890', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2396, output_tokens=137)),
#  ToolsBetaMessage(id='msg_01CfXfLPF8M6xhxryfLvUrrF', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for Luxe Apparel's Fall Campaign 2023.", type='text'), ToolUseBlock(id='toolu_01C2uSaUh7dpf1srrNwQvMMh', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2428, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01KMUhYA5jNptpr4WYaCsnXS', content=[TextBlock(text="Okay, let's address this issue step-by-step:", type='text'), ToolUseBlock(id='toolu_018L6EuEEHBWnQRorP6DCDDj', input={'space_id': 'outreachQ2'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2420, output_tokens=85)),
#  ToolsBetaMessage(id='msg_01T14omM4LpmNa4EUEUjytGu', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Urgent Review" tag to the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_01DnsGPtinZ3YMjGU1x4eYny', input={'team_id': 'YOUR_TEAM_ID_HERE', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2403, output_tokens=120)),
#  ToolsBetaMessage(id='msg_01PfwWTbWCPVcasCjpj5MSLP', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs at Echo Media. Based on the information provided, it seems that the existing space "EMContentPlanning" ("EMContent2023") needs to be updated to enable time tracking features and change the theme color.', type='text'), ToolUseBlock(id='toolu_01SB74EeiKfQQE6xZWAGtw8r', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2401, output_tokens=346)),
#  ToolsBetaMessage(id='msg_0188meYcpgvoadV7eSxLK59S', content=[TextBlock(text="Okay, let's use the ClickUp API to update the existing space based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01UWDrAQiJmHExpHs3CNbpaw', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2480, output_tokens=317)),
#  ToolsBetaMessage(id='msg_01CRa4uUCBcDqX9mzfh8AgGd', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of all tags in the "DSAnalysis" space.', type='text'), ToolUseBlock(id='toolu_01XecbVGjF1xf2enhrmEx7aW', input={'space_id': 'DSAnalysis'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2395, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01Dmso9V2SuHZvmU1frRKCdk', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the details of the "TF_ProjectX" space before it is phased out.', type='text'), ToolUseBlock(id='toolu_01SnUnuZobSB5xCJr4Uavsfq', input={'space_id': 'TF_ProjectX'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2399, output_tokens=101)),
#  ToolsBetaMessage(id='msg_01SCFYVyXBwBXTweFfBgPbre', content=[TextBlock(text='Okay, let\'s start by getting a list of all the spaces available for the "FI_Team2023" team, including both active and archived spaces.', type='text'), ToolUseBlock(id='toolu_012WoRCeLz59hkGUhrfqY6hY', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2465, output_tokens=119)),
#  ToolsBetaMessage(id='msg_01Bf9rixFhXBMPcf2586f6La', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space as per Vera's requirements.", type='text'), ToolUseBlock(id='toolu_01HPPRFJu4bvRmaRsogxwGwi', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2475, output_tokens=259)),
#  ToolsBetaMessage(id='msg_01XFHgHQQ1cMwysvvrXimdE3', content=[TextBlock(text="Okay, let's use the ClickUp tools to help Jess and the WebFlow content team with their task management needs.", type='text'), ToolUseBlock(id='toolu_014uj5uCkC9jRbLbtir8geLm', input={'team_id': '$TEAM_ID', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2444, output_tokens=112)),
#  ToolsBetaMessage(id='msg_01SuueMpVAiS4MZoppuMHeeG', content=[TextBlock(text="Okay, let's address the requirements from the finance team at Prospera Finances:", type='text'), ToolUseBlock(id='toolu_014FJNbyH1mJuEHr9V2oKCyu', input={'space_id': 'PF_Projects', 'name': 'Finance Operations 2023', 'color': '#123456', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2479, output_tokens=312)),
#  ToolsBetaMessage(id='msg_013ima6aVZRuLUKPojN35nTn', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_018enYGmq3ud3diHDEqP7F3j', input={'team_id': 'TEAM_ID_HERE', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2432, output_tokens=99)),
#  ToolsBetaMessage(id='msg_01PAFkqz7oMnx5pjnv6sjYEt', content=[TextBlock(text='Understood. To delete the redundant ClickUp space "NGS_EarlyConcepts" as part of the strategic realignment and workspace optimization initiative, I will use the following tool:', type='text'), ToolUseBlock(id='toolu_015TcpYttrA4vTeMZonmgn8s', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2423, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01DWBtG1LZmySFdmoF4W4eUP', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of all existing tags in the "Marketing2023" space.', type='text'), ToolUseBlock(id='toolu_01QV9zKmyH1mJFBrCpRUWGX9', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2432, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01URm5P7uik1iLhszrws8TVB', content=[TextBlock(text='Okay, let\'s address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace of Titan Industries.', type='text'), ToolUseBlock(id='toolu_01CiZdde81zp2XMuyMXW7ain', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2473, output_tokens=331)),
#  ToolsBetaMessage(id='msg_016gQQK9Ei7vdRJooixTPQQC', content=[TextBlock(text='Okay, let\'s use the ClickUp API tools to gather the necessary information about the "CS_ProjectSpace1" space.', type='text'), ToolUseBlock(id='toolu_01B6bd91kVNkU93CQF8XbCy2', input={'space_id': 'CS_ProjectSpace1'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2440, output_tokens=97)),
#  ToolsBetaMessage(id='msg_011PNEsXCdmBEXu7dsH7NWGH', content=[TextBlock(text='Okay, let\'s use the ClickUp API to implement the new "MilestoneCritical" tag in the "DigitalTrans2023" space as requested.', type='text'), ToolUseBlock(id='toolu_011uHesYFMb6wv9FYmm9VBar', input={'team_id': '$TEAM_ID', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2468, output_tokens=124)),
#  ToolsBetaMessage(id='msg_01Px2SRuNtwojiqs8Vk6eoWh', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the customer success team based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_01AUEee5RnRvActTesq5ep8F', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2427, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01Fv6bu2miLZmtLmBUC6QCpK', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "social123" space as per the requirements:', type='text'), ToolUseBlock(id='toolu_01VZGfBfct4zE6iL28Eq5ULp', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2418, output_tokens=317)),
#  ToolsBetaMessage(id='msg_01SsfQjN9MzSWg7tN9vBqBJ2', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the unused "OldCampaign" tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_01P9WFSpetzDQ6j7Fit9XZ2z', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2415, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01FsRsb5VVFPc4vkRtdvHPui', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01EhDx1dip7D1EjE1JnC2LtT', input={'space_id': 'engteam777'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2413, output_tokens=84)),
#  ToolsBetaMessage(id='msg_018tBzbapyNd26C3szkvGZSA', content=[TextBlock(text='Okay, let\'s use the appropriate tool to remove the "BetaFeature" tag from the "proddev808" ClickUp space.', type='text'), ToolUseBlock(id='toolu_015Q65XDGoRbWYgA2G2rhk97', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2406, output_tokens=195)),
#  ToolsBetaMessage(id='msg_016gqpP9nRubCrQW6m3sfdTU', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01L5in9kdwVfARRCp5215waE', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'private': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2405, output_tokens=277)),
#  ToolsBetaMessage(id='msg_011SetCcGp4qTNuXAapE9BVR', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the ClickUp space dedicated to inventory management.", type='text'), ToolUseBlock(id='toolu_011oSPrviEm5Uw7NnCFKbKPM', input={'space_id': 'ecominv500'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2372, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01ByXFUaL3mAfhYRNd7CKk5L', content=[TextBlock(text="Okay, let's handle this request to decommission the old ClickUp space for the facility upgrades.", type='text'), ToolUseBlock(id='toolu_012UgsgAxGVHz7E7P3JDz3Ej', input={'space_id': 'eduop876'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2375, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01T6VDSWXcdCwa46n6UqQdhK', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to fulfill Natalie's request:", type='text'), ToolUseBlock(id='toolu_013apWUcA6SxTKAV6tivQZpC', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2409, output_tokens=257)),
#  ToolsBetaMessage(id='msg_0173bapBoWDDWZrkJLES6qzz', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01S4g6ep1Vex8BiJKiiDN8cQ', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2408, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01SBK1zhmrrtKT1EWeuGw7o6', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Digital Design Team" space based on Samantha\'s requirements.', type='text'), ToolUseBlock(id='toolu_01WyTDWsEEiqjZdirS1amLXt', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2452, output_tokens=321)),
#  ToolsBetaMessage(id='msg_012FMwKLahHcWNbRrxd1TfAf', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the content strategy team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01KRfvLazr1Beun79XmF4fBG', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2416, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01FFdffrACvTSm4SBzhwRSVH', content=[TextBlock(text='Okay, let\'s use the appropriate tool to get the list of tags for the ClickUp space with the ID "appdev300".', type='text'), ToolUseBlock(id='toolu_012xeVYVMyXNnmKXf5xh5Prb', input={'space_id': 'appdev300'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2398, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01QfqdfeTUW2nWEQp1zMmiBM', content=[TextBlock(text="Okay, let's address this request step-by-step:", type='text'), ToolUseBlock(id='toolu_01HPBYL6AZ4AhEABtv2dqbPH', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2411, output_tokens=154)),
#  ToolsBetaMessage(id='msg_01JsXE8kFRD8wrLM6SQFBgqL', content=[TextBlock(text='Okay, based on the information provided, the finance team needs to delete the "finforecast345" ClickUp space as it is no longer in use. To do this, I will use the following tool:', type='text'), ToolUseBlock(id='toolu_01JcdqENgeKwr1mn7WCmvVuj', input={'space_id': 'finforecast345'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2379, output_tokens=111)),
#  ToolsBetaMessage(id='msg_01HtCWEruVGCL6BSwk7T7Dsr', content=[TextBlock(text="Okay, let's handle this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_01PXxiU9TL4o63MYfhKBJuFG', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2418, output_tokens=181)),
#  ToolsBetaMessage(id='msg_01YDbwMougKhCQpVg84RVYZv', content=[TextBlock(text="Okay, based on the information provided, it seems the client support division needs to create a new space in ClickUp for their Q2 support updates. Here's how I can help:", type='text'), ToolUseBlock(id='toolu_01Fx2U3PASkwVzdgCaGUVmeY', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2419, output_tokens=276)),
#  ToolsBetaMessage(id='msg_012K4xKoBzCFrLsNDqKZSg5h', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the details of the ClickUp space with the ID "gamedev909":', type='text'), ToolUseBlock(id='toolu_019aQBsbGqbcHnvJFyxMtkks', input={'space_id': 'gamedev909'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2395, output_tokens=94)),
#  ToolsBetaMessage(id='msg_01DPh7TwSHxPEFSFmLTW78rM', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01G27eoRrPHcDw2oHg9Z8E64', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2418, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01McX7mP24YvyoQMtunNPRXy', content=[TextBlock(text="Okay, let's set up the new ClickUp space for the Fall Events 2023 based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01MVAibtCzqYncnn2mC71RiW', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2433, output_tokens=263))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

def convert_str_to_bool(nested_dict):
    for key, value in nested_dict.items():
        # If the value is a nested dictionary, recursively process it
        if isinstance(value, dict):
            convert_str_to_bool(value)
        else:
            if value == "True":
                nested_dict[key] = True
            elif value == "False":
                nested_dict[key] = False
    return nested_dict

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    llm_response_dict = convert_str_to_bool(llm_response_dict)

    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'prj1122'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#123456',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'outreachQ2'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': 'YOUR_TEAM_ID_HERE'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'DSAnalysis'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': '$TEAM_ID'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#123456',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': 'TEAM_ID_HERE'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': '$TEAM_ID'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'engteam777'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# 0.46

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_2 = sum(result_list)/len(result_list)
# run_acc_2

# %%
# from tqdm import tqdm
# # from tqdm.auto import tqdm


# llm_output = []

# for bdata in tqdm(bench_data):
#     response = fcalling_llm(bdata["prompt"])
#     try:
#         llm_output.append(response)
#     except TypeError:
#         print(bdata["prompt"])
#         print(response)
#         llm_output.append(None)
#         print("------")
# llm_output

# %%
# from pprint import pprint

# fsp = FuncStringParser()
# result_list = []

# # fsp.func_to_args_dict(func_args)
# for bdata, llm_response in zip(bench_data, llm_output):
#     bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
#     bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
#     bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
#     llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
#     pprint(bdata_solution_dict)
#     pprint(llm_response_dict)
#     print(llm_response_dict == bdata_solution_dict)
#     result_list.append(llm_response_dict == bdata_solution_dict)
#     print("-----")
    
# run_acc_3 = sum(result_list)/len(result_list)
# run_acc_3

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary + \nFunction Name Optimized : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
# print(f"Run 2: {run_acc_2}")
# print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary +
# Function Name Optimized : Accuracy
# =========================================
# Run 1: 0.46
