# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.

# %%
schema_func_name_dict = {
    "get_spaces": "get_all_clickup_spaces_available",
    "create_space": "create_a_new_clickup_space",
    "get_space": "get_a_specific_clickup_space_details",
    "update_space": "modify_an_existing_clickup_space",
    "delete_space": "delete_an_existing_clickup_space",
    "get_space_tags": "get_all_tags_of_a_clickup_space",
    "create_space_tag": "assign_a_tag_to_a_clickup_space",
    "delete_space_tag": "remove_a_tag_from_a_clickup_space",
}

optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["name"] = schema_func_name_dict[temp_dict["name"]]
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_all_clickup_spaces_available',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_a_new_clickup_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_a_specific_clickup_space_details',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'modify_an_existing_clickup_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_an_existing_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_all_tags_of_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'assign_a_tag_to_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'remove_a_tag_from_a_clickup_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()

tools = [{"name":sc["name"],  "description":sc["description"], "input_schema": sc["parameters"]} for sc in optimized_schema]
tools
# Out:
# [{'name': 'get_all_clickup_spaces_available',
#   'description': 'View the Spaces available in a Workspace.',
#   'input_schema': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'name': 'create_a_new_clickup_space',
#   'description': 'Add a new Space to a Workspace.',
#   'input_schema': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'get_a_specific_clickup_space_details',
#   'description': 'View the details of a specific Space in a Workspace.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'modify_an_existing_clickup_space',
#   'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'input_schema': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'name': 'delete_an_existing_clickup_space',
#   'description': 'Delete a Space from your Workspace.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'get_all_tags_of_a_clickup_space',
#   'description': 'View the task Tags available in a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'name': 'assign_a_tag_to_a_clickup_space',
#   'description': 'Add a new task Tag to a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'name': 'remove_a_tag_from_a_clickup_space',
#   'description': 'Delete a task Tag from a Space.',
#   'input_schema': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
import anthropic
client = anthropic.Anthropic()

fcalling_llm = lambda fprompt : client.beta.tools.messages.create(
  model="claude-3-sonnet-20240229",
  system = f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
""",
  messages=[
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response
# Out:
# ToolsBetaMessage(id='msg_01B7RZ8tZQGdr25ZYv23AAhz', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_01ByxhEeKC2UJZZ97mXSsmBP', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=269))

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        for message in llm_response.content:
            if message.type == "tool_use":
                return {
                    "name": message.name,
                    "arguments": message.input,
                }
        return {"name": None, "arguments": None}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:50<00:00,  2.22s/it]
# [ToolsBetaMessage(id='msg_01SCKAWJdvRNhSTx14geYXSE', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of spaces under the "Innovative Solutions" team and check which ones are active.', type='text'), ToolUseBlock(id='toolu_01YWcDQWQJVLyoBjtGPYNxNF', input={'team_id': 'team123', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=113)),
#  ToolsBetaMessage(id='msg_01B1fz48PnbmdnfTJD7hBeMX', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_01S7hKWPsWTWNeex2oFMxrP5', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=269)),
#  ToolsBetaMessage(id='msg_01DJvpZrBJpRHZh99dnLMAqS', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the list of custom tags for the ClickUp space with the ID "sd456".', type='text'), ToolUseBlock(id='toolu_01BNr62jfLAe6nbuAwk7rste', input={'space_id': 'sd456'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2182, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01AwvZ2n8LgDLTKH3ejNFbUS', content=[TextBlock(text='Okay, let\'s use the ClickUp API to update the tag in the "prj1122" space.', type='text'), ToolUseBlock(id='toolu_019b8iCE1cHomvJVDG6iJiiS', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2209, output_tokens=191)),
#  ToolsBetaMessage(id='msg_01XvMjh8ocq2mnGyPWVbVKzx', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the ClickUp space with ID "qa789".', type='text'), ToolUseBlock(id='toolu_01JJXwkqGJzLCSmkuZoHhvTs', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01Qnad1rwMegtbtHS29cyWe2', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Backend_Development_Space" as per Thomas\' requirements.', type='text'), ToolUseBlock(id='toolu_01Ey4DLBaabfhpY42gAEepdj', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=319)),
#  ToolsBetaMessage(id='msg_017PLevMWv33EoJeBZtkvsFv', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to delete the unused space.", type='text'), ToolUseBlock(id='toolu_014HiSDJdqSiYnq1ZdVP7ZcX', input={'space_id': 'gt678'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2177, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01EZMMGSs6MZE8A2HZLCWEio', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the design team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01JSwh6iMcGNNLQ7CVMB2Eb6', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=261)),
#  ToolsBetaMessage(id='msg_01C3WUz7ASajKVLZb4RYkrEy', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the specific space requested by the project manager.", type='text'), ToolUseBlock(id='toolu_016TDFPL6gdwsSJ24LYkuHSf', input={'space_id': 'ep456'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01USCJhE153aZAHkApEfZ8hz', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_012ehtkzoMybmnhPWNwEwAMR', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01XNvxVckjT7MKX395vYXQNy', content=[TextBlock(text="Okay, let's address Samantha's requirements for the strategic shift in how product development milestones are managed at Neptune Technologies.", type='text'), ToolUseBlock(id='toolu_01Qw3qPdYXEJaqKhuJagBrNH', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2263, output_tokens=323)),
#  ToolsBetaMessage(id='msg_01Np5TPW7SiX37kPK9L8s2UH', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the events management team at Glorious Events Inc.", type='text'), ToolUseBlock(id='toolu_016PYe6ZGiSCEJw54QCP5pkN', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2236, output_tokens=265)),
#  ToolsBetaMessage(id='msg_013r7yvyeD869ETTh3yitco1', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces.", type='text'), ToolUseBlock(id='toolu_01DajhRdDgjuTQYUaU5MPeX7', input={'team_id': 'it7890', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=109)),
#  ToolsBetaMessage(id='msg_016o2rpLFC2qCmRq58NpajBV', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for Darren's marketing team to manage the upcoming fall campaign.", type='text'), ToolUseBlock(id='toolu_01SrxfzRsxYDMtuaQ4HWgt9c', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2227, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01AwXUVAhWnfyf7PoqPoca9E', content=[TextBlock(text="Okay, let's address this situation using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01GMMfYEtkEB7XYC5gUAv6JN', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2219, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01BKLjrVNWHVj9PN4415zZ8x', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Urgent Review" tag to the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_01NASLicJzbbneEQrtv6akSH', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2202, output_tokens=171)),
#  ToolsBetaMessage(id='msg_01UzT91RtbnMQXBQxgxjFgfW', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01XVqHKzUdstDPU7M6sTEFNL', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2200, output_tokens=316)),
#  ToolsBetaMessage(id='msg_018GjkSjCJxrzL6q75AXF8Fs', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this situation.", type='text'), ToolUseBlock(id='toolu_01QbQzY21dR6o1UGokkYGX6c', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2279, output_tokens=311)),
#  ToolsBetaMessage(id='msg_01JaoohmRvGLoQN8TKCv5Kec', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of all tags in the "DSAnalysis" space. ', type='text'), ToolUseBlock(id='toolu_01V7G9zdBwBVrTGCcow9G3NK', input={'space_id': 'SPACE_ID_FOR_DSANALYSIS'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=105)),
#  ToolsBetaMessage(id='msg_01ST3y7XG8nbgdvyB6VGJBP1', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the details of the "TF_ProjectX" space that TerraFirma wants to phase out.', type='text'), ToolUseBlock(id='toolu_01UBtaAzTyNybEVd8GWsJM84', input={'space_id': 'TF_ProjectX'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2198, output_tokens=106)),
#  ToolsBetaMessage(id='msg_018CGmm9qEW4mjYx2KuAZceo', content=[TextBlock(text="Okay, let's use the ClickUp API to gather the information needed for this audit.", type='text'), ToolUseBlock(id='toolu_01PnitdAAqPSkVzYcv8jiZ2A', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2264, output_tokens=105)),
#  ToolsBetaMessage(id='msg_019QK4CWZoJkXMALbsvfjbvn', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Design Hub 2023" space for the PixelPerfect Studios design team.', type='text'), ToolUseBlock(id='toolu_012Q9cjEVrUE5oFzEUkL8Uwg', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2274, output_tokens=271)),
#  ToolsBetaMessage(id='msg_01KaAig3PpM3appps6TLc9LP', content=[TextBlock(text="Okay, let's use the ClickUp API to help Jess with her request.", type='text'), ToolUseBlock(id='toolu_01FMGACzc1szyvby9BczzaK3', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2243, output_tokens=156)),
#  ToolsBetaMessage(id='msg_01EaKZojHA5D8bPTHSPcCirR', content=[TextBlock(text="Okay, let's address the requirements from the finance team at Prospera Finances:", type='text'), ToolUseBlock(id='toolu_01CuG1QaKu6WXyE2YcoyaCp2', input={'space_id': '$SPACE_ID', 'name': 'Finance Operations 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2278, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01MDDhJWQDuhCSsW95bQj7se', content=[TextBlock(text="Okay, let's break this down step-by-step:", type='text'), ToolUseBlock(id='toolu_015rsXQusfbMXci1kFnYLtLB', input={'team_id': '$TEAM_ID', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01EhR41ENxuJYmrHssJLrTk4', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to delete the redundant "NGS_EarlyConcepts" space as part of the strategic realignment initiative.', type='text'), ToolUseBlock(id='toolu_019vbQQk3GrRdszJHg9gAPyY', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2222, output_tokens=107)),
#  ToolsBetaMessage(id='msg_018rTB7rJVND6sKXdBACQVGM', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of all existing tags in the "Marketing2023" space.', type='text'), ToolUseBlock(id='toolu_01X52Zcy93N5vHLk9gDV3nGR', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=106)),
#  ToolsBetaMessage(id='msg_012Puzvsh5oKu2f6ApazsYpP', content=[TextBlock(text='Okay, let\'s address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace of Titan Industries.', type='text'), ToolUseBlock(id='toolu_01G8JppVvjmFTJsPv3RhYpAC', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2272, output_tokens=331)),
#  ToolsBetaMessage(id='msg_01WuMHRBDYiZeWHHTYdkkNPq', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_01HPZDZcUBJb8jgVMFvxtuKC', input={'space_id': 'CS_ProjectSpace1'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2239, output_tokens=83)),
#  ToolsBetaMessage(id='msg_01P6NdAYYbsjTMWGBrpJuS7d', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "MilestoneCritical" tag in the "DigitalTrans2023" space.', type='text'), ToolUseBlock(id='toolu_01PexWEDLyZBmLnvTqHhRi48', input={'team_id': 'YOUR_TEAM_ID_HERE', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2267, output_tokens=125)),
#  ToolsBetaMessage(id='msg_018Lnix6JG6RxajoGkJYLqar', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the customer success team based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_01F5c45LKsxAHWrtHhFsXGej', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2226, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01PicnCSxp6QmjkS1Uz1pjDE', content=[TextBlock(text='Okay, let\'s use the "modify_an_existing_clickup_space" tool to update the "social123" space with the new requirements.', type='text'), ToolUseBlock(id='toolu_01RwoxJG7ao7CDmx7oaHrSrT', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=325)),
#  ToolsBetaMessage(id='msg_01Hqvdv2W3wAkKiKzC9TEiNP', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the unused "OldCampaign" tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_01NpkDUXQmTrbChx9KmHeqYV', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2214, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01Am74Q4eK543Rn3YywbhFMC', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Time-Sensitive" tag to the existing "engteam777" space.', type='text'), ToolUseBlock(id='toolu_016jM8f7EEvp5WSeU3JSUWKu', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2212, output_tokens=172)),
#  ToolsBetaMessage(id='msg_01Bo2qKQvkPdewZ2zwPksz9W', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_01XvEimnwMUtwobT3r4gCfHa', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2205, output_tokens=194)),
#  ToolsBetaMessage(id='msg_01Nrc8YvUJ59G1jimi83aiug', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_014EF2wdaQdpoFyaTeoeAdFj', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False, 'private': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=277)),
#  ToolsBetaMessage(id='msg_01TiqkTwXH8YC95ezhdxk8dA', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the ClickUp space dedicated to inventory management.", type='text'), ToolUseBlock(id='toolu_01TSGA3wJQxRvsbJihpnaN2c', input={'space_id': 'ecominv500'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2171, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01RxEii7WxkuUrtEm5QxLJGh', content=[TextBlock(text="Okay, let's use the ClickUp API to delete the unnecessary space.", type='text'), ToolUseBlock(id='toolu_01L8wH9SL6gKVt8Zd9hsg4xo', input={'space_id': 'eduop876'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2174, output_tokens=82)),
#  ToolsBetaMessage(id='msg_019eajZfKSMAUGTkPb7AcLjB', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to fulfill Natalie's request.", type='text'), ToolUseBlock(id='toolu_01FhjqRHguh5133c8226zuCN', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01P6igL4jEpnpMveA2DRupBe', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_015nQKgbMmpvGvF626geaxeQ', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2207, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01CMq1o5RL47EACAAZkG4v1g', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Digital Design Team" space based on Samantha\'s requirements.', type='text'), ToolUseBlock(id='toolu_018nB2XBaNvUsbMEDXsRzF5C', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2251, output_tokens=321)),
#  ToolsBetaMessage(id='msg_018PeZQxc73wLig7W4SfJZtS', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the content strategy team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01C25N4P8srm74awLaZkgzVC', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2215, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01L2vfNemq7Hxd2t7Pa1oC2a', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of tags for the "appdev300" space.', type='text'), ToolUseBlock(id='toolu_01TqMGSxTs7AvnixuwcGV134', input={'space_id': 'appdev300'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=96)),
#  ToolsBetaMessage(id='msg_017dcvLS5w8Bg7364XgR7yZj', content=[TextBlock(text="Okay, let's address this request using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01L9WRV2oWRmPjaJNcpx9fj4', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2210, output_tokens=159)),
#  ToolsBetaMessage(id='msg_01W4Fk97QvCEdHRFvqHfWars', content=[TextBlock(text='Okay, based on the given situation, the finance team needs to delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the "delete_an_existing_clickup_space" function.', type='text'), ToolUseBlock(id='toolu_01NMNS5FP3EebwWnf98FDwjA', input={'space_id': 'finforecast345'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2178, output_tokens=122)),
#  ToolsBetaMessage(id='msg_01CfKRjBaCvxEJFApa93FQJk', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "LowPriority" tag from the "gfxdes678" space.', type='text'), ToolUseBlock(id='toolu_01TNp67cyFyQcgiFBQDyroPZ', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=200)),
#  ToolsBetaMessage(id='msg_017qYJXek2Vr2MPS2DVy6tYu', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the support team based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01AhdX9vpm7uuB6Fmbf4NpSE', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2218, output_tokens=262)),
#  ToolsBetaMessage(id='msg_017pYibXJGm8ZukCZV8uSNoV', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to retrieve the details of the "gamedev909" space:', type='text'), ToolUseBlock(id='toolu_01L82NEr4ovpKArTNi8KafdR', input={'space_id': 'gamedev909'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01MDoWLmSZJeSXxSm2xWvBKw', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01JumRsXJ4fiejR9g58ayDFD', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01W6HikdvTHT9iaoVPvAKvew', content=[TextBlock(text="Okay, let's use the ClickUp API to set up the new space for the Fall Events 2023 team.", type='text'), ToolUseBlock(id='toolu_01Ljv6okKmnNwNkBPf5eQcJ1', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2232, output_tokens=263))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DSANALYSIS'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': '$SPACE_ID'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': '$TEAM_ID'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': 'YOUR_TEAM_ID_HERE'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# 0.52

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:51<00:00,  2.23s/it]
# [ToolsBetaMessage(id='msg_018nNSjv3PzMrX31MMMuE97B', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of spaces under the "Innovative Solutions" team and check which ones are active.', type='text'), ToolUseBlock(id='toolu_01CcKzXv6ZFPzXtHZbHSFz2X', input={'team_id': 'team123', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=113)),
#  ToolsBetaMessage(id='msg_011XsKdXtaPRvgZbFcbV3yWN', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_016dRBwTrpTPHF218iWrexCV', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=269)),
#  ToolsBetaMessage(id='msg_01LvwYyuKvXmGoFdb7pFQP8x', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the list of custom tags for the ClickUp space with the ID "sd456".', type='text'), ToolUseBlock(id='toolu_019GGTxg9zy6iCCwowRRPKsj', input={'space_id': 'sd456'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2182, output_tokens=97)),
#  ToolsBetaMessage(id='msg_017cugcqoEUonbwV9jfhRBEk', content=[TextBlock(text='Okay, let\'s use the ClickUp API to update the tag in the "prj1122" space.', type='text'), ToolUseBlock(id='toolu_01VPAvfXkTi8NR6cYzrug91f', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2209, output_tokens=191)),
#  ToolsBetaMessage(id='msg_0129Aqa6V7JsKu7xtUsLmwdn', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the ClickUp space with ID "qa789".', type='text'), ToolUseBlock(id='toolu_01Uygvq3gY4NwopeVMUSUbAM', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01MbGPL45PHqySYzZVxEPLYk', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Backend_Development_Space" as per Thomas\' requirements.', type='text'), ToolUseBlock(id='toolu_014HgyQnHWn5NAVHNEyjRy3v', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=319)),
#  ToolsBetaMessage(id='msg_01J2ue6F6MMRzZw18R1QSWHT', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to delete the unused space.", type='text'), ToolUseBlock(id='toolu_01MPwyJQbRK2SBMfz76uSQcA', input={'space_id': 'gt678'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2177, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01YFyjKYoRJ737P7SjhtPgav', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the design team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01WQ7jcXrTzZpmqbRdjTfhSN', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=261)),
#  ToolsBetaMessage(id='msg_01WRbPQn5hcaogRoRrEYAvEB', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the specific space requested by the project manager.", type='text'), ToolUseBlock(id='toolu_01C29fssS13aWRoF3BNir1zb', input={'space_id': 'ep456'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=89)),
#  ToolsBetaMessage(id='msg_016VuUAuDMyyHkXbbDnUtcdm', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01P9a8fXZron5vaHUwmsJYQa', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01FSw3rS337HKSUUVrgAxQ6r', content=[TextBlock(text="Okay, let's address Samantha's requirements for the strategic shift in how product development milestones are managed at Neptune Technologies.", type='text'), ToolUseBlock(id='toolu_01St44zijMFik85gLN5viVHF', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2263, output_tokens=323)),
#  ToolsBetaMessage(id='msg_016wi6ihsQboPkEioshoBLjL', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the events management team at Glorious Events Inc.", type='text'), ToolUseBlock(id='toolu_01YTGfWctfcymCQiBU4p9pra', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2236, output_tokens=265)),
#  ToolsBetaMessage(id='msg_01P4Taa9HbUmFFKnciFBd9Kw', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces.", type='text'), ToolUseBlock(id='toolu_011ijk8QJLdWLQyyDLunV7nU', input={'team_id': 'it7890', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=109)),
#  ToolsBetaMessage(id='msg_012tuihEd7vHXER8wX6pBsKK', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for Darren's marketing team to manage the upcoming fall campaign.", type='text'), ToolUseBlock(id='toolu_01LDFYESwkjhxxdLa9EaUgmV', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2227, output_tokens=264)),
#  ToolsBetaMessage(id='msg_017tSGas2VRcDBe8XnJxcDPb', content=[TextBlock(text="Okay, let's address this situation using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01TzfHJo5DDEqani5o6vgA73', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2219, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01WAFfEgq5mYkzPhFwXsLujC', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Urgent Review" tag to the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_01QnpJ5BTcF87anhvw1Tgo87', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2202, output_tokens=171)),
#  ToolsBetaMessage(id='msg_013T67pKHNPwQMCfDGwvDeFz', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01LrPvoCrFaT1WeBiComRFTP', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2200, output_tokens=316)),
#  ToolsBetaMessage(id='msg_01789W9AkKUH2JqhhSNtqCPC', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this situation.", type='text'), ToolUseBlock(id='toolu_01QoTE7EmgBddjpyjEpBGKp4', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2279, output_tokens=311)),
#  ToolsBetaMessage(id='msg_01P83LGGPqHP3wcmeAgrgq8R', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of all tags in the "DSAnalysis" space. ', type='text'), ToolUseBlock(id='toolu_01CHrD5vDPPTMBLutmyD7v2D', input={'space_id': 'SPACE_ID_FOR_DSANALYSIS'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=105)),
#  ToolsBetaMessage(id='msg_013FucHSp39Ma6HhcPzGqeBP', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the details of the "TF_ProjectX" space that TerraFirma wants to phase out.', type='text'), ToolUseBlock(id='toolu_0158oZJsSvzTBGSnFkWzZuUn', input={'space_id': 'TF_ProjectX'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2198, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01KDVvgWXfsUouxEkhy85seB', content=[TextBlock(text="Okay, let's use the ClickUp API to gather the information needed for this audit.", type='text'), ToolUseBlock(id='toolu_015CJzQCU7PW8yKKWEsgPzH5', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2264, output_tokens=105)),
#  ToolsBetaMessage(id='msg_01PUZ3e46zNefgFqQbgcRCpB', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Design Hub 2023" space for the PixelPerfect Studios design team.', type='text'), ToolUseBlock(id='toolu_01FRmccYgy1wFwi6TTsyMBfU', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2274, output_tokens=271)),
#  ToolsBetaMessage(id='msg_01RMau1oZPYi4nSRzH5XaPHo', content=[TextBlock(text="Okay, let's use the ClickUp API to help Jess with her request.", type='text'), ToolUseBlock(id='toolu_015AGwLSi9cmJ2bZ6ZtfgF17', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2243, output_tokens=156)),
#  ToolsBetaMessage(id='msg_01FKS8xrCAWYRAUoiTryTQKd', content=[TextBlock(text="Okay, let's address the requirements from the finance team at Prospera Finances:", type='text'), ToolUseBlock(id='toolu_01EFHmeZ8rRATQEJiGPFQRs6', input={'space_id': '$SPACE_ID', 'name': 'Finance Operations 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2278, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01CmwbJMaRawCbys6ZPoGTuZ', content=[TextBlock(text="Okay, let's break this down step-by-step:", type='text'), ToolUseBlock(id='toolu_01HZ7VyN9Yg5bv2cPJ3cDkg7', input={'team_id': '$TEAM_ID', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=98)),
#  ToolsBetaMessage(id='msg_011xUgQzyyN5GjTadE5U46mE', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to delete the redundant "NGS_EarlyConcepts" space as part of the strategic realignment initiative.', type='text'), ToolUseBlock(id='toolu_01XKTyMsfbCXoekmMoVz9cRR', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2222, output_tokens=107)),
#  ToolsBetaMessage(id='msg_01HQ4ztFDoSswDaWiiUQvZXJ', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of all existing tags in the "Marketing2023" space.', type='text'), ToolUseBlock(id='toolu_01Aq9nSMKoYtbeq1DWN6EVQ5', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01KmetpFieYBWmizZcjTAkLe', content=[TextBlock(text='Okay, let\'s address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace of Titan Industries.', type='text'), ToolUseBlock(id='toolu_01JvJCRnqtjsfxtEN4XPj2va', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2272, output_tokens=331)),
#  ToolsBetaMessage(id='msg_012eu3KarZG7RF4wTdocj9ku', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_017fnYxdVjn2VhhFKqHt61bU', input={'space_id': 'CS_ProjectSpace1'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2239, output_tokens=83)),
#  ToolsBetaMessage(id='msg_01CbxxnJ3H6RexKvpYZo6XdE', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "MilestoneCritical" tag in the "DigitalTrans2023" space.', type='text'), ToolUseBlock(id='toolu_01GQAjoWToKxnVe6bsSw9hop', input={'team_id': 'YOUR_TEAM_ID_HERE', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2267, output_tokens=125)),
#  ToolsBetaMessage(id='msg_01BWSy52p5bzzHWE3UYouqP3', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the customer success team based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_0191PfnRcEmMLuw5fAyTyHaE', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2226, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01W997x7jMWAoc3SFXKjwqD6', content=[TextBlock(text='Okay, let\'s use the "modify_an_existing_clickup_space" tool to update the "social123" space with the new requirements.', type='text'), ToolUseBlock(id='toolu_014gWzKyNpZAD5JkbVesWAQZ', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=325)),
#  ToolsBetaMessage(id='msg_01QqC2QDfeFB1nMsqbHXAvs5', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the unused "OldCampaign" tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_0136dHv6P8aKAsMkSt1aTZvn', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2214, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01Bm4S5Rgr415dSKGqCdUiiE', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Time-Sensitive" tag to the existing "engteam777" space.', type='text'), ToolUseBlock(id='toolu_01BX6PUSSuzxypSsD2C6X5rJ', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2212, output_tokens=172)),
#  ToolsBetaMessage(id='msg_019rXfA3Z8ksCJpxVGV3nCcB', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_01UHtmm3WrZtShaMZNHze6wd', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2205, output_tokens=194)),
#  ToolsBetaMessage(id='msg_01Qq8wDhnPN3Qxd4bfaTbQgR', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_01KprP7hnLgb74H2UoraBApj', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False, 'private': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=277)),
#  ToolsBetaMessage(id='msg_01Q6ktRjBxgCGaecdKx65irC', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the ClickUp space dedicated to inventory management.", type='text'), ToolUseBlock(id='toolu_018RYvB3YAseNdpTbojATByK', input={'space_id': 'ecominv500'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2171, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01UvpYK23JyGu4VNGDuECsYs', content=[TextBlock(text="Okay, let's use the ClickUp API to delete the unnecessary space.", type='text'), ToolUseBlock(id='toolu_01NnoRgxxe6frFpD5cSP29YN', input={'space_id': 'eduop876'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2174, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01LMy4dhywYJLHm7T4dgBdHf', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to fulfill Natalie's request.", type='text'), ToolUseBlock(id='toolu_018stP4Wgmi3spoGY9aM7UD4', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=257)),
#  ToolsBetaMessage(id='msg_01JiDK4Gz1i5mgKrBeH8M8CQ', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01UXCrojp1WKtx6CDrTdswef', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2207, output_tokens=309)),
#  ToolsBetaMessage(id='msg_01YGGkbmdq6MtadgunPsZvNM', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Digital Design Team" space based on Samantha\'s requirements.', type='text'), ToolUseBlock(id='toolu_01NWcnCGE98ap2HjK778mP9T', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2251, output_tokens=321)),
#  ToolsBetaMessage(id='msg_018nhK5gXmLeXYi2Q4nsDwK8', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the content strategy team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01BpshK2PxsgRSCSzJskRAxM', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2215, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01AmzpyGT27dfkRUUKpsW1h1', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of tags for the "appdev300" space.', type='text'), ToolUseBlock(id='toolu_01KaDtq1hriFUPr8RybyKKZi', input={'space_id': 'appdev300'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=96)),
#  ToolsBetaMessage(id='msg_013sCCBLqeEnRpq7yR4FXKT2', content=[TextBlock(text="Okay, let's address this request using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01JHmuwizTrsX672opQhTAqK', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2210, output_tokens=159)),
#  ToolsBetaMessage(id='msg_01EgDiWNJuWwoeaeiwYB74xe', content=[TextBlock(text='Okay, based on the given situation, the finance team needs to delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the "delete_an_existing_clickup_space" function.', type='text'), ToolUseBlock(id='toolu_01U9yf7hhQDDCsGN5JGNwM9x', input={'space_id': 'finforecast345'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2178, output_tokens=122)),
#  ToolsBetaMessage(id='msg_01D8auLPLVSr9tUj6CRJ2b41', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "LowPriority" tag from the "gfxdes678" space.', type='text'), ToolUseBlock(id='toolu_01Ed1pMfmbzAF7mroZZfiHuB', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=200)),
#  ToolsBetaMessage(id='msg_01FhCFHeq8cXUWkSxCf6XdQX', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the support team based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01C5KkMX3P9kuctfSj6BcLxZ', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2218, output_tokens=262)),
#  ToolsBetaMessage(id='msg_018NVWR68pKtiqcP9aijcZLw', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to retrieve the details of the "gamedev909" space:', type='text'), ToolUseBlock(id='toolu_01X8n4Zjj8hfHcD2ketLFUd8', input={'space_id': 'gamedev909'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01MdkxbDJZ5LTHW2vNXwWKKd', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01VA2tCSq9hyQVCm3wq698FG', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=313)),
#  ToolsBetaMessage(id='msg_013gP6Utxddr4YAwdeLDUWcv', content=[TextBlock(text="Okay, let's use the ClickUp API to set up the new space for the Fall Events 2023 team.", type='text'), ToolUseBlock(id='toolu_01EzEB9QbaKb73js1nZA6d4i', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2232, output_tokens=263))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_2 = sum(result_list)/len(result_list)
run_acc_2
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DSANALYSIS'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': '$SPACE_ID'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': '$TEAM_ID'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': 'YOUR_TEAM_ID_HERE'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# 0.52

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [01:49<00:00,  2.20s/it]
# [ToolsBetaMessage(id='msg_01P5wH7Wq5ycMdVmtcPopVLa', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of spaces under the "Innovative Solutions" team and check which ones are active.', type='text'), ToolUseBlock(id='toolu_01JYGTuNHtc8D3nAqN9WdjaW', input={'team_id': 'team123', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=113)),
#  ToolsBetaMessage(id='msg_012M1GpK2aDcvce6MAnqKWYP', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to set up the new space for the "Creative Minds" team as per Ella\'s requirements.', type='text'), ToolUseBlock(id='toolu_01WcMSiLJAwvm7V43hw4Cwei', input={'team_id': 'cm789', 'name': 'Innovative Campaigns 2023', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=269)),
#  ToolsBetaMessage(id='msg_01Qthjp2pAQR5drXTz5M4yzH', content=[TextBlock(text='Okay, let\'s use the appropriate tool to retrieve the list of custom tags for the ClickUp space with the ID "sd456".', type='text'), ToolUseBlock(id='toolu_01JhPSvVBvZo52qeawJ7LALm', input={'space_id': 'sd456'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2182, output_tokens=97)),
#  ToolsBetaMessage(id='msg_01GMTBajzqmRUULuuybcpfj9', content=[TextBlock(text='Okay, let\'s use the ClickUp API to update the tag in the "prj1122" space.', type='text'), ToolUseBlock(id='toolu_01QsKiaownsFkXbGWHrhmkwX', input={'space_id': 'prj1122', 'tag_name': 'CriticalIssue', 'tag__name': 'CriticalIssue', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#8B0000'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2209, output_tokens=191)),
#  ToolsBetaMessage(id='msg_01M4FSmedGPvcfpVCbhr1Q7u', content=[TextBlock(text='Okay, let\'s remove the "MinorIssue" tag from the ClickUp space with ID "qa789".', type='text'), ToolUseBlock(id='toolu_01TzGs38FQ9EYWbgTELB5C8p', input={'space_id': 'qa789', 'tag_name': 'MinorIssue', 'tag__name': 'MinorIssue', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFFE0'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=189)),
#  ToolsBetaMessage(id='msg_01D98t1CvuQrCY6ZT8jQ3i9a', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Backend_Development_Space" as per Thomas\' requirements.', type='text'), ToolUseBlock(id='toolu_01YXTKG7Mkq8vG4EpeHNPVnE', input={'space_id': 'bkend345', 'name': 'Backend_Development_Space', 'color': 'black', 'private': False, 'admin_can_manage': True, 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=319)),
#  ToolsBetaMessage(id='msg_01SNJVEL2v73tzLBKQBgwbRL', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to delete the unused space.", type='text'), ToolUseBlock(id='toolu_01M217sHC9tq6ZYE3b4znu7J', input={'space_id': 'gt678'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2177, output_tokens=82)),
#  ToolsBetaMessage(id='msg_01KMaPGYTKJVgQ4gcJzZHRwv', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the design team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_015oWLPFtjnS8D8H7U6w6NNn', input={'team_id': 'ds101', 'name': 'Design Studio 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2188, output_tokens=261)),
#  ToolsBetaMessage(id='msg_01RHGKr7mTuNp3R2s6EX6DK7', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the specific space requested by the project manager.", type='text'), ToolUseBlock(id='toolu_01E47K8Z8tuF5ZqyKH7VJfhq', input={'space_id': 'ep456'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2172, output_tokens=89)),
#  ToolsBetaMessage(id='msg_01BzXL4VPbJ9iYEbGCGtqi4B', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to update the space as per the requirements:", type='text'), ToolUseBlock(id='toolu_01J1ZgJMfBUZZTBzUpcDBkf7', input={'space_id': 'fe987', 'name': 'FE Development 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01WVJUuvyc8kJzM5YGN3maYV', content=[TextBlock(text="Okay, let's address Samantha's requirements for the strategic shift in how product development milestones are managed at Neptune Technologies.", type='text'), ToolUseBlock(id='toolu_018oRaToEfwnzf9Se8L4SrtG', input={'space_id': 'pd2023', 'name': 'Product Dev 2023 - Strategic Shift', 'color': 'white', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2263, output_tokens=323)),
#  ToolsBetaMessage(id='msg_01DpxgN9dZMZEnDpHdPod68p', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the events management team at Glorious Events Inc.", type='text'), ToolUseBlock(id='toolu_01LFZDJqfDKtFEtyrstmjWVb', input={'team_id': 'gei1234', 'name': 'Event Planning 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2236, output_tokens=265)),
#  ToolsBetaMessage(id='msg_01VdqBRYPseQ7fkWynRxPZJb', content=[TextBlock(text="Okay, let's use the ClickUp API to help the IT department at Zenith Corp. audit their project spaces.", type='text'), ToolUseBlock(id='toolu_01U2oCJoZXrYe87cTxxescpQ', input={'team_id': 'it7890', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2195, output_tokens=109)),
#  ToolsBetaMessage(id='msg_01PKTk6gc5XH3kT3No6TdyTQ', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for Darren's marketing team to manage the upcoming fall campaign.", type='text'), ToolUseBlock(id='toolu_01LsCGU4xR3QN7giKSz8ZBZG', input={'team_id': 'la456', 'name': 'Fall Campaign 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2227, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01CrkUei2CW1tG7RYkq2EgNH', content=[TextBlock(text="Okay, let's address this situation using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01Vu4PjoYdHKWKVFJWuiptxa', input={'space_id': 'outreachQ2', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_bg': '#add8e6', 'tag__tag_fg': '#00008B'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2219, output_tokens=187)),
#  ToolsBetaMessage(id='msg_01NPDAFSwUbGoy8wFiA8W3un', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Urgent Review" tag to the "FTProjects" space as requested.', type='text'), ToolUseBlock(id='toolu_014XFHyyWRAP6F8NNEH8rwCV', input={'space_id': 'FTProjects', 'tag__name': 'Urgent Review', 'tag__tag_bg': '#FF0000', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2202, output_tokens=171)),
#  ToolsBetaMessage(id='msg_01FKqLVzDErFsSa9ouW7tTLJ', content=[TextBlock(text='Okay, let\'s address Crystal\'s needs for the "EMContentPlanning" space at Echo Media.', type='text'), ToolUseBlock(id='toolu_01Qg6AoAeyAMxWxjC1A4bbhP', input={'space_id': 'EMContent2023', 'name': 'EMContentPlanning', 'color': '#483D8B', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2200, output_tokens=316)),
#  ToolsBetaMessage(id='msg_01MHzsKQ3P1EBVeRE99R2eHY', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this situation.", type='text'), ToolUseBlock(id='toolu_01LawkDUr21vZgRjQnNzwu67', input={'space_id': 'OTSpace1', 'name': 'NGT Development 2023', 'color': '#006400', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2279, output_tokens=311)),
#  ToolsBetaMessage(id='msg_01Mcnhh1UjLPzRKj7hKRFVco', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the list of all tags in the "DSAnalysis" space. ', type='text'), ToolUseBlock(id='toolu_01Xzf8E291BNwpwbxiwox1XC', input={'space_id': 'SPACE_ID_FOR_DSANALYSIS'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=105)),
#  ToolsBetaMessage(id='msg_019ABJByWYuuZTnZRHWwzKVw', content=[TextBlock(text='Okay, let\'s use the ClickUp API to get the details of the "TF_ProjectX" space that TerraFirma wants to phase out.', type='text'), ToolUseBlock(id='toolu_01Lxh4Y3fTgyNMn27RtqxXvz', input={'space_id': 'TF_ProjectX'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2198, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01QrcPuekC4WXLi4sgR7aQHo', content=[TextBlock(text="Okay, let's use the ClickUp API to gather the information needed for this audit.", type='text'), ToolUseBlock(id='toolu_017SxbQAAh6xzJXWqKvrMUBr', input={'team_id': 'FI_Team2023', 'archived': True}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2264, output_tokens=105)),
#  ToolsBetaMessage(id='msg_01YPsDj3Kh6Ucp9wyQmdrYJ3', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "Design Hub 2023" space for the PixelPerfect Studios design team.', type='text'), ToolUseBlock(id='toolu_018EXrHTNn4SapnVLFvErCzh', input={'team_id': 'PPS_Design', 'name': 'Design Hub 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': False}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2274, output_tokens=271)),
#  ToolsBetaMessage(id='msg_0184NyZPhYm9mp9UiTf92rGk', content=[TextBlock(text="Okay, let's use the ClickUp API to help Jess with her request.", type='text'), ToolUseBlock(id='toolu_011YdSV92xoNeXssxnFKwTAD', input={'space_id': 'WF_Content', 'tag__name': 'Priority', 'tag__tag_bg': '#FFA500', 'tag__tag_fg': '#FFFFFF'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2243, output_tokens=156)),
#  ToolsBetaMessage(id='msg_01PVCdMsRuj8L6F5x4Syxwmj', content=[TextBlock(text="Okay, let's address the requirements from the finance team at Prospera Finances:", type='text'), ToolUseBlock(id='toolu_0163D6tet6hFN94pDqQkxAzS', input={'space_id': '$SPACE_ID', 'name': 'Finance Operations 2023', 'color': '#000000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2278, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01QRdaQJEC2RkRWmTxAKpkwV', content=[TextBlock(text="Okay, let's break this down step-by-step:", type='text'), ToolUseBlock(id='toolu_018AJP2HbXvbvq643mprh8dt', input={'team_id': '$TEAM_ID', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=98)),
#  ToolsBetaMessage(id='msg_01W4kRJmmyTq1Y79jMnVCoAK', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to delete the redundant "NGS_EarlyConcepts" space as part of the strategic realignment initiative.', type='text'), ToolUseBlock(id='toolu_01Ef3QTrrgA7hHpgeWNM1daD', input={'space_id': 'NGS_EarlyConcepts'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2222, output_tokens=107)),
#  ToolsBetaMessage(id='msg_0148dNH3ocEcNNbR6Eh8rKTf', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of all existing tags in the "Marketing2023" space.', type='text'), ToolUseBlock(id='toolu_01DGzkMMieXNKSMT5UX6puF7', input={'space_id': 'SPACE_ID_FOR_MARKETING2023'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2231, output_tokens=106)),
#  ToolsBetaMessage(id='msg_01MFkAwLmDbGPBvCanDe339f', content=[TextBlock(text='Okay, let\'s address Mitchell\'s requirements for the "TI_ProductLaunches" space in the ClickUp workspace of Titan Industries.', type='text'), ToolUseBlock(id='toolu_01EekAdyTbrhomwssfxmKG84', input={'space_id': 'TI_ProductLaunches', 'name': 'Dynamic Launches 2023', 'color': '#4682B4', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2272, output_tokens=331)),
#  ToolsBetaMessage(id='msg_01BscxLcgcSqYrH6mRNAF4op', content=[TextBlock(text="Okay, let's address this situation step-by-step:", type='text'), ToolUseBlock(id='toolu_01JfV86b1qebuddZDfrsn7Ev', input={'space_id': 'CS_ProjectSpace1'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2239, output_tokens=83)),
#  ToolsBetaMessage(id='msg_01H8DY8NxNzcK2n5xEPAWaYH', content=[TextBlock(text='Okay, let\'s use the ClickUp API to create the new "MilestoneCritical" tag in the "DigitalTrans2023" space.', type='text'), ToolUseBlock(id='toolu_01Qr96BocMVZtndQnrbrvbuH', input={'team_id': 'YOUR_TEAM_ID_HERE', 'archived': False}, name='get_all_clickup_spaces_available', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2267, output_tokens=125)),
#  ToolsBetaMessage(id='msg_01JCvx5N7SkpuHFp1bgXabpT', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the customer success team based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_01Kxm5R77ML9CYqFDEfdD7Gn', input={'team_id': 'custsuccess2020', 'name': 'Customer Engagement Hub', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2226, output_tokens=264)),
#  ToolsBetaMessage(id='msg_01AoJDLFuFxJbBsmB2z2pxqt', content=[TextBlock(text='Okay, let\'s use the "modify_an_existing_clickup_space" tool to update the "social123" space with the new requirements.', type='text'), ToolUseBlock(id='toolu_01C2cFyW71rHvqMX1c3cg8ka', input={'space_id': 'social123', 'name': 'Social Media Command Center', 'color': '#ADD8E6', 'private': False, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=325)),
#  ToolsBetaMessage(id='msg_01GPQeyMYkQZUuimK1hvShpT', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the unused "OldCampaign" tag from the "branddept301" space.', type='text'), ToolUseBlock(id='toolu_016pKaRjtKJc4xbGDULQfRE5', input={'space_id': 'branddept301', 'tag_name': 'OldCampaign', 'tag__name': 'OldCampaign', 'tag__tag_fg': '#808080', 'tag__tag_bg': '#F0F8FF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2214, output_tokens=201)),
#  ToolsBetaMessage(id='msg_01AkkjrA863u966uaufX47BS', content=[TextBlock(text='Okay, let\'s use the ClickUp API to add the new "Time-Sensitive" tag to the existing "engteam777" space.', type='text'), ToolUseBlock(id='toolu_01GmBq1Lw6PnsJgLk6TYKcPp', input={'space_id': 'engteam777', 'tag__name': 'Time-Sensitive', 'tag__tag_fg': '#FFFFFF', 'tag__tag_bg': '#FF4500'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2212, output_tokens=172)),
#  ToolsBetaMessage(id='msg_015jXcBtu1Ssf6KqrBeYCmzR', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "BetaFeature" tag from the "proddev808" space.', type='text'), ToolUseBlock(id='toolu_01PPeiJ6QaqgpkiuV2DZwsFG', input={'space_id': 'proddev808', 'tag_name': 'BetaFeature', 'tag__name': 'BetaFeature', 'tag__tag_fg': '#000000', 'tag__tag_bg': '#FFFF00'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2205, output_tokens=194)),
#  ToolsBetaMessage(id='msg_018Ke2yvoitJWABXyEv8ouxi', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to create the new space for the HR department based on the requirements provided.", type='text'), ToolUseBlock(id='toolu_01AKgrARLDQBbDGLYkQiW6iA', input={'team_id': 'hrdept201', 'name': 'Employee Relations', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': False, 'private': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2204, output_tokens=277)),
#  ToolsBetaMessage(id='msg_01WDxB6SAYP1y5yX2MZGMQ7f', content=[TextBlock(text="Okay, let's use the appropriate tool to retrieve the details of the ClickUp space dedicated to inventory management.", type='text'), ToolUseBlock(id='toolu_014xLbAyjKQHiv5xfBYsQsbS', input={'space_id': 'ecominv500'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2171, output_tokens=92)),
#  ToolsBetaMessage(id='msg_01GSCFofTEBM8vnNfPuDmNdt', content=[TextBlock(text="Okay, let's use the ClickUp API to delete the unnecessary space.", type='text'), ToolUseBlock(id='toolu_0179pyqExhhZ7Zbrw6kNphW8', input={'space_id': 'eduop876'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2174, output_tokens=82)),
#  ToolsBetaMessage(id='msg_012jxqZRLEtQ7R1HyjWLdbA3', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to fulfill Natalie's request.", type='text'), ToolUseBlock(id='toolu_01QN793Z9erCNLSfK8xbEP1H', input={'team_id': 'npo123', 'name': 'Community Driven Projects 2023', 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2208, output_tokens=257)),
#  ToolsBetaMessage(id='msg_012smnkLohZ73fn1hV7vn9qy', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01JEfXJXjTsGJ991U8wWydyK', input={'space_id': 'globalsales400', 'name': 'International Sales Division', 'color': '#FF0000', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2207, output_tokens=309)),
#  ToolsBetaMessage(id='msg_012Cdei4gnMvzeWs8Dgt1Tm5', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to update the "Digital Design Team" space based on Samantha\'s requirements.', type='text'), ToolUseBlock(id='toolu_01NShxQzUbnkYNXaeivctgn6', input={'space_id': 'uiux1020', 'name': 'Digital Design Team', 'color': '#800080', 'private': True, 'admin_can_manage': False, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2251, output_tokens=321)),
#  ToolsBetaMessage(id='msg_01DCYv1ZRmQfYTb1Gp2ZF7yg', content=[TextBlock(text="Okay, let's use the ClickUp API to create a new space for the content strategy team based on the requirements you provided.", type='text'), ToolUseBlock(id='toolu_01TForbicmghmv6UmXkHLCyc', input={'team_id': 'cntstr1234', 'name': 'Content Analysis Q2', 'multiple_assignees': True, 'features__due_dates__enabled': False, 'features__due_dates__start_date': False, 'features__due_dates__remap_due_dates': False, 'features__due_dates__remap_closed_due_date': False, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2215, output_tokens=264)),
#  ToolsBetaMessage(id='msg_013VuZZ9JcL7UyAvrP9r93Rb', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to get the list of tags for the "appdev300" space.', type='text'), ToolUseBlock(id='toolu_015C4gJ8xx36yv5B5FMigoFr', input={'space_id': 'appdev300'}, name='get_all_tags_of_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2197, output_tokens=96)),
#  ToolsBetaMessage(id='msg_01Q53FxU4nn4TNGtBxMJMQCT', content=[TextBlock(text="Okay, let's address this request using the ClickUp API tools available to us.", type='text'), ToolUseBlock(id='toolu_01TFiDAynrxiGaV6iei8rP6Y', input={'space_id': 'datamodel404', 'tag__name': 'Urgent Discrepancy', 'tag__tag_fg': '#FF0000', 'tag__tag_bg': '#808080'}, name='assign_a_tag_to_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2210, output_tokens=159)),
#  ToolsBetaMessage(id='msg_01GB5xzMJFnefKYpPu7UcNco', content=[TextBlock(text='Okay, based on the given situation, the finance team needs to delete the "finforecast345" ClickUp space as it is no longer in use. To accomplish this, I will use the "delete_an_existing_clickup_space" function.', type='text'), ToolUseBlock(id='toolu_01Nw8kxU6Bf9o5Yrz6QZoT89', input={'space_id': 'finforecast345'}, name='delete_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2178, output_tokens=122)),
#  ToolsBetaMessage(id='msg_01N4Kmp2saTTKKZA7Nf9zo8U', content=[TextBlock(text='Okay, let\'s use the ClickUp API to remove the "LowPriority" tag from the "gfxdes678" space.', type='text'), ToolUseBlock(id='toolu_01CpZCjj2JAfu8ZRTDqieXDB', input={'space_id': 'gfxdes678', 'tag_name': 'LowPriority', 'tag__name': 'LowPriority', 'tag__tag_fg': '#D3D3D3', 'tag__tag_bg': '#FFFFFF'}, name='remove_a_tag_from_a_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=200)),
#  ToolsBetaMessage(id='msg_01ERcNqRyeNxMGXDdE9HShm8', content=[TextBlock(text="Okay, let's use the ClickUp API to create the new space for the support team based on the requirements provided:", type='text'), ToolUseBlock(id='toolu_01AGNaeUvmko91cearRgEZpc', input={'team_id': 'supdiv210', 'name': 'Q2 Support Updates', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2218, output_tokens=262)),
#  ToolsBetaMessage(id='msg_01Utf4XWbn3HvaCF32b9Fo4U', content=[TextBlock(text='Okay, let\'s use the appropriate ClickUp tool to retrieve the details of the "gamedev909" space:', type='text'), ToolUseBlock(id='toolu_01DqrHPMqjVFSto8r1rAhNFa', input={'space_id': 'gamedev909'}, name='get_a_specific_clickup_space_details', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2194, output_tokens=92)),
#  ToolsBetaMessage(id='msg_016NrK6Nfm443WZi2HTk1ZAn', content=[TextBlock(text="Okay, let's use the appropriate ClickUp tool to address this request:", type='text'), ToolUseBlock(id='toolu_01F16JwW9NgukvmbVQgaDWXZ', input={'space_id': 'mktoutreach768', 'name': 'Market Outreach 2023', 'color': '#000080', 'private': True, 'admin_can_manage': True, 'multiple_assignees': True, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='modify_an_existing_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2217, output_tokens=313)),
#  ToolsBetaMessage(id='msg_01SWkFm3ciyogV4amQSouys1', content=[TextBlock(text="Okay, let's use the ClickUp API to set up the new space for the Fall Events 2023 team.", type='text'), ToolUseBlock(id='toolu_011jaetYketPzVCYrM1kwbzp', input={'team_id': 'eventeam500', 'name': 'Fall Events 2023', 'multiple_assignees': False, 'features__due_dates__enabled': True, 'features__due_dates__start_date': True, 'features__due_dates__remap_due_dates': True, 'features__due_dates__remap_closed_due_date': True, 'features__time_tracking__enabled': True}, name='create_a_new_clickup_space', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(input_tokens=2232, output_tokens=263))]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_3 = sum(result_list)/len(result_list)
run_acc_3
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': False, 'team_id': 'team123'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'CriticalIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'black',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ep456'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': 'white',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'it7890'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_DSANALYSIS'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'TF_ProjectX'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_all_clickup_spaces_available'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': '$SPACE_ID'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': '$TEAM_ID'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'NGS_EarlyConcepts'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'Marketing2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'SPACE_ID_FOR_MARKETING2023'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'archived': False, 'team_id': 'YOUR_TEAM_ID_HERE'},
#  'name': 'get_all_clickup_spaces_available'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'private': True,
#                'team_id': 'hrdept201'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'ecominv500'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'eduop876'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# {'arguments': {'space_id': 'appdev300'},
#  'name': 'get_all_tags_of_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'assign_a_tag_to_a_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# {'arguments': {'space_id': 'finforecast345'},
#  'name': 'delete_an_existing_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'remove_a_tag_from_a_clickup_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_a_new_clickup_space'}
# True
# -----
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# {'arguments': {'space_id': 'gamedev909'},
#  'name': 'get_a_specific_clickup_space_details'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'modify_an_existing_clickup_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_a_new_clickup_space'}
# False
# -----
# 0.52

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt + Function Name Optimized : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
print(f"Run 2: {run_acc_2}")
print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt + Function Name Optimized : Accuracy
# =========================================
# Run 1: 0.52
# Run 2: 0.52
# Run 3: 0.52
