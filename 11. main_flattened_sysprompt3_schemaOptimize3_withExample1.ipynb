# %%
import json

with open("clickup_space_flattened_schema.json") as f:
    flattened_schema = json.load(f)
    
flattened_schema
# Out:
# [{'description': 'View the Spaces available in a Workspace.',
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not__',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': 'Add a new Space to a Workspace.',
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space__', 'type': 'string'},
#     'team_id': {'description': 'The ID of the team__', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'View the details of a specific Space in a Workspace.',
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Rename, set the Space color, and enable ClickApps for a Space.',
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not__',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space__',
#      'type': 'string'},
#     'features__due_dates__enabled': {'description': 'enabled__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'remap_closed_due_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'remap_due_dates__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'start_date__Due dates feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'enabled__Time tracking feature settings__Enabled features within the space__',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space__',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space__', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not__',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space__', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': 'Delete a Space from your Workspace.',
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'View the task Tags available in a Space.',
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': 'Add a new task Tag to a Space.',
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to create__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to create__',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': 'Delete a task Tag from a Space.',
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space__',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag__The properties of the tag to delete__',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete__',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

schema_funcs_param = {}

for sc in flattened_schema:
    print(sc["name"], "-", sc["description"])
    single_func_param = {}
    for sck, scv in sc["parameters"]["properties"].items():
        single_func_param[sck] = scv['description']
    schema_funcs_param[sc["name"]] = single_func_param

pprint(schema_funcs_param)  # print(f"\t{sck} - {scv['description']}")
# Out:
# get_spaces - View the Spaces available in a Workspace.
# create_space - Add a new Space to a Workspace.
# get_space - View the details of a specific Space in a Workspace.
# update_space - Rename, set the Space color, and enable ClickApps for a Space.
# delete_space - Delete a Space from your Workspace.
# get_space_tags - View the task Tags available in a Space.
# create_space_tag - Add a new task Tag to a Space.
# delete_space_tag - Delete a task Tag from a Space.
# {'create_space': {'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The name of the new space__',
#                   'team_id': 'The ID of the team__'},
#  'create_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to create__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to create__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to create__'},
#  'delete_space': {'space_id': 'The ID of the space__'},
#  'delete_space_tag': {'space_id': 'The ID of the space__',
#                       'tag__name': 'The name of the tag__The properties of the '
#                                    'tag to delete__',
#                       'tag__tag_bg': 'The background color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag__tag_fg': 'The foreground color of the tag__The '
#                                      'properties of the tag to delete__',
#                       'tag_name': 'The name of the tag to delete__'},
#  'get_space': {'space_id': 'The ID of the space__'},
#  'get_space_tags': {'space_id': 'The ID of the space__'},
#  'get_spaces': {'archived': 'A flag to decide whether to include archived '
#                             'spaces or not__',
#                 'team_id': 'The ID of the team__'},
#  'update_space': {'admin_can_manage': 'A flag to determine if the '
#                                       'administrator can manage the space or '
#                                       'not__',
#                   'color': 'The color used for the space__',
#                   'features__due_dates__enabled': 'enabled__Due dates feature '
#                                                   'settings__Enabled features '
#                                                   'within the space__',
#                   'features__due_dates__remap_closed_due_date': 'remap_closed_due_date__Due '
#                                                                 'dates feature '
#                                                                 'settings__Enabled '
#                                                                 'features '
#                                                                 'within the '
#                                                                 'space__',
#                   'features__due_dates__remap_due_dates': 'remap_due_dates__Due '
#                                                           'dates feature '
#                                                           'settings__Enabled '
#                                                           'features within the '
#                                                           'space__',
#                   'features__due_dates__start_date': 'start_date__Due dates '
#                                                      'feature '
#                                                      'settings__Enabled '
#                                                      'features within the '
#                                                      'space__',
#                   'features__time_tracking__enabled': 'enabled__Time tracking '
#                                                       'feature '
#                                                       'settings__Enabled '
#                                                       'features within the '
#                                                       'space__',
#                   'multiple_assignees': 'Enable or disable multiple assignees '
#                                         'for tasks within the space__',
#                   'name': 'The new name of the space__',
#                   'private': 'A flag to determine if the space is private or '
#                              'not__',
#                   'space_id': 'The ID of the space__'}}

# %%
schema_func_decription_dict = {
    "get_spaces": """\
Retrives information of all the spaces available in user's Clickup Workspace. Example Call:
```python
get_spaces({'team_id': 'a1b2c3d4', 'archived': False})
```
    """,
    "create_space": """\
Creates a new ClickUp space. Example Call:
```python
create_space ({
  'team_id': 'abc123',
  'name': 'NewWorkspace',
  'multiple_assignees': True,
  'features__due_dates__enabled': True,
  'features__due_dates__start_date': False,
  'features__due_dates__remap_due_dates': False,
  'features__due_dates__remap_closed_due_date': False,
  'features__time_tracking__enabled': True
})
```
""",
    "get_space": """\
Retrives information of a specific Clickup space. Example Call:
```python
get_space({'space_id': 's12345'})
```
""",
    "update_space": """\
Modifies name, settings the Space color, and assignee management Space. Example Call:
```python
update_space({
  'space_id': 's12345',
  'name': 'UpdatedWorkspace',
  'color': '#f0f0f0',
  'private': True,
  'admin_can_manage': False,
  'multiple_assignees': True,
  'features__due_dates__enabled': True,
  'features__due_dates__start_date': False,
  'features__due_dates__remap_due_dates': False,
  'features__due_dates__remap_closed_due_date': False,
  'features__time_tracking__enabled': True
})
```

""",
    "delete_space": """\
Delete an existing space from user's ClickUp Workspace. Example Call:
```python
delete_space({'space_id': 's12345'})
```
    """,
    "get_space_tags": """\
Retrives all the Tags assigned on all the tasks in a Space. Example Call:
```python
get_space_tags({'space_id': 's12345'})
```
""",
    "create_space_tag": """\
        Assigns a customized Tag in a ClickUp Space. Example Call:
```python
create_space_tag({
  'space_id': 's12345',
  'tag__name': 'Important',
  'tag__tag_bg': '#ff0000',
  'tag__tag_fg': '#ffffff'
})
```
        """,
    "delete_space_tag": """\
    Deletes a specific tag previously assigned in a space. Example Call:
```python
delete_space_tag({
  'space_id': 's12345',
  'tag_name': 'Important',
  'tag__name': 'Important',
  'tag__tag_bg': '#ff0000',
  'tag__tag_fg': '#ffffff'
})
```
    """,
}

schema_func_params_dict = {
    'create_space': {
        'features__due_dates__enabled': 'If due date feature is enabled within the space. Default: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. Default: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space. Default: True',
        'name': 'The name of the new space to create',
        'team_id': 'The ID of the team'
        },
    'create_space_tag': {
        'space_id': 'The ID of the space',
        'tag__name': 'The name of the tag to assign',
        'tag__tag_bg': 'The background color of the tag to assign',
        'tag__tag_fg': 'The foreground(text) color of the tag to assign'
        },
    'delete_space': {
        'space_id': 'The ID of the space to delete'
        },
    'delete_space_tag': {
        'space_id': 'The ID of the space',
        'tag__name': 'The name of the tag to delete',
        'tag__tag_bg': 'The background color of the tag to delete',
        'tag__tag_fg': 'The foreground color of the tag to delete',
        'tag_name': 'The name of the tag to delete'
        },
    'get_space': {
        'space_id': 'The ID of the space to retrieve details'
        },
    'get_space_tags': {
        'space_id': 'The ID of the space to retrieve all the tags from'
        },
    'get_spaces': {
        'archived': 'A flag to decide whether to include archived spaces or not. Default: True',
        'team_id': 'The ID of the team'
        },
    'update_space': {
        'admin_can_manage': 'A flag to determine if the administrator can manage the space or not. Default: True',
        'color': 'The color used for the space',
        'features__due_dates__enabled': 'If due date feature is enabled within the space. Default: True',
        'features__due_dates__remap_closed_due_date': 'If remapping closed date feature in due dates is available within the space. Default: False',
        'features__due_dates__remap_due_dates': 'If remapping due date feature in due dates is available within the space. Default: False',
        'features__due_dates__start_date': 'If start date feature in due dates is available within the space. Default: False',
        'features__time_tracking__enabled': 'If time tracking feature is available within the space. Default: True',
        'multiple_assignees': 'Enable or disable multiple assignees for tasks within the space. Default: True',
        'name': 'The new name of the space',
        'private': 'A flag to determine if the space is private or not. Default: False',
        'space_id': 'The ID of the space'
        }
        }
    
optimized_schema = []
for sc in flattened_schema:
    temp_dict = sc.copy()
    temp_dict["description"] = schema_func_decription_dict[temp_dict["name"]]
    for func_param_name, func_param_description in schema_func_params_dict[temp_dict["name"]].items():
        sc["parameters"]["properties"][func_param_name]["description"] = func_param_description
    optimized_schema.append(temp_dict)

with open('clickup_space_flattened_optimized3_schema.json', 'w') as f:
    json.dump(optimized_schema, f, indent=4, sort_keys=True)
    
optimized_schema
# Out:
# [{'description': "Retrives information of all the spaces available in user's Clickup Workspace. Example Call:\n```python\nget_spaces({'team_id': 'a1b2c3d4', 'archived': False})\n```\n    ",
#   'name': 'get_spaces',
#   'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not. Default: True',
#      'type': 'boolean'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id', 'archived'],
#    'type': 'object'}},
#  {'description': "Creates a new ClickUp space. Example Call:\n```python\ncreate_space ({\n  'team_id': 'abc123',\n  'name': 'NewWorkspace',\n  'multiple_assignees': True,\n  'features__due_dates__enabled': True,\n  'features__due_dates__start_date': False,\n  'features__due_dates__remap_due_dates': False,\n  'features__due_dates__remap_closed_due_date': False,\n  'features__time_tracking__enabled': True\n})\n```\n",
#   'name': 'create_space',
#   'parameters': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The name of the new space to create',
#      'type': 'string'},
#     'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#    'required': ['team_id',
#     'name',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': "Retrives information of a specific Clickup space. Example Call:\n```python\nget_space({'space_id': 's12345'})\n```\n",
#   'name': 'get_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve details',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': "Modifies name, settings the Space color, and assignee management Space. Example Call:\n```python\nupdate_space({\n  'space_id': 's12345',\n  'name': 'UpdatedWorkspace',\n  'color': '#f0f0f0',\n  'private': True,\n  'admin_can_manage': False,\n  'multiple_assignees': True,\n  'features__due_dates__enabled': True,\n  'features__due_dates__start_date': False,\n  'features__due_dates__remap_due_dates': False,\n  'features__due_dates__remap_closed_due_date': False,\n  'features__time_tracking__enabled': True\n})\n```\n\n",
#   'name': 'update_space',
#   'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not. Default: True',
#      'type': 'boolean'},
#     'color': {'description': 'The color used for the space', 'type': 'string'},
#     'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#      'type': 'boolean'},
#     'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#      'type': 'boolean'},
#     'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#      'type': 'boolean'},
#     'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#      'type': 'boolean'},
#     'name': {'description': 'The new name of the space', 'type': 'string'},
#     'private': {'description': 'A flag to determine if the space is private or not. Default: False',
#      'type': 'boolean'},
#     'space_id': {'description': 'The ID of the space', 'type': 'string'}},
#    'required': ['space_id',
#     'name',
#     'color',
#     'private',
#     'admin_can_manage',
#     'multiple_assignees',
#     'features__due_dates__enabled',
#     'features__due_dates__start_date',
#     'features__due_dates__remap_due_dates',
#     'features__due_dates__remap_closed_due_date',
#     'features__time_tracking__enabled'],
#    'type': 'object'}},
#  {'description': "Delete an existing space from user's ClickUp Workspace. Example Call:\n```python\ndelete_space({'space_id': 's12345'})\n```\n    ",
#   'name': 'delete_space',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to delete',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': "Retrives all the Tags assigned on all the tasks in a Space. Example Call:\n```python\nget_space_tags({'space_id': 's12345'})\n```\n",
#   'name': 'get_space_tags',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve all the tags from',
#      'type': 'string'}},
#    'required': ['space_id'],
#    'type': 'object'}},
#  {'description': "        Assigns a customized Tag in a ClickUp Space. Example Call:\n```python\ncreate_space_tag({\n  'space_id': 's12345',\n  'tag__name': 'Important',\n  'tag__tag_bg': '#ff0000',\n  'tag__tag_fg': '#ffffff'\n})\n```\n        ",
#   'name': 'create_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to assign',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to assign',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground(text) color of the tag to assign',
#      'type': 'string'}},
#    'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#    'type': 'object'}},
#  {'description': "    Deletes a specific tag previously assigned in a space. Example Call:\n```python\ndelete_space_tag({\n  'space_id': 's12345',\n  'tag_name': 'Important',\n  'tag__name': 'Important',\n  'tag__tag_bg': '#ff0000',\n  'tag__tag_fg': '#ffffff'\n})\n```\n    ",
#   'name': 'delete_space_tag',
#   'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#      'type': 'string'},
#     'tag__name': {'description': 'The name of the tag to delete',
#      'type': 'string'},
#     'tag__tag_bg': {'description': 'The background color of the tag to delete',
#      'type': 'string'},
#     'tag__tag_fg': {'description': 'The foreground color of the tag to delete',
#      'type': 'string'},
#     'tag_name': {'description': 'The name of the tag to delete',
#      'type': 'string'}},
#    'required': ['space_id',
#     'tag_name',
#     'tag__name',
#     'tag__tag_fg',
#     'tag__tag_bg'],
#    'type': 'object'}}]

# %%
from pprint import pprint

def flatten_dict(d, parent_key='', sep='__'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Your original dictionary
original_dict = {
    'features': {
        'due_dates': {
            'enabled': False,
            'remap_closed_due_date': False,
            'remap_due_dates': False,
            'start_date': False
        },
        'time_tracking': {
            'enabled': False
        }
    },
    'multiple_assignees': True,
    'name': 'Innovative Campaigns 2023',
    'team_id': 'cm789'
}

# Flatten the dictionary
flattened_dict = flatten_dict(original_dict)

pprint(flattened_dict)
# Out:
# {'features__due_dates__enabled': False,
#  'features__due_dates__remap_closed_due_date': False,
#  'features__due_dates__remap_due_dates': False,
#  'features__due_dates__start_date': False,
#  'features__time_tracking__enabled': False,
#  'multiple_assignees': True,
#  'name': 'Innovative Campaigns 2023',
#  'team_id': 'cm789'}

# %%
import json

with open("clickup_space_benchmark.json") as f:
    bench_data = json.load(f)
    
bench_data[1]
# Out:
# {'prompt': 'Ella, the project coordinator, is setting up a new project space in ClickUp for the "Creative Minds" team with team ID "cm789". This space, named "Innovative Campaigns 2023", should allow multiple assignees for tasks, but keep due dates and time tracking disabled, as the initial planning phase doesn\'t require strict deadlines or time monitoring.',
#  'solution': 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'}

# %%
import os
import json
import dotenv
import openai
from textwrap import dedent
from datetime import datetime

dotenv.load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

tools = [{"type":"function", "function":sc} for sc in optimized_schema]
tools
# Out:
# [{'type': 'function',
#   'function': {'description': "Retrives information of all the spaces available in user's Clickup Workspace. Example Call:\n```python\nget_spaces({'team_id': 'a1b2c3d4', 'archived': False})\n```\n    ",
#    'name': 'get_spaces',
#    'parameters': {'properties': {'archived': {'description': 'A flag to decide whether to include archived spaces or not. Default: True',
#       'type': 'boolean'},
#      'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#     'required': ['team_id', 'archived'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "Creates a new ClickUp space. Example Call:\n```python\ncreate_space ({\n  'team_id': 'abc123',\n  'name': 'NewWorkspace',\n  'multiple_assignees': True,\n  'features__due_dates__enabled': True,\n  'features__due_dates__start_date': False,\n  'features__due_dates__remap_due_dates': False,\n  'features__due_dates__remap_closed_due_date': False,\n  'features__time_tracking__enabled': True\n})\n```\n",
#    'name': 'create_space',
#    'parameters': {'properties': {'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#       'type': 'boolean'},
#      'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#       'type': 'boolean'},
#      'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#       'type': 'boolean'},
#      'name': {'description': 'The name of the new space to create',
#       'type': 'string'},
#      'team_id': {'description': 'The ID of the team', 'type': 'string'}},
#     'required': ['team_id',
#      'name',
#      'multiple_assignees',
#      'features__due_dates__enabled',
#      'features__due_dates__start_date',
#      'features__due_dates__remap_due_dates',
#      'features__due_dates__remap_closed_due_date',
#      'features__time_tracking__enabled'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "Retrives information of a specific Clickup space. Example Call:\n```python\nget_space({'space_id': 's12345'})\n```\n",
#    'name': 'get_space',
#    'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve details',
#       'type': 'string'}},
#     'required': ['space_id'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "Modifies name, settings the Space color, and assignee management Space. Example Call:\n```python\nupdate_space({\n  'space_id': 's12345',\n  'name': 'UpdatedWorkspace',\n  'color': '#f0f0f0',\n  'private': True,\n  'admin_can_manage': False,\n  'multiple_assignees': True,\n  'features__due_dates__enabled': True,\n  'features__due_dates__start_date': False,\n  'features__due_dates__remap_due_dates': False,\n  'features__due_dates__remap_closed_due_date': False,\n  'features__time_tracking__enabled': True\n})\n```\n\n",
#    'name': 'update_space',
#    'parameters': {'properties': {'admin_can_manage': {'description': 'A flag to determine if the administrator can manage the space or not. Default: True',
#       'type': 'boolean'},
#      'color': {'description': 'The color used for the space',
#       'type': 'string'},
#      'features__due_dates__enabled': {'description': 'If due date feature is enabled within the space. Default: True',
#       'type': 'boolean'},
#      'features__due_dates__remap_closed_due_date': {'description': 'If remapping closed date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__due_dates__remap_due_dates': {'description': 'If remapping due date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__due_dates__start_date': {'description': 'If start date feature in due dates is available within the space. Default: False',
#       'type': 'boolean'},
#      'features__time_tracking__enabled': {'description': 'If time tracking feature is available within the space. Default: True',
#       'type': 'boolean'},
#      'multiple_assignees': {'description': 'Enable or disable multiple assignees for tasks within the space. Default: True',
#       'type': 'boolean'},
#      'name': {'description': 'The new name of the space', 'type': 'string'},
#      'private': {'description': 'A flag to determine if the space is private or not. Default: False',
#       'type': 'boolean'},
#      'space_id': {'description': 'The ID of the space', 'type': 'string'}},
#     'required': ['space_id',
#      'name',
#      'color',
#      'private',
#      'admin_can_manage',
#      'multiple_assignees',
#      'features__due_dates__enabled',
#      'features__due_dates__start_date',
#      'features__due_dates__remap_due_dates',
#      'features__due_dates__remap_closed_due_date',
#      'features__time_tracking__enabled'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "Delete an existing space from user's ClickUp Workspace. Example Call:\n```python\ndelete_space({'space_id': 's12345'})\n```\n    ",
#    'name': 'delete_space',
#    'parameters': {'properties': {'space_id': {'description': 'The ID of the space to delete',
#       'type': 'string'}},
#     'required': ['space_id'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "Retrives all the Tags assigned on all the tasks in a Space. Example Call:\n```python\nget_space_tags({'space_id': 's12345'})\n```\n",
#    'name': 'get_space_tags',
#    'parameters': {'properties': {'space_id': {'description': 'The ID of the space to retrieve all the tags from',
#       'type': 'string'}},
#     'required': ['space_id'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "        Assigns a customized Tag in a ClickUp Space. Example Call:\n```python\ncreate_space_tag({\n  'space_id': 's12345',\n  'tag__name': 'Important',\n  'tag__tag_bg': '#ff0000',\n  'tag__tag_fg': '#ffffff'\n})\n```\n        ",
#    'name': 'create_space_tag',
#    'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#       'type': 'string'},
#      'tag__name': {'description': 'The name of the tag to assign',
#       'type': 'string'},
#      'tag__tag_bg': {'description': 'The background color of the tag to assign',
#       'type': 'string'},
#      'tag__tag_fg': {'description': 'The foreground(text) color of the tag to assign',
#       'type': 'string'}},
#     'required': ['space_id', 'tag__name', 'tag__tag_fg', 'tag__tag_bg'],
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'description': "    Deletes a specific tag previously assigned in a space. Example Call:\n```python\ndelete_space_tag({\n  'space_id': 's12345',\n  'tag_name': 'Important',\n  'tag__name': 'Important',\n  'tag__tag_bg': '#ff0000',\n  'tag__tag_fg': '#ffffff'\n})\n```\n    ",
#    'name': 'delete_space_tag',
#    'parameters': {'properties': {'space_id': {'description': 'The ID of the space',
#       'type': 'string'},
#      'tag__name': {'description': 'The name of the tag to delete',
#       'type': 'string'},
#      'tag__tag_bg': {'description': 'The background color of the tag to delete',
#       'type': 'string'},
#      'tag__tag_fg': {'description': 'The foreground color of the tag to delete',
#       'type': 'string'},
#      'tag_name': {'description': 'The name of the tag to delete',
#       'type': 'string'}},
#     'required': ['space_id',
#      'tag_name',
#      'tag__name',
#      'tag__tag_fg',
#      'tag__tag_bg'],
#     'type': 'object'}}}]

# %%
from openai import OpenAI
client = OpenAI()

tool_trailer = "\n".join([f'{sc["name"]} - {sc["description"]}' for sc in optimized_schema])


fcalling_llm = lambda fprompt : client.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {
      "role": "system",
      "content": f"""
You are an agent who is responsible for managing various employee management platform, 
one of which is CliuckUp. 

You are given a number of tools as functions, you must use one of those tools and fillup 
all the parameters of those tools ,whose answers you will get from the given situation.

When you are presented with a technical situation, that a person of a team is facing, 
you must give the soulution utilizing your functionalities. 

The Functions provided to you are:
{tool_trailer}

First analyze the given situation to fully anderstand what is the intention of the user,
what they need and exactly which tool will fill up that necessity.

Then look into the parameters and extract all the relevant informations to fillup the 
parameter with right values.
"""
    },
    {
      "role": "user",
      "content": fprompt
    },
  ],
  temperature=0,
  max_tokens=4096,
  top_p=1,
  tools=tools,
  tool_choice="auto"
)

response = fcalling_llm(bench_data[1]["prompt"])
# response
response.choices[0].message.tool_calls[0].function
# Out:
# Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Innovative Campaigns 2023","team_id":"cm789"}', name='create_space')

# %%
import re 
from pprint import pprint



class FuncStringParser():
    def __init__(self):
        self.record_keeper = {}
        
        
    def replace_with_dict(self, match):
        replacement = f"dict{len(self.record_keeper)}"
        self.record_keeper[replacement] = match.group()
        # dict_counter += 1
        return replacement

    def arg_tuple_str_to_args_dict(self, func_args):
        # print(func_args)
        args_dict = {}
        func_args = func_args[1:-1].split(",")
        for arg in func_args:
            k, v = arg[:arg.find("=")], arg[arg.find("=")+1:]
            k, v = k.strip(), v.strip()
            
            if v.startswith("(") and v.endswith(")"):
                v = self.func_to_args_dict(v)
                # print(v)
            
            args_dict[k] = v

        return args_dict

    def replace_true_false_dfs(self, nested_dict):
        for key, value in nested_dict.items():
            # If the value is a nested dictionary, recursively process it
            if isinstance(value, dict):
                self.replace_true_false_dfs(value)
            else:
                nested_dict[key] = eval(value)
                
                    
    def func_to_args_dict(self, func_args):
        pattern_uncompiled = r'\(([^()]+)\)'
        pattern = re.compile(pattern_uncompiled)
        # print(re.findall(pattern_uncompiled, func_args))
        while len(re.findall(pattern_uncompiled, func_args)) > 1:
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            
        # print(re.findall(pattern_uncompiled, func_args))
        if sum([m.start(0) > 2 for m in re.finditer(r'\(([^()]+)\)', func_args)]):
            func_args = re.sub(pattern, self.replace_with_dict, func_args)
            # print(func_args)
        func_args = re.sub(pattern, self.replace_with_dict, func_args)
        # pprint(func_args)
            
        dict_record_keeper = {k:self.arg_tuple_str_to_args_dict(v) for k, v in self.record_keeper.items()}
        # print(dict_record_keeper)
        
        # inv_dict_record_keeper = {v:k for k,v in dict_record_keeper.items()}
        for i1, (k1, v1) in enumerate(dict_record_keeper.items()):
            for i2, (k2, v2) in enumerate(dict_record_keeper.items()):
                if i2 == i1:
                    break
                if k2 in v1.values():
                    # print(k2, v1)
                    dict_record_keeper[k1][list(v1.keys())[list(v1.values()).index(k2)]] = v2
        args_dict = list(dict_record_keeper.values())[-1]
        self.replace_true_false_dfs(args_dict)
        self.record_keeper = {}
        return args_dict
    
    def func_string_to_func_dict(self, func_string):
        func_name = func_string[:func_string.find("(")]
        func_args = func_string[func_string.find("("):]
        func_args_dict = self.func_to_args_dict(func_args)
        return {"name": func_name, "arguments": func_args_dict}
    
    def llm_response_to_func_dict(self, llm_response):
        if llm_response is not None:
            func_name = llm_response.name
            func_args_dict = json.loads(llm_response.arguments)
        else:
            func_name = None
            func_args_dict = None 
        return {"name": func_name, "arguments": func_args_dict}
        

                    
        
    
# Sample string
func = 'create_space(team_id="cm789", name="Innovative Campaigns 2023", multiple_assignees=True, features=(due_dates=(enabled=False, start_date=False, remap_due_dates=False, remap_closed_due_date=False), time_tracking=(enabled=False)))'

func_name = func[:func.find("(")]
func_args = func[func.find("("):]

fsp = FuncStringParser()
# fsp.func_to_args_dict(func_args)

fsp.func_string_to_func_dict(func)
# Out:
# {'name': 'create_space',
#  'arguments': {'team_id': 'cm789',
#   'name': 'Innovative Campaigns 2023',
#   'multiple_assignees': True,
#   'features': {'due_dates': {'enabled': False,
#     'start_date': False,
#     'remap_due_dates': False,
#     'remap_closed_due_date': False},
#    'time_tracking': {'enabled': False}}}}

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response.choices[0].message.tool_calls[0].function)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [03:38<00:00,  4.36s/it]
# [Function(arguments='{"archived":false,"team_id":"team123"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Innovative Campaigns 2023","team_id":"cm789"}', name='create_space'),
#  Function(arguments='{"space_id": "sd456"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"prj1122","tag__name":"CriticalIssue","tag__name":"CriticalIssue","tag__tag_bg":"#ff0000","tag__tag_fg":"#ffffff"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"qa789","tag__name":"MinorIssue","tag__tag_bg":"#FFFFE0","tag__tag_fg":"#000000","tag_name":"MinorIssue"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"bkend345","name":"Backend_Development_Space","color":"#000000","private":false,"admin_can_manage":true,"multiple_assignees":false,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":true,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"gt678"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Design Studio 2023","team_id":"ds101"}', name='create_space'),
#  Function(arguments='{"space_id":"ep456"}', name='get_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#f0f0f0","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"FE Development 2023","private":true,"space_id":"fe987"}', name='update_space'),
#  Function(arguments='{"space_id":"pd2023","name":"Product Dev 2023 - Strategic Shift","color":"#ffffff","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Event Planning 2023","team_id":"gei1234"}', name='create_space'),
#  Function(arguments='{"archived":true,"team_id":"it7890"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Fall Campaign 2023","team_id":"la456"}', name='create_space'),
#  Function(arguments='{"space_id":"outreachQ2","tag__name":"OldCampaign","tag__tag_bg":"#add8e6","tag__tag_fg":"#00008B","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"archived":false,"team_id":"Forward Technologies"}', name='get_spaces'),
#  Function(arguments='{"space_id":"EMContent2023","name":"EMContentPlanning","color":"#483D8B","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#006400","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"NGT Development 2023","private":true,"space_id":"OTSpace1"}', name='update_space'),
#  Function(arguments='{"space_id":"DSAnalysis"}', name='get_space_tags'),
#  Function(arguments='{"archived":false,"team_id":"TerraFirma"}', name='get_spaces'),
#  Function(arguments='{"archived":true,"team_id":"FI_Team2023"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Design Hub 2023","team_id":"PPS_Design"}', name='create_space'),
#  Function(arguments='{"space_id":"WF_Content","tag__name":"Priority","tag__tag_bg":"#FFA500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"archived":false,"team_id":"PF_Projects"}', name='get_spaces'),
#  Function(arguments='{"archived":false,"team_id":"GlobalEngineeringSolutions"}', name='get_spaces'),
#  Function(arguments='{"archived":false,"team_id":"NexGen Solutions"}', name='get_spaces'),
#  Function(arguments='{"space_id":"s12345"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"TI_ProductLaunches","name":"Dynamic Launches 2023","color":"#4682B4","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":false}', name='update_space'),
#  Function(arguments='{"space_id":"CS_ProjectSpace1"}', name='get_space'),
#  Function(arguments='{"space_id":"DigitalTrans2023","tag__name":"MilestoneCritical","tag__tag_bg":"#00008B","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Customer Engagement Hub","team_id":"custsuccess2020"}', name='create_space'),
#  Function(arguments='{"space_id":"social123","name":"Social Media Command Center","color":"#ADD8E6","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"branddept301","tag__name":"OldCampaign","tag__tag_bg":"#F0F8FF","tag__tag_fg":"#808080","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"engteam777","tag__name":"Time-Sensitive","tag__tag_bg":"#FF4500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"proddev808","tag__name":"BetaFeature","tag__tag_bg":"#FFFF00","tag__tag_fg":"#000000","tag_name":"BetaFeature"}', name='delete_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Employee Relations","team_id":"hrdept201"}', name='create_space'),
#  Function(arguments='{"space_id":"ecominv500"}', name='get_space'),
#  Function(arguments='{"space_id":"eduop876"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Community Driven Projects 2023","team_id":"npo123"}', name='create_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#FF0000","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"International Sales Division","private":true,"space_id":"globalsales400"}', name='update_space'),
#  Function(arguments='{"space_id":"uiux1020","name":"Digital Design Team","color":"#800080","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Content Analysis Q2","team_id":"cntstr1234"}', name='create_space'),
#  Function(arguments='{"space_id":"appdev300"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"datamodel404","tag__name":"Urgent Discrepancy","tag__tag_bg":"#808080","tag__tag_fg":"#FF0000"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"finforecast345"}', name='delete_space'),
#  Function(arguments='{"space_id":"gfxdes678","tag__name":"LowPriority","tag__tag_bg":"#FFFFFF","tag__tag_fg":"#D3D3D3","tag_name":"LowPriority"}', name='delete_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":true,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":false,"name":"Q2 Support Updates","team_id":"supdiv210"}', name='create_space'),
#  Function(arguments='{"space_id":"gamedev909"}', name='get_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#000080","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Market Outreach 2023","private":true,"space_id":"mktoutreach768"}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":false,"name":"Fall Events 2023","team_id":"eventeam500"}', name='create_space')]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_1 = sum(result_list)/len(result_list)
run_acc_1
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'CriticalIssue',
#                'tag__tag_bg': '#ff0000',
#                'tag__tag_fg': '#ffffff'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#f0f0f0',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'Forward Technologies'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'archived': False, 'team_id': 'TerraFirma'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'PF_Projects'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'GlobalEngineeringSolutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'archived': False, 'team_id': 'NexGen Solutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 's12345'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.72

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response.choices[0].message.tool_calls[0].function)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [03:14<00:00,  3.90s/it]
# [Function(arguments='{"archived":false,"team_id":"team123"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Innovative Campaigns 2023","team_id":"cm789"}', name='create_space'),
#  Function(arguments='{"space_id": "sd456"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"prj1122"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"qa789","tag__name":"MinorIssue","tag__tag_bg":"#FFFFE0","tag__tag_fg":"#000000","tag_name":"MinorIssue"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"bkend345","name":"Backend_Development_Space","color":"#000000","private":false,"admin_can_manage":true,"multiple_assignees":false,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":true,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"gt678"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Design Studio 2023","team_id":"ds101"}', name='create_space'),
#  Function(arguments='{"space_id":"ep456"}', name='get_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#f0f0f0","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"FE Development 2023","private":true,"space_id":"fe987"}', name='update_space'),
#  Function(arguments='{"space_id":"pd2023","name":"Product Dev 2023 - Strategic Shift","color":"#ffffff","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Event Planning 2023","team_id":"gei1234"}', name='create_space'),
#  Function(arguments='{"archived":true,"team_id":"it7890"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Fall Campaign 2023","team_id":"la456"}', name='create_space'),
#  Function(arguments='{"space_id":"s12345","tag__name":"OldCampaign","tag__tag_bg":"#add8e6","tag__tag_fg":"#00008B","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"archived":false,"team_id":"ForwardTechnologies"}', name='get_spaces'),
#  Function(arguments='{"space_id":"EMContent2023","name":"EMContentPlanning","color":"#483D8B","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"OTSpace1","name":"NGT Development 2023","color":"#006400","private":true,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":false}', name='update_space'),
#  Function(arguments='{"space_id":"DSAnalysis"}', name='get_space_tags'),
#  Function(arguments='{"archived":false,"team_id":"TerraFirma"}', name='get_spaces'),
#  Function(arguments='{"archived":true,"team_id":"FI_Team2023"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Design Hub 2023","team_id":"PPS_Design"}', name='create_space'),
#  Function(arguments='{"space_id":"WF_Content","tag__name":"Priority","tag__tag_bg":"#FFA500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"archived":false,"team_id":"PF_Projects"}', name='get_spaces'),
#  Function(arguments='{"archived":false,"team_id":"GlobalEngineeringSolutions"}', name='get_spaces'),
#  Function(arguments='{"archived":false,"team_id":"NexGen Solutions"}', name='get_spaces'),
#  Function(arguments='{"space_id":"s12345"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"TI_ProductLaunches","name":"Dynamic Launches 2023","color":"#4682B4","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"CS_ProjectSpace1"}', name='get_space'),
#  Function(arguments='{"space_id":"DigitalTrans2023","tag__name":"MilestoneCritical","tag__tag_bg":"#00008B","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Customer Engagement Hub","team_id":"custsuccess2020"}', name='create_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#ADD8E6","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Social Media Command Center","private":false,"space_id":"social123"}', name='update_space'),
#  Function(arguments='{"space_id":"branddept301","tag__name":"OldCampaign","tag__tag_bg":"#F0F8FF","tag__tag_fg":"#808080","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"engteam777","tag__name":"Time-Sensitive","tag__tag_bg":"#FF4500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"proddev808","tag__name":"BetaFeature","tag__tag_bg":"#FFFF00","tag__tag_fg":"#000000","tag_name":"BetaFeature"}', name='delete_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Employee Relations","team_id":"hrdept201"}', name='create_space'),
#  Function(arguments='{"space_id":"ecominv500"}', name='get_space'),
#  Function(arguments='{"space_id":"eduop876"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Community Driven Projects 2023","team_id":"npo123"}', name='create_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#FF0000","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"International Sales Division","private":true,"space_id":"globalsales400"}', name='update_space'),
#  Function(arguments='{"space_id":"uiux1020","name":"Digital Design Team","color":"#800080","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Content Analysis Q2","team_id":"cntstr1234"}', name='create_space'),
#  Function(arguments='{"space_id":"appdev300"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"datamodel404","tag__name":"Urgent Discrepancy","tag__tag_bg":"#808080","tag__tag_fg":"#FF0000"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"finforecast345"}', name='delete_space'),
#  Function(arguments='{"space_id":"gfxdes678","tag__name":"LowPriority","tag__tag_bg":"#FFFFFF","tag__tag_fg":"#D3D3D3","tag_name":"LowPriority"}', name='delete_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":true,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":false,"name":"Q2 Support Updates","team_id":"supdiv210"}', name='create_space'),
#  Function(arguments='{"space_id":"gamedev909"}', name='get_space'),
#  Function(arguments='{"space_id":"mktoutreach768","name":"Market Outreach 2023","color":"#000080","private":true,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":false,"name":"Fall Events 2023","team_id":"eventeam500"}', name='create_space')]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    # bdata_solution_dict["name"] = schema_func_name_dict[bdata_solution_dict["name"]]
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_2 = sum(result_list)/len(result_list)
run_acc_2
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#f0f0f0',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 's12345',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'ForwardTechnologies'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'archived': False, 'team_id': 'TerraFirma'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'archived': False, 'team_id': 'PF_Projects'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'GlobalEngineeringSolutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'archived': False, 'team_id': 'NexGen Solutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 's12345'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# True
# -----
# 0.7

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm


llm_output = []

for bdata in tqdm(bench_data):
    response = fcalling_llm(bdata["prompt"])
    try:
        llm_output.append(response.choices[0].message.tool_calls[0].function)
    except TypeError:
        print(bdata["prompt"])
        print(response)
        llm_output.append(None)
        print("------")
llm_output
# Out:
# 100%|██████████| 50/50 [03:24<00:00,  4.09s/it]
# [Function(arguments='{"archived":false,"team_id":"team123"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Innovative Campaigns 2023","team_id":"cm789"}', name='create_space'),
#  Function(arguments='{"space_id": "sd456"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"prj1122"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"qa789","tag__name":"MinorIssue","tag__tag_bg":"#FFFFE0","tag__tag_fg":"#000000","tag_name":"MinorIssue"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"bkend345","name":"Backend_Development_Space","color":"#000000","private":false,"admin_can_manage":true,"multiple_assignees":false,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":true,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"gt678"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Design Studio 2023","team_id":"ds101"}', name='create_space'),
#  Function(arguments='{"space_id":"ep456"}', name='get_space'),
#  Function(arguments='{"space_id":"fe987","name":"FE Development 2023","color":"#f0f0f0","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#ffffff","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Product Dev 2023 - Strategic Shift","private":true,"space_id":"pd2023"}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Event Planning 2023","team_id":"gei1234"}', name='create_space'),
#  Function(arguments='{"archived":true,"team_id":"it7890"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Fall Campaign 2023","team_id":"la456"}', name='create_space'),
#  Function(arguments='{"space_id":"s12345","tag__name":"OldCampaign","tag__tag_bg":"#add8e6","tag__tag_fg":"#00008B","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"archived":false,"team_id":"ForwardTechnologies"}', name='get_spaces'),
#  Function(arguments='{"space_id":"EMContent2023","name":"EMContentPlanning","color":"#483D8B","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#006400","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"NGT Development 2023","private":true,"space_id":"OTSpace1"}', name='update_space'),
#  Function(arguments='{"space_id":"DSAnalysis"}', name='get_space_tags'),
#  Function(arguments='{"archived":false,"team_id":"TerraFirma"}', name='get_spaces'),
#  Function(arguments='{"archived":true,"team_id":"FI_Team2023"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Design Hub 2023","team_id":"PPS_Design"}', name='create_space'),
#  Function(arguments='{"space_id":"WF_Content","tag__name":"Priority","tag__tag_bg":"#FFA500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"PF_Projects"}', name='get_space'),
#  Function(arguments='{"archived":false,"team_id":"GlobalEngineeringSolutions"}', name='get_spaces'),
#  Function(arguments='{"archived":false,"team_id":"NexGen Solutions"}', name='get_spaces'),
#  Function(arguments='{"space_id":"Marketing2023"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"TI_ProductLaunches","name":"Dynamic Launches 2023","color":"#4682B4","private":false,"admin_can_manage":true,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"space_id":"CS_ProjectSpace1"}', name='get_space'),
#  Function(arguments='{"archived":false,"team_id":"Pathway Technologies"}', name='get_spaces'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Customer Engagement Hub","team_id":"custsuccess2020"}', name='create_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#ADD8E6","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Social Media Command Center","private":false,"space_id":"social123"}', name='update_space'),
#  Function(arguments='{"space_id":"branddept301","tag__name":"OldCampaign","tag__tag_bg":"#F0F8FF","tag__tag_fg":"#808080","tag_name":"OldCampaign"}', name='delete_space_tag'),
#  Function(arguments='{"space_id":"engteam777","tag__name":"Time-Sensitive","tag__tag_bg":"#FF4500","tag__tag_fg":"#FFFFFF"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"proddev808","tag__name":"BetaFeature","tag__tag_bg":"#FFFF00","tag__tag_fg":"#000000","tag_name":"BetaFeature"}', name='delete_space_tag'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Employee Relations","team_id":"hrdept201"}', name='create_space'),
#  Function(arguments='{"space_id":"ecominv500"}', name='get_space'),
#  Function(arguments='{"space_id":"eduop876"}', name='delete_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":true,"name":"Community Driven Projects 2023","team_id":"npo123"}', name='create_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#FF0000","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"International Sales Division","private":true,"space_id":"globalsales400"}', name='update_space'),
#  Function(arguments='{"space_id":"uiux1020","name":"Digital Design Team","color":"#800080","private":true,"admin_can_manage":false,"multiple_assignees":true,"features__due_dates__enabled":true,"features__due_dates__start_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":true}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":false,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Content Analysis Q2","team_id":"cntstr1234"}', name='create_space'),
#  Function(arguments='{"space_id":"appdev300"}', name='get_space_tags'),
#  Function(arguments='{"space_id":"datamodel404","tag__name":"Urgent Discrepancy","tag__tag_bg":"#808080","tag__tag_fg":"#FF0000"}', name='create_space_tag'),
#  Function(arguments='{"space_id":"finforecast345"}', name='delete_space'),
#  Function(arguments='{"space_id":"gfxdes678","tag__name":"LowPriority","tag__tag_bg":"#FFFFFF","tag__tag_fg":"#D3D3D3","tag_name":"LowPriority"}', name='delete_space_tag'),
#  Function(arguments='{"team_id":"supdiv210","name":"Q2 Support Updates","multiple_assignees":false,"features__due_dates__enabled":true,"features__due_dates__start_date":true,"features__due_dates__remap_due_dates":true,"features__due_dates__remap_closed_due_date":false,"features__time_tracking__enabled":false}', name='create_space'),
#  Function(arguments='{"space_id":"gamedev909"}', name='get_space'),
#  Function(arguments='{"admin_can_manage":true,"color":"#000080","features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":false,"features__time_tracking__enabled":true,"multiple_assignees":true,"name":"Market Outreach 2023","private":true,"space_id":"mktoutreach768"}', name='update_space'),
#  Function(arguments='{"features__due_dates__enabled":true,"features__due_dates__remap_closed_due_date":false,"features__due_dates__remap_due_dates":false,"features__due_dates__start_date":true,"features__time_tracking__enabled":false,"multiple_assignees":false,"name":"Fall Events 2023","team_id":"eventeam500"}', name='create_space')]

# %%
from pprint import pprint

fsp = FuncStringParser()
result_list = []

# fsp.func_to_args_dict(func_args)
for bdata, llm_response in zip(bench_data, llm_output):
    bdata_solution_dict = fsp.func_string_to_func_dict(bdata["solution"])
    bdata_solution_dict["arguments"] = flatten_dict(bdata_solution_dict["arguments"])
    
    llm_response_dict = fsp.llm_response_to_func_dict(llm_response)
    
    pprint(bdata_solution_dict)
    pprint(llm_response_dict)
    print(llm_response_dict == bdata_solution_dict)
    result_list.append(llm_response_dict == bdata_solution_dict)
    print("-----")
    
run_acc_3 = sum(result_list)/len(result_list)
run_acc_3
# Out:
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# {'arguments': {'archived': False, 'team_id': 'team123'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Innovative Campaigns 2023',
#                'team_id': 'cm789'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'sd456'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'prj1122',
#                'tag__name': 'Critical Bug',
#                'tag__tag_bg': '#8B0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'prj1122'}, 'name': 'get_space_tags'}
# False
# -----
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'qa789',
#                'tag__name': 'MinorIssue',
#                'tag__tag_bg': '#FFFFE0',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'MinorIssue'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Backend_Development_Space',
#                'private': False,
#                'space_id': 'bkend345'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'gt678'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Design Studio 2023',
#                'team_id': 'ds101'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ep456'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#f0f0f0',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'FE Development 2023',
#                'private': True,
#                'space_id': 'fe987'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FFFFFF',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ffffff',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Product Dev 2023 - Strategic Shift',
#                'private': True,
#                'space_id': 'pd2023'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Event Planning 2023',
#                'team_id': 'gei1234'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'it7890'}, 'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Fall Campaign 2023',
#                'team_id': 'la456'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'outreachQ2',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 's12345',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#add8e6',
#                'tag__tag_fg': '#00008B',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# False
# -----
# {'arguments': {'space_id': 'FTProjects',
#                'tag__name': 'Urgent Review',
#                'tag__tag_bg': '#FF0000',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'ForwardTechnologies'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#483D8B',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'EMContentPlanning',
#                'private': False,
#                'space_id': 'EMContent2023'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#006400',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'NGT Development 2023',
#                'private': True,
#                'space_id': 'OTSpace1'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'DSAnalysis'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'TF_ProjectX'}, 'name': 'get_space'}
# {'arguments': {'archived': False, 'team_id': 'TerraFirma'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# {'arguments': {'archived': True, 'team_id': 'FI_Team2023'},
#  'name': 'get_spaces'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Design Hub 2023',
#                'team_id': 'PPS_Design'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'WF_Content',
#                'tag__name': 'Priority',
#                'tag__tag_bg': '#FFA500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#0000FF',
#                'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Finance Operations 2023',
#                'private': True,
#                'space_id': 'PF_Projects'},
#  'name': 'update_space'}
# {'arguments': {'space_id': 'PF_Projects'}, 'name': 'get_space'}
# False
# -----
# {'arguments': {'space_id': 'GES_InfraDev2022',
#                'tag__name': 'ArchiveThis',
#                'tag__tag_bg': '#000000',
#                'tag__tag_fg': '#FFFFFF',
#                'tag_name': 'ArchiveThis'},
#  'name': 'delete_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'GlobalEngineeringSolutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'NGS_EarlyConcepts'}, 'name': 'delete_space'}
# {'arguments': {'archived': False, 'team_id': 'NexGen Solutions'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'Marketing2023'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#4682B4',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Dynamic Launches 2023',
#                'private': False,
#                'space_id': 'TI_ProductLaunches'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'CS_ProjectSpace1'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'DigitalTrans2023',
#                'tag__name': 'MilestoneCritical',
#                'tag__tag_bg': '#00008B',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'archived': False, 'team_id': 'Pathway Technologies'},
#  'name': 'get_spaces'}
# False
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Customer Engagement Hub',
#                'team_id': 'custsuccess2020'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#ADD8E6',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Social Media Command Center',
#                'private': False,
#                'space_id': 'social123'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'branddept301',
#                'tag__name': 'OldCampaign',
#                'tag__tag_bg': '#F0F8FF',
#                'tag__tag_fg': '#808080',
#                'tag_name': 'OldCampaign'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'engteam777',
#                'tag__name': 'Time-Sensitive',
#                'tag__tag_bg': '#FF4500',
#                'tag__tag_fg': '#FFFFFF'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'proddev808',
#                'tag__name': 'BetaFeature',
#                'tag__tag_bg': '#FFFF00',
#                'tag__tag_fg': '#000000',
#                'tag_name': 'BetaFeature'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Employee Relations',
#                'team_id': 'hrdept201'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'ecominv500'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'eduop876'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Community Driven Projects 2023',
#                'team_id': 'npo123'},
#  'name': 'create_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#FF0000',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'International Sales Division',
#                'private': True,
#                'space_id': 'globalsales400'},
#  'name': 'update_space'}
# False
# -----
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': False,
#                'color': '#800080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Digital Design Team',
#                'private': True,
#                'space_id': 'uiux1020'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': False,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Content Analysis Q2',
#                'team_id': 'cntstr1234'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# {'arguments': {'space_id': 'appdev300'}, 'name': 'get_space_tags'}
# True
# -----
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# {'arguments': {'space_id': 'datamodel404',
#                'tag__name': 'Urgent Discrepancy',
#                'tag__tag_bg': '#808080',
#                'tag__tag_fg': '#FF0000'},
#  'name': 'create_space_tag'}
# True
# -----
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# {'arguments': {'space_id': 'finforecast345'}, 'name': 'delete_space'}
# True
# -----
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# {'arguments': {'space_id': 'gfxdes678',
#                'tag__name': 'LowPriority',
#                'tag__tag_bg': '#FFFFFF',
#                'tag__tag_fg': '#D3D3D3',
#                'tag_name': 'LowPriority'},
#  'name': 'delete_space_tag'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': True,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': True,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': False,
#                'name': 'Q2 Support Updates',
#                'team_id': 'supdiv210'},
#  'name': 'create_space'}
# False
# -----
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# {'arguments': {'space_id': 'gamedev909'}, 'name': 'get_space'}
# True
# -----
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# {'arguments': {'admin_can_manage': True,
#                'color': '#000080',
#                'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': False,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': True,
#                'name': 'Market Outreach 2023',
#                'private': True,
#                'space_id': 'mktoutreach768'},
#  'name': 'update_space'}
# True
# -----
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': True,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# {'arguments': {'features__due_dates__enabled': True,
#                'features__due_dates__remap_closed_due_date': False,
#                'features__due_dates__remap_due_dates': False,
#                'features__due_dates__start_date': True,
#                'features__time_tracking__enabled': False,
#                'multiple_assignees': False,
#                'name': 'Fall Events 2023',
#                'team_id': 'eventeam500'},
#  'name': 'create_space'}
# False
# -----
# 0.66

# %%
print("ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary + \nFunction and Parameter Descriptions Optimized + Function Call examples added : Accuracy")
print("=========================================")
print(f"Run 1: {run_acc_1}")
print(f"Run 2: {run_acc_2}")
print(f"Run 3: {run_acc_3}")
# Out:
# ClickUp Benchmark - Flattened Schema + Focused System Prompt containing Schema summary +
# Function and Parameter Descriptions Optimized + Function Call examples added : Accuracy
# =========================================
# Run 1: 0.72
# Run 2: 0.7
# Run 3: 0.66
